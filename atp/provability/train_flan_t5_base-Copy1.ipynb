# %%
import os
import random
import pickle

def is_pp_useful(pp):
    lines = pp.split('\n')
    targets = []
    conditions = []
    min_freq = 1000000
    for line in lines:
        if line.startswith("⊢"):
            target = line.strip()
            targets.append(target)
        else:
            conditions.append(line.strip())
    if '⊢ False' in targets:
        return False
    #if '⊢ R' in targets:
    #    return False
    if '?m.' in pp:
        return False
    return True

# Given a pkl file which contains the provability data
# Returns (list(state_pp, next_tactic), list(state_pp, steps_to_proven(int or -1)))
def get_states_and_shortest_proofs(pkl_path, verbose=False):
    next_tac_list = []
    provability_list = []
    fin = open(pkl_path, 'rb')
    theorem_states = dict()
    if verbose: print("Loading", pkl_path)
    #
    while True:
        try:
            result = pickle.load(fin)
        except Exception as e:
            print(e)
            break
        file_path, full_name, theorem, state_pair = result
        if state_pair is None:
            continue
        state, proven_state, dist, tactics = state_pair
        state_pp = state.pp
        if full_name not in theorem_states:
            theorem_states[full_name] = dict()
            if verbose: print("Loading theorem", full_name)
        if state_pp not in theorem_states[full_name]:
            theorem_states[full_name][state_pp] = list()
        if tactics is not None and len(tactics) > 0:
            theorem_states[full_name][state_pp].append(tactics)
    #
    if verbose: print("Summarizing data ...")
    for full_name, states in theorem_states.items():
        negative_provability_list = list()
        num_tac_added = 0
        for state_pp, proofs in states.items():
            if not is_pp_useful(state_pp):
                continue
            if len(proofs) == 0:
                negative_provability_list.append((file_path, full_name, state_pp, -1))
            else:
                shortest_tac_len = min([len(str(proof)) for proof in proofs])
                shortest_proofs = [proof for proof in proofs if len(str(proof)) == shortest_tac_len]
                dist = min([len(proof) for proof in shortest_proofs])
                provability_list.append((file_path, full_name, state_pp, dist))
                next_tac_list.append((file_path, full_name, state_pp, random.choice(shortest_proofs)))
                num_tac_added += 1
        negative_provability_list = random.sample(negative_provability_list, 
                                                  min(num_tac_added, len(negative_provability_list)))
        provability_list.extend(negative_provability_list)
    #
    if verbose: print("Done")
    return next_tac_list, provability_list


def get_all_theorems_processed(folder_paths, verbose=True):
    # Enumerate all .pkl files in the folder
    all_proof_list = list()
    all_provability_list = list()
    for folder_path in folder_paths:
        for filename in os.listdir(folder_path):
            if filename.endswith(".pkl"):
                found = False
                file_path = os.path.join(folder_path, filename)
                next_tac_list, provability_list = get_states_and_shortest_proofs(
                    file_path,
                    verbose=True
                )
                all_proof_list.extend(next_tac_list)
                all_provability_list.extend(provability_list)
    return all_proof_list, all_provability_list

previous_output_paths = [
    "/home/mcwave/code/automath/atp/datasets/provability/rag_20240621",
    "/home/mcwave/code/automath/atp/datasets/provability/rag_20240622",
    "/home/mcwave/code/automath/atp/datasets/provability/rag_20240623"
]

all_proof_list, all_provability_list = get_all_theorems_processed(previous_output_paths)

fout = open('/home/mcwave/code/automath/atp/datasets/provability/rag_20240621_20240623_state_proof.pkl', 'wb')
pickle.dump(all_proof_list, fout)
fout.close()

fout = open('/home/mcwave/code/automath/atp/datasets/provability/rag_20240621_20240623_state_provability.pkl', 'wb')
pickle.dump(all_provability_list, fout)
fout.close()
# Out:
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Combinatorics__Enumerative__Partition.lean.pkl
# Loading theorem Nat.Partition.ofComposition_surj
# Loading theorem Nat.Partition.indiscrete_parts
# Loading theorem Nat.Partition.partition_one_parts
# Loading theorem Nat.Partition.count_ofSums_of_ne_zero
# Loading theorem Nat.Partition.count_ofSums_zero
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__SetTheory__Game__State.lean.pkl
# Loading theorem SetTheory.PGame.turnBound_ne_zero_of_left_move
# Loading theorem SetTheory.PGame.turnBound_ne_zero_of_right_move
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__GroupTheory__CommutingProbability.lean.pkl
# Loading theorem commProb_def
# Loading theorem commProb_prod
# Loading theorem commProb_pi
# Loading theorem commProb_function
# Loading theorem commProb_eq_zero_of_infinite
# Loading theorem commProb_le_one
# Loading theorem commProb_eq_one_iff
# Loading theorem commProb_def'
# Loading theorem Subgroup.commProb_subgroup_le
# Loading theorem Subgroup.commProb_quotient_le
# Loading theorem DihedralGroup.commProb_odd
# Loading theorem DihedralGroup.reciprocalFactors_zero
# Loading theorem DihedralGroup.reciprocalFactors_one
# Loading theorem DihedralGroup.reciprocalFactors_even
# Loading theorem DihedralGroup.reciprocalFactors_odd
# Loading theorem DihedralGroup.commProb_nil
# Loading theorem DihedralGroup.commProb_cons
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Analysis__Complex__Hadamard.lean.pkl
# Loading theorem Complex.HadamardThreeLines.sSupNormIm_nonneg
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Analysis__SpecialFunctions__Complex__Analytic.lean.pkl
# Loading theorem analyticOn_cexp
# Loading theorem analyticAt_clog
# Loading theorem AnalyticAt.cpow
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Topology__Category__TopCat__Limits__Cofiltered.lean.pkl
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__AlgebraicGeometry__AffineScheme.lean.pkl
# Loading theorem AlgebraicGeometry.isAffineOfIso
# Loading theorem AlgebraicGeometry.rangeIsAffineOpenOfOpenImmersion
# Loading theorem AlgebraicGeometry.topIsAffineOpen
# Loading theorem AlgebraicGeometry.isBasis_affine_open
# Loading theorem AlgebraicGeometry.isBasis_basicOpen
# Loading theorem AlgebraicGeometry.IsAffineOpen.fromSpec_range
# Loading theorem AlgebraicGeometry.IsAffineOpen.fromSpec_image_top
# Loading theorem AlgebraicGeometry.IsAffineOpen.isCompact
# Loading theorem AlgebraicGeometry.IsAffineOpen.imageIsOpenImmersion
# Loading theorem AlgebraicGeometry.IsAffineOpen.fromSpec_base_preimage
# Loading theorem AlgebraicGeometry.IsAffineOpen.fromSpec_app_self
# Loading theorem AlgebraicGeometry.IsAffineOpen.fromSpec_map_basicOpen'
# Loading theorem AlgebraicGeometry.IsAffineOpen.fromSpec_map_basicOpen
# Loading theorem AlgebraicGeometry.IsAffineOpen.opensFunctor_map_basicOpen
# Loading theorem AlgebraicGeometry.IsAffineOpen.basicOpen_fromSpec_app
# Loading theorem AlgebraicGeometry.IsAffineOpen.basicOpenIsAffine
# Loading theorem AlgebraicGeometry.IsAffineOpen.mapRestrictBasicOpen
# Loading theorem AlgebraicGeometry.IsAffineOpen.exists_basicOpen_le
# Loading theorem AlgebraicGeometry.IsAffineOpen.isLocalization_basicOpen
# Loading theorem AlgebraicGeometry.IsAffineOpen.isLocalization_of_eq_basicOpen
# Loading theorem AlgebraicGeometry.IsAffineOpen.basicOpen_basicOpen_is_basicOpen
# Loading theorem AlgebraicGeometry.exists_basicOpen_le_affine_inter
# Loading theorem AlgebraicGeometry.IsAffineOpen.fromSpec_primeIdealOf
# Loading theorem AlgebraicGeometry.IsAffineOpen.isLocalization_stalk
# Loading theorem AlgebraicGeometry.IsAffineOpen.basicOpen_union_eq_self_iff
# Loading theorem AlgebraicGeometry.IsAffineOpen.self_le_basicOpen_union_iff
# Loading theorem AlgebraicGeometry.of_affine_open_cover
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__CategoryTheory__Limits__Fubini.lean.pkl
# Loading theorem CategoryTheory.Limits.DiagramOfCones.mkOfHasLimits_conePoints
# Loading theorem CategoryTheory.Limits.limitUncurryIsoLimitCompLim_hom_π_π
# Loading theorem CategoryTheory.Limits.limitUncurryIsoLimitCompLim_inv_π
# Loading theorem CategoryTheory.Limits.DiagramOfCocones.mkOfHasColimits_coconePoints
# Loading theorem CategoryTheory.Limits.colimitUncurryIsoColimitCompColim_ι_ι_inv
# Loading theorem CategoryTheory.Limits.colimitUncurryIsoColimitCompColim_ι_hom
# Loading theorem CategoryTheory.Limits.limitFlipCompLimIsoLimitCompLim_hom_π_π
# Loading theorem CategoryTheory.Limits.limitFlipCompLimIsoLimitCompLim_inv_π_π
# Loading theorem CategoryTheory.Limits.colimitFlipCompColimIsoColimitCompColim_ι_ι_hom
# Loading theorem CategoryTheory.Limits.colimitFlipCompColimIsoColimitCompColim_ι_ι_inv
# Loading theorem CategoryTheory.Limits.limitIsoLimitCurryCompLim_hom_π_π
# Loading theorem CategoryTheory.Limits.limitIsoLimitCurryCompLim_inv_π
# Loading theorem CategoryTheory.Limits.colimitIsoColimitCurryCompColim_ι_ι_inv
# Loading theorem CategoryTheory.Limits.colimitIsoColimitCurryCompColim_ι_hom
# Loading theorem CategoryTheory.Limits.limitCurrySwapCompLimIsoLimitCurryCompLim_hom_π_π
# Loading theorem CategoryTheory.Limits.limitCurrySwapCompLimIsoLimitCurryCompLim_inv_π_π
# Loading theorem CategoryTheory.Limits.colimitCurrySwapCompColimIsoColimitCurryCompColim_ι_ι_hom
# Loading theorem CategoryTheory.Limits.colimitCurrySwapCompColimIsoColimitCurryCompColim_ι_ι_inv
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__MeasureTheory__Function__L2Space.lean.pkl
# Loading theorem MeasureTheory.Memℒp.integrable_sq
# Loading theorem MeasureTheory.memℒp_two_iff_integrable_sq_norm
# Loading theorem MeasureTheory.memℒp_two_iff_integrable_sq
# Loading theorem MeasureTheory.Integrable.const_inner
# Loading theorem MeasureTheory.Integrable.inner_const
# Loading theorem integral_eq_zero_of_forall_integral_inner_eq_zero
# Loading theorem MeasureTheory.L2.snorm_rpow_two_norm_lt_top
# Loading theorem MeasureTheory.L2.snorm_inner_lt_top
# Loading theorem MeasureTheory.L2.inner_def
# Loading theorem MeasureTheory.L2.integral_inner_eq_sq_snorm
# Loading theorem MeasureTheory.L2.norm_sq_eq_inner'
# Loading theorem MeasureTheory.L2.mem_L1_inner
# Loading theorem MeasureTheory.L2.add_left'
# Loading theorem MeasureTheory.L2.smul_left'
# Loading theorem MeasureTheory.L2.inner_indicatorConstLp_eq_setIntegral_inner
# Loading theorem MeasureTheory.L2.inner_indicatorConstLp_eq_inner_setIntegral
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Order__BoundedOrder.lean.pkl
# Loading theorem isTop_top
# Loading theorem isMax_top
# Loading theorem ne_top_of_lt
# Loading theorem not_isMax_iff_ne_top
# Loading theorem not_isTop_iff_ne_top
# Loading theorem top_le_iff
# Loading theorem top_unique
# Loading theorem eq_top_iff
# Loading theorem eq_top_mono
# Loading theorem lt_top_iff_ne_top
# Loading theorem not_lt_top_iff
# Loading theorem eq_top_or_lt_top
# Loading theorem Ne.lt_top
# Loading theorem Ne.lt_top'
# Loading theorem OrderTop.ext_top
# Loading theorem bot_le
# Loading theorem isBot_bot
# Loading theorem OrderDual.ofDual_bot
# Loading theorem OrderDual.ofDual_top
# Loading theorem OrderDual.toDual_bot
# Loading theorem OrderDual.toDual_top
# Loading theorem isMin_bot
# Loading theorem not_isMin_iff_ne_bot
# Loading theorem not_isBot_iff_ne_bot
# Loading theorem le_bot_iff
# Loading theorem bot_unique
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Analysis__SpecialFunctions__Complex__Log.lean.pkl
# Loading theorem Complex.log_re
# Loading theorem Complex.log_im
# Loading theorem Complex.neg_pi_lt_log_im
# Loading theorem Complex.log_im_le_pi
# Loading theorem Complex.exp_log
# Loading theorem Complex.log_exp
# Loading theorem Complex.exp_inj_of_neg_pi_lt_of_le_pi
# Loading theorem Complex.natCast_log
# Loading theorem Complex.ofNat_log
# Loading theorem Complex.log_ofReal_re
# Loading theorem Complex.log_ofReal_mul
# Loading theorem Complex.log_mul_ofReal
# Loading theorem Complex.log_mul_eq_add_log_iff
# Loading theorem Complex.log_zero
# Loading theorem Complex.log_one
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Topology__Category__Compactum.lean.pkl
# Loading theorem Compactum.str_incl
# Loading theorem Compactum.str_hom_commute
# Loading theorem Compactum.join_distrib
# Loading theorem Compactum.isClosed_iff
# Loading theorem Compactum.basic_inter
# Loading theorem Compactum.cl_cl
# Loading theorem Compactum.isClosed_cl
# Loading theorem Compactum.str_eq_of_le_nhds
# Loading theorem Compactum.le_nhds_of_str_eq
# Loading theorem Compactum.lim_eq_str
# Loading theorem Compactum.cl_eq_closure
# Loading theorem Compactum.continuous_of_hom
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Topology__Compactness__Lindelof.lean.pkl
# Loading theorem IsLindelof.compl_mem_sets
# Loading theorem IsLindelof.compl_mem_sets_of_nhdsWithin
# Loading theorem IsLindelof.induction_on
# Loading theorem IsLindelof.inter_right
# Loading theorem IsLindelof.image_of_continuousOn
# Loading theorem IsLindelof.elim_countable_subcover
# Loading theorem IsLindelof.elim_nhds_subcover'
# Loading theorem IsLindelof.elim_nhds_subcover
# Loading theorem IsLindelof.indexed_countable_subcover
# Loading theorem IsLindelof.disjoint_nhdsSet_left
# Loading theorem IsLindelof.disjoint_nhdsSet_right
# Loading theorem IsLindelof.elim_countable_subfamily_closed
# Loading theorem IsLindelof.inter_iInter_nonempty
# Loading theorem IsLindelof.elim_countable_subcover_image
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Tactic__Peel.lean.pkl
# Loading theorem Mathlib.Tactic.Peel.and_imp_left_of_imp_imp
# Loading theorem Mathlib.Tactic.Peel.eventually_imp
# Loading theorem Mathlib.Tactic.Peel.frequently_imp
# Loading theorem Mathlib.Tactic.Peel.eventually_congr
# Loading theorem Mathlib.Tactic.Peel.frequently_congr
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Algebra__Regular__Basic.lean.pkl
# Loading theorem IsLeftRegular.right_of_commute
# Loading theorem IsRightRegular.left_of_commute
# Loading theorem IsLeftRegular.mul
# Loading theorem IsRightRegular.of_mul
# Loading theorem mul_isRightRegular_iff
# Loading theorem isRegular_mul_and_mul_iff
# Loading theorem IsLeftRegular.subsingleton
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__AlgebraicGeometry__GammaSpecAdjunction.lean.pkl
# Loading theorem AlgebraicGeometry.LocallyRingedSpace.not_mem_prime_iff_unit_in_stalk
# Loading theorem AlgebraicGeometry.LocallyRingedSpace.toΓSpec_preim_basicOpen_eq
# Loading theorem AlgebraicGeometry.LocallyRingedSpace.toΓSpec_continuous
# Loading theorem AlgebraicGeometry.LocallyRingedSpace.isUnit_res_toΓSpecMapBasicOpen
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/.lake__packages__batteries__Batteries__Data__List__Init__Attach.lean.pkl
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__CategoryTheory__Category__Basic.lean.pkl
# Loading theorem CategoryTheory.eq_whisker
# Loading theorem CategoryTheory.whisker_eq
# Loading theorem CategoryTheory.eq_of_comp_left_eq
# Loading theorem CategoryTheory.eq_of_comp_right_eq
# Loading theorem CategoryTheory.id_of_comp_left_id
# Loading theorem CategoryTheory.id_of_comp_right_id
# Loading theorem CategoryTheory.comp_ite
# Loading theorem CategoryTheory.ite_comp
# Loading theorem CategoryTheory.comp_dite
# Loading theorem CategoryTheory.dite_comp
# Loading theorem CategoryTheory.cancel_epi_id
# Loading theorem CategoryTheory.cancel_mono_id
# Loading theorem CategoryTheory.epi_comp
# Loading theorem CategoryTheory.mono_comp
# Loading theorem CategoryTheory.mono_of_mono
# Loading theorem CategoryTheory.mono_of_mono_fac
# Loading theorem CategoryTheory.epi_of_epi
# Loading theorem CategoryTheory.epi_of_epi_fac
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__MeasureTheory__Measure__Content.lean.pkl
# Loading theorem MeasureTheory.Content.apply_eq_coe_toFun
# Loading theorem MeasureTheory.Content.mono
# Loading theorem MeasureTheory.Content.sup_disjoint
# Loading theorem MeasureTheory.Content.sup_le
# Loading theorem MeasureTheory.Content.lt_top
# Loading theorem MeasureTheory.Content.empty
# Loading theorem MeasureTheory.Content.innerContent_bot
# Loading theorem MeasureTheory.Content.innerContent_exists_compact
# Loading theorem MeasureTheory.Content.innerContent_iSup_nat
# Loading theorem MeasureTheory.Content.innerContent_iUnion_nat
# Loading theorem MeasureTheory.Content.innerContent_comap
# Loading theorem MeasureTheory.Content.is_mul_left_invariant_innerContent
# Loading theorem MeasureTheory.Content.innerContent_pos_of_is_mul_left_invariant
# Loading theorem MeasureTheory.Content.le_outerMeasure_compacts
# Loading theorem MeasureTheory.Content.outerMeasure_exists_compact
# Loading theorem MeasureTheory.Content.outerMeasure_exists_open
# Loading theorem MeasureTheory.Content.outerMeasure_preimage
# Loading theorem MeasureTheory.Content.outerMeasure_lt_top_of_isCompact
# Loading theorem MeasureTheory.Content.is_mul_left_invariant_outerMeasure
# Loading theorem MeasureTheory.Content.outerMeasure_caratheodory
# Loading theorem MeasureTheory.Content.outerMeasure_pos_of_is_mul_left_invariant
# Loading theorem MeasureTheory.Content.contentRegular_exists_compact
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__LinearAlgebra__InvariantBasisNumber.lean.pkl
# Loading theorem strongRankCondition_iff_succ
# Loading theorem card_le_of_injective
# Loading theorem card_le_of_injective'
# Loading theorem card_le_of_surjective
# Loading theorem card_le_of_surjective'
# Loading theorem eq_of_fin_equiv
# Loading theorem nontrivial_of_invariantBasisNumber
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__RingTheory__Nilpotent__Basic.lean.pkl
# Loading theorem IsNilpotent.neg
# Loading theorem IsNilpotent.smul
# Loading theorem IsNilpotent.isUnit_sub_one
# Loading theorem IsNilpotent.isUnit_one_sub
# Loading theorem IsNilpotent.isUnit_add_one
# Loading theorem IsNilpotent.isUnit_add_left_of_commute
# Loading theorem zero_isRadical_iff
# Loading theorem isReduced_iff_pow_one_lt
# Loading theorem Commute.add_pow_eq_zero_of_add_le_succ_of_pow_eq_zero
# Loading theorem Commute.isNilpotent_add
# Loading theorem Commute.isNilpotent_sum
# Loading theorem Commute.isNilpotent_mul_left_iff
# Loading theorem Commute.isNilpotent_mul_right_iff
# Loading theorem Commute.isNilpotent_sub
# Loading theorem NoZeroSMulDivisors.isReduced
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Topology__Algebra__Module__CharacterSpace.lean.pkl
# Loading theorem WeakDual.CharacterSpace.coe_coe
# Loading theorem WeakDual.CharacterSpace.ext
# Loading theorem WeakDual.CharacterSpace.coe_toCLM
# Loading theorem WeakDual.CharacterSpace.coe_toNonUnitalAlgHom
# Loading theorem WeakDual.CharacterSpace.union_zero_isClosed
# Loading theorem WeakDual.CharacterSpace.eq_set_map_one_map_mul
# Loading theorem WeakDual.CharacterSpace.isClosed
# Loading theorem WeakDual.CharacterSpace.ext_ker
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Algebra__Polynomial__Splits.lean.pkl
# Loading theorem Polynomial.splits_zero
# Loading theorem Polynomial.splits_map_iff
# Loading theorem Polynomial.splits_of_isUnit
# Loading theorem Polynomial.splits_prod
# Loading theorem Polynomial.splits_pow
# Loading theorem Polynomial.splits_id_iff_splits
# Loading theorem Polynomial.natDegree_eq_card_roots'
# Loading theorem Polynomial.degree_eq_card_roots'
# Loading theorem Polynomial.splits_iff
# Loading theorem Polynomial.Splits.def
# Loading theorem Polynomial.splits_of_splits_of_dvd
# Loading theorem Polynomial.splits_prod_iff
# Loading theorem Polynomial.degree_eq_one_of_irreducible_of_splits
# Loading theorem Polynomial.rootOfSplits'_eq_rootOfSplits
# Loading theorem Polynomial.degree_eq_card_roots
# Loading theorem Polynomial.image_rootSet
# Loading theorem Polynomial.adjoin_rootSet_eq_range
# Loading theorem Polynomial.eq_prod_roots_of_splits
# Loading theorem Polynomial.eq_prod_roots_of_splits_id
# Loading theorem Polynomial.eq_prod_roots_of_monic_of_splits_id
# Loading theorem Polynomial.eq_X_sub_C_of_splits_of_single_root
# Loading theorem Polynomial.mem_lift_of_splits_of_roots_mem_range
# Loading theorem Polynomial.splits_of_comp
# Loading theorem Polynomial.splits_of_algHom
# Loading theorem Polynomial.splits_iff_card_roots
# Loading theorem Polynomial.aeval_root_derivative_of_splits
# Loading theorem Polynomial.prod_roots_eq_coeff_zero_of_monic_of_split
# Loading theorem Polynomial.sum_roots_eq_nextCoeff_of_monic_of_split
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Topology__MetricSpace__IsometricSMul.lean.pkl
# Loading theorem isometry_smul
# Loading theorem edist_div_right
# Loading theorem edist_inv_inv
# Loading theorem isometry_inv
# Loading theorem edist_inv
# Loading theorem edist_div_left
# Loading theorem IsometryEquiv.constSMul_symm
# Loading theorem IsometryEquiv.mulLeft_symm
# Loading theorem IsometryEquiv.mulRight_symm
# Loading theorem IsometryEquiv.divRight_symm
# Loading theorem IsometryEquiv.inv_symm
# Loading theorem EMetric.preimage_smul_ball
# Loading theorem EMetric.preimage_smul_closedBall
# Loading theorem EMetric.preimage_mul_right_ball
# Loading theorem EMetric.preimage_mul_right_closedBall
# Loading theorem dist_smul
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Topology__Category__Profinite__Nobeling.lean.pkl
# Loading theorem Profinite.NobelingProof.continuous_proj
# Loading theorem Profinite.NobelingProof.proj_eq_self
# Loading theorem Profinite.NobelingProof.proj_prop_eq_self
# Loading theorem Profinite.NobelingProof.proj_comp_of_subset
# Loading theorem Profinite.NobelingProof.proj_eq_of_subset
# Loading theorem Profinite.NobelingProof.projRestricts_eq_id
# Loading theorem Profinite.NobelingProof.projRestricts_eq_comp
# Loading theorem Profinite.NobelingProof.projRestricts_comp_projRestrict
# Loading theorem Profinite.NobelingProof.iso_map_bijective
# Loading theorem Profinite.NobelingProof.Products.lt_iff_lex_lt
# Loading theorem Profinite.NobelingProof.GoodProducts.injective
# Loading theorem Profinite.NobelingProof.GoodProducts.equiv_toFun_eq_eval
# Loading theorem Profinite.NobelingProof.GoodProducts.linearIndependent_iff_range
# Loading theorem Profinite.NobelingProof.Products.eval_eq
# Loading theorem Profinite.NobelingProof.Products.evalFacProp
# Loading theorem Profinite.NobelingProof.Products.evalFacProps
# Loading theorem Profinite.NobelingProof.Products.prop_of_isGood
# Loading theorem Profinite.NobelingProof.GoodProducts.span_iff_products
# Loading theorem Profinite.NobelingProof.eval_eq_πJ
# Loading theorem Profinite.NobelingProof.spanFinBasis.span
# Loading theorem Profinite.NobelingProof.list_prod_apply
# Loading theorem Profinite.NobelingProof.factors_prod_eq_basis_of_eq
# Loading theorem Profinite.NobelingProof.e_mem_of_eq_true
# Loading theorem Profinite.NobelingProof.one_sub_e_mem_of_false
# Loading theorem Profinite.NobelingProof.factors_prod_eq_basis_of_ne
# Loading theorem Profinite.NobelingProof.factors_prod_eq_basis
# Loading theorem Profinite.NobelingProof.GoodProducts.finsupp_sum_mem_span_eval
# Loading theorem Profinite.NobelingProof.GoodProducts.spanFin
# Loading theorem Profinite.NobelingProof.fin_comap_jointlySurjective
# Loading theorem Profinite.NobelingProof.GoodProducts.span
# Loading theorem Profinite.NobelingProof.term_ord_aux
# Loading theorem Profinite.NobelingProof.ord_term_aux
# Loading theorem Profinite.NobelingProof.ord_term
# Loading theorem Profinite.NobelingProof.Products.prop_of_isGood_of_contained
# Loading theorem Profinite.NobelingProof.GoodProducts.linearIndependentEmpty
# Loading theorem Profinite.NobelingProof.Products.lt_nil_empty
# Loading theorem Profinite.NobelingProof.Products.isGood_nil
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Algebra__Module__Submodule__IterateMapComap.lean.pkl
# Loading theorem LinearMap.iterateMapComap_le_succ
# Loading theorem LinearMap.iterateMapComap_eq_succ
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Order__Monotone__Extension.lean.pkl
# Loading theorem MonotoneOn.exists_monotone_extension
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Analysis__Calculus__Deriv__Support.lean.pkl
# Loading theorem support_deriv_subset
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__MeasureTheory__Measure__MeasureSpace.lean.pkl
# Loading theorem MeasureTheory.ae_uIoc_iff
# Loading theorem MeasureTheory.measure_diff_add_inter
# Loading theorem MeasureTheory.measure_union_add_inter
# Loading theorem MeasureTheory.measure_union_add_inter'
# Loading theorem MeasureTheory.measure_symmDiff_eq
# Loading theorem MeasureTheory.measure_biUnion₀
# Loading theorem MeasureTheory.measure_sUnion₀
# Loading theorem MeasureTheory.measure_sUnion
# Loading theorem MeasureTheory.measure_biUnion_finset₀
# Loading theorem MeasureTheory.tsum_meas_le_meas_iUnion_of_disjoint₀
# Loading theorem MeasureTheory.tsum_measure_preimage_singleton
# Loading theorem MeasureTheory.measure_preimage_eq_zero_iff_of_countable
# Loading theorem MeasureTheory.sum_measure_preimage_singleton
# Loading theorem MeasureTheory.measure_diff_null'
# Loading theorem MeasureTheory.measure_add_diff
# Loading theorem MeasureTheory.measure_diff
# Loading theorem MeasureTheory.measure_eq_top_iff_of_symmDiff
# Loading theorem MeasureTheory.measure_diff_lt_of_lt_add
# Loading theorem MeasureTheory.measure_diff_le_iff_le_add
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__CategoryTheory__Limits__Constructions__Filtered.lean.pkl
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Data__Set__Equitable.lean.pkl
# Loading theorem Set.equitableOn_empty
# Loading theorem Set.equitableOn_iff_exists_le_le_add_one
# Loading theorem Set.equitableOn_iff_exists_image_subset_icc
# Loading theorem Set.equitableOn_iff_exists_eq_eq_add_one
# Loading theorem Set.not_equitableOn
# Loading theorem Finset.equitableOn_iff_le_le_add_one
# Loading theorem Finset.equitableOn_iff
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Analysis__Analytic__Inverse.lean.pkl
# Loading theorem FormalMultilinearSeries.leftInv_coeff_zero
# Loading theorem FormalMultilinearSeries.leftInv_coeff_one
# Loading theorem FormalMultilinearSeries.leftInv_removeZero
# Loading theorem FormalMultilinearSeries.leftInv_comp
# Loading theorem FormalMultilinearSeries.rightInv_coeff_zero
# Loading theorem FormalMultilinearSeries.rightInv_coeff_one
# Loading theorem FormalMultilinearSeries.rightInv_removeZero
# Loading theorem FormalMultilinearSeries.comp_rightInv_aux1
# Loading theorem FormalMultilinearSeries.comp_rightInv_aux2
# Loading theorem FormalMultilinearSeries.comp_rightInv
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__MeasureTheory__Integral__LebesgueNormedSpace.lean.pkl
# Loading theorem aemeasurable_withDensity_iff
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Data__Finset__Sort.lean.pkl
# Loading theorem Finset.sort_nodup
# Loading theorem Finset.sort_empty
# Loading theorem Finset.sort_perm_toList
# Loading theorem Finset.sorted_zero_eq_min'_aux
# Loading theorem Finset.min'_eq_sorted_zero
# Loading theorem Finset.sorted_last_eq_max'_aux
# Loading theorem Finset.coe_orderIsoOfFin_apply
# Loading theorem Finset.orderIsoOfFin_symm_apply
# Loading theorem Finset.orderEmbOfFin_apply
# Loading theorem Finset.range_orderEmbOfFin
# Loading theorem Finset.orderEmbOfFin_zero
# Loading theorem Finset.orderEmbOfFin_last
# Loading theorem Finset.orderEmbOfFin_singleton
# Loading theorem Finset.orderEmbOfFin_unique
# Loading theorem Finset.orderEmbOfFin_eq_orderEmbOfFin_iff
# Loading theorem Finset.orderEmbOfCardLe_mem
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__NumberTheory__RamificationInertia.lean.pkl
# Loading theorem Ideal.ramificationIdx_spec
# Loading theorem Ideal.ramificationIdx_lt
# Loading theorem Ideal.ramificationIdx_ne_zero
# Loading theorem Ideal.le_pow_of_le_ramificationIdx
# Loading theorem Ideal.IsDedekindDomain.ramificationIdx_eq_normalizedFactors_count
# Loading theorem Ideal.IsDedekindDomain.ramificationIdx_eq_factors_count
# Loading theorem Ideal.IsDedekindDomain.ramificationIdx_ne_zero
# Loading theorem Ideal.inertiaDeg_of_subsingleton
# Loading theorem Ideal.inertiaDeg_algebraMap
# Loading theorem Ideal.FinrankQuotientMap.linearIndependent_of_nontrivial
# Loading theorem Ideal.FinrankQuotientMap.span_eq_top
# Loading theorem Ideal.finrank_quotient_map
# Loading theorem Ideal.Quotient.algebraMap_quotient_pow_ramificationIdx
# Loading theorem Ideal.Quotient.algebraMap_quotient_of_ramificationIdx_neZero
# Loading theorem Ideal.powQuotSuccInclusion_injective
# Loading theorem Ideal.quotientToQuotientRangePowQuotSuccAux_mk
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__RingTheory__Bezout.lean.pkl
# Loading theorem IsBezout.iff_span_pair_isPrincipal
# Loading theorem Function.Surjective.isBezout
# Loading theorem IsBezout.TFAE
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__AlgebraicGeometry__Restrict.lean.pkl
# Loading theorem AlgebraicGeometry.Scheme.ofRestrict_val_c_app_self
# Loading theorem AlgebraicGeometry.Scheme.eq_restrict_presheaf_map_eqToHom
# Loading theorem AlgebraicGeometry.Scheme.map_basicOpen'
# Loading theorem AlgebraicGeometry.Scheme.map_basicOpen
# Loading theorem AlgebraicGeometry.Scheme.map_basicOpen_map
# Loading theorem AlgebraicGeometry.Scheme.restrictFunctor_obj_left
# Loading theorem AlgebraicGeometry.Scheme.restrictFunctor_obj_hom
# Loading theorem AlgebraicGeometry.Scheme.restrictFunctor_map_left
# Loading theorem AlgebraicGeometry.Scheme.restrictFunctor_map_ofRestrict
# Loading theorem AlgebraicGeometry.Scheme.restrictFunctor_map_base
# Loading theorem AlgebraicGeometry.Scheme.restrictFunctor_map_app_aux
# Loading theorem AlgebraicGeometry.pullbackRestrictIsoRestrict_inv_fst
# Loading theorem AlgebraicGeometry.pullbackRestrictIsoRestrict_hom_restrict
# Loading theorem AlgebraicGeometry.morphismRestrict_ι
# Loading theorem AlgebraicGeometry.isPullback_morphismRestrict
# Loading theorem AlgebraicGeometry.morphismRestrict_comp
# Loading theorem AlgebraicGeometry.image_morphismRestrict_preimage
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Algebra__Module__Submodule__Map.lean.pkl
# Loading theorem Submodule.map_coe
# Loading theorem Submodule.map_toAddSubmonoid
# Loading theorem Submodule.map_toAddSubmonoid'
# Loading theorem AddMonoidHom.coe_toIntLinearMap_map
# Loading theorem MonoidHom.coe_toAdditive_map
# Loading theorem AddMonoidHom.coe_toMultiplicative_map
# Loading theorem Submodule.mem_map
# Loading theorem Submodule.mem_map_of_mem
# Loading theorem Submodule.apply_coe_mem_map
# Loading theorem Submodule.map_id
# Loading theorem Submodule.map_comp
# Loading theorem Submodule.map_mono
# Loading theorem Submodule.map_zero
# Loading theorem Submodule.map_add_le
# Loading theorem Submodule.map_inf_le
# Loading theorem Submodule.range_map_nonempty
# Loading theorem Submodule.coe_equivMapOfInjective_apply
# Loading theorem Submodule.map_equivMapOfInjective_symm_apply
# Loading theorem Submodule.comap_coe
# Loading theorem Submodule.AddMonoidHom.coe_toIntLinearMap_comap
# Loading theorem Submodule.mem_comap
# Loading theorem Submodule.comap_id
# Loading theorem Submodule.comap_comp
# Loading theorem Submodule.comap_mono
# Loading theorem Submodule.le_comap_pow_of_le_comap
# Loading theorem Submodule.map_le_iff_le_comap
# Loading theorem Submodule.map_bot
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__CategoryTheory__IsConnected.lean.pkl
# Loading theorem CategoryTheory.any_functor_const_on_obj
# Loading theorem CategoryTheory.constant_of_preserves_morphisms
# Loading theorem CategoryTheory.induct_on_objects
# Loading theorem CategoryTheory.Zag.symm
# Loading theorem CategoryTheory.Zag.of_hom
# Loading theorem CategoryTheory.Zag.of_inv
# Loading theorem CategoryTheory.Zigzag.refl
# Loading theorem CategoryTheory.Zigzag.of_zag
# Loading theorem CategoryTheory.Zigzag.of_hom
# Loading theorem CategoryTheory.Zigzag.of_inv
# Loading theorem CategoryTheory.Zigzag.of_hom_hom
# Loading theorem CategoryTheory.Zigzag.of_hom_inv
# Loading theorem CategoryTheory.Zigzag.of_inv_hom
# Loading theorem CategoryTheory.Zigzag.of_inv_inv
# Loading theorem CategoryTheory.equiv_relation
# Loading theorem CategoryTheory.zigzag_isPreconnected
# Loading theorem CategoryTheory.isPreconnected_of_zigzag
# Loading theorem CategoryTheory.nonempty_hom_of_preconnected_groupoid
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Init__Meta__WellFoundedTactics.lean.pkl
# Loading theorem Nat.lt_add_of_zero_lt_left
# Loading theorem Nat.zero_lt_one_add
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__LinearAlgebra__Projection.lean.pkl
# Loading theorem LinearMap.ker_id_sub_eq_of_proj
# Loading theorem LinearMap.range_eq_of_proj
# Loading theorem LinearMap.isCompl_of_proj
# Loading theorem Submodule.quotientEquivOfIsCompl_symm_apply
# Loading theorem Submodule.coe_prodEquivOfIsCompl
# Loading theorem Submodule.coe_prodEquivOfIsCompl'
# Loading theorem Submodule.prodEquivOfIsCompl_symm_apply_fst_eq_zero
# Loading theorem Submodule.prodEquivOfIsCompl_symm_apply_snd_eq_zero
# Loading theorem Submodule.prodComm_trans_prodEquivOfIsCompl
# Loading theorem Submodule.linearProjOfIsCompl_apply_left
# Loading theorem Submodule.linearProjOfIsCompl_apply_eq_zero_iff
# Loading theorem Submodule.linearProjOfIsCompl_apply_right'
# Loading theorem Submodule.linearProjOfIsCompl_apply_right
# Loading theorem Submodule.linearProjOfIsCompl_ker
# Loading theorem Submodule.linearProjOfIsCompl_comp_subtype
# Loading theorem Submodule.linearProjOfIsCompl_idempotent
# Loading theorem Submodule.linear_proj_add_linearProjOfIsCompl_eq_self
# Loading theorem LinearMap.ofIsCompl_left_apply
# Loading theorem LinearMap.ofIsCompl_right_apply
# Loading theorem LinearMap.ofIsCompl_eq
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__CategoryTheory__Monoidal__CommMon_.lean.pkl
# Loading theorem CommMon_.id_hom
# Loading theorem CommMon_.comp_hom
# Loading theorem CommMon_.hom_ext
# Loading theorem CommMon_.id'
# Loading theorem CommMon_.comp'
# Loading theorem CommMon_.forget₂_Mon_obj_one
# Loading theorem CommMon_.forget₂_Mon_obj_mul
# Loading theorem CommMon_.forget₂_Mon_map_hom
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__RingTheory__RootsOfUnity__Basic.lean.pkl
# Loading theorem mem_rootsOfUnity
# Loading theorem mem_rootsOfUnity'
# Loading theorem rootsOfUnity_one
# Loading theorem rootsOfUnity.coe_injective
# Loading theorem rootsOfUnity.coe_mkOfPowEq
# Loading theorem rootsOfUnity_le_of_dvd
# Loading theorem map_rootsOfUnity
# Loading theorem rootsOfUnity.coe_pow
# Loading theorem restrictRootsOfUnity_coe_apply
# Loading theorem MulEquiv.restrictRootsOfUnity_coe_apply
# Loading theorem MulEquiv.restrictRootsOfUnity_symm
# Loading theorem mem_rootsOfUnity_iff_mem_nthRoots
# Loading theorem rootsOfUnityEquivNthRoots_apply
# Loading theorem rootsOfUnityEquivNthRoots_symm_apply
# Loading theorem map_rootsOfUnity_eq_pow_self
# Loading theorem mem_rootsOfUnity_prime_pow_mul_iff
# Loading theorem mem_rootsOfUnity_prime_pow_mul_iff'
# Loading theorem mem_primitiveRoots
# Loading theorem primitiveRoots_zero
# Loading theorem isPrimitiveRoot_of_mem_primitiveRoots
# Loading theorem IsPrimitiveRoot.mk_of_lt
# Loading theorem IsPrimitiveRoot.of_subsingleton
# Loading theorem IsPrimitiveRoot.isUnit
# Loading theorem IsPrimitiveRoot.pow_inj
# Loading theorem IsPrimitiveRoot.one
# Loading theorem IsPrimitiveRoot.one_right_iff
# Loading theorem IsPrimitiveRoot.coe_submonoidClass_iff
# Loading theorem IsPrimitiveRoot.coe_units_iff
# Loading theorem IsPrimitiveRoot.pow_of_coprime
# Loading theorem IsPrimitiveRoot.pow_iff_coprime
# Loading theorem IsPrimitiveRoot.orderOf
# Loading theorem IsPrimitiveRoot.iff
# Loading theorem IsPrimitiveRoot.pow_mul_pow_lcm
# Loading theorem IsPrimitiveRoot.pow_of_dvd
# Loading theorem IsPrimitiveRoot.mem_rootsOfUnity
# Loading theorem IsPrimitiveRoot.pow
# Loading theorem IsPrimitiveRoot.injOn_pow
# Loading theorem IsPrimitiveRoot.map_iff_of_injective
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Combinatorics__SimpleGraph__Operations.lean.pkl
# Loading theorem SimpleGraph.Iso.card_edgeFinset_eq
# Loading theorem SimpleGraph.not_adj_replaceVertex_same
# Loading theorem SimpleGraph.replaceVertex_self
# Loading theorem SimpleGraph.adj_replaceVertex_iff_of_ne_left
# Loading theorem SimpleGraph.adj_replaceVertex_iff_of_ne_right
# Loading theorem SimpleGraph.adj_replaceVertex_iff_of_ne
# Loading theorem SimpleGraph.edgeSet_replaceVertex_of_not_adj
# Loading theorem SimpleGraph.edgeSet_replaceVertex_of_adj
# Loading theorem SimpleGraph.edgeFinset_replaceVertex_of_not_adj
# Loading theorem SimpleGraph.edgeFinset_replaceVertex_of_adj
# Loading theorem SimpleGraph.disjoint_sdiff_neighborFinset_image
# Loading theorem SimpleGraph.card_edgeFinset_replaceVertex_of_not_adj
# Loading theorem SimpleGraph.card_edgeFinset_replaceVertex_of_adj
# Loading theorem SimpleGraph.edge_adj
# Loading theorem SimpleGraph.edge_self_eq_bot
# Loading theorem SimpleGraph.sup_edge_self
# Loading theorem SimpleGraph.edge_edgeSet_of_ne
# Loading theorem SimpleGraph.sup_edge_of_adj
# Loading theorem SimpleGraph.card_edgeFinset_sup_edge
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__MeasureTheory__Function__ConditionalExpectation__CondexpL2.lean.pkl
# Loading theorem MeasureTheory.snorm_condexpL2_le
# Loading theorem MeasureTheory.norm_condexpL2_coe_le
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__NumberTheory__Zsqrtd__Basic.lean.pkl
# Loading theorem Zsqrtd.ofInt_re
# Loading theorem Zsqrtd.ofInt_im
# Loading theorem Zsqrtd.zero_re
# Loading theorem Zsqrtd.zero_im
# Loading theorem Zsqrtd.one_re
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Algebra__Category__MonCat__Basic.lean.pkl
# Loading theorem MonCat.coe_id
# Loading theorem MonCat.coe_comp
# Loading theorem MonCat.forget_map
# Loading theorem MonCat.ext
# Loading theorem MonCat.coe_of
# Loading theorem MonCat.ofHom_apply
# Loading theorem MonCat.oneHom_apply
# Loading theorem MonCat.one_of
# Loading theorem MonCat.mul_of
# Loading theorem CommMonCat.coe_id
# Loading theorem CommMonCat.coe_comp
# Loading theorem CommMonCat.forget_map
# Loading theorem CommMonCat.ext
# Loading theorem CommMonCat.coe_of
# Loading theorem CommMonCat.ofHom_apply
# Loading theorem MonoidHom.comp_id_monCat
# Loading theorem MonoidHom.id_monCat_comp
# Loading theorem MonoidHom.comp_id_commMonCat
# Loading theorem MonoidHom.id_commMonCat_comp
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__RingTheory__Ideal__Quotient.lean.pkl
# Loading theorem Ideal.Quotient.mk_eq_mk
# Loading theorem Ideal.Quotient.eq_zero_iff_mem
# Loading theorem Ideal.Quotient.eq_zero_iff_dvd
# Loading theorem Ideal.Quotient.mk_singleton_self
# Loading theorem Ideal.Quotient.mk_eq_mk_iff_sub_mem
# Loading theorem Ideal.Quotient.zero_eq_one_iff
# Loading theorem Ideal.Quotient.subsingleton_iff
# Loading theorem Ideal.Quotient.mk_surjective
# Loading theorem Ideal.Quotient.quotient_ring_saturate
# Loading theorem Ideal.Quotient.isDomain_iff_prime
# Loading theorem Ideal.Quotient.exists_inv
# Loading theorem Ideal.Quotient.maximal_of_isField
# Loading theorem Ideal.Quotient.lift_mk
# Loading theorem Ideal.Quotient.lift_surjective_of_surjective
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/.lake__packages__batteries__Batteries__Data__ByteArray.lean.pkl
# Loading theorem ByteArray.getElem_eq_data_getElem
# Loading theorem ByteArray.uset_eq_set
# Loading theorem ByteArray.mkEmpty_data
# Loading theorem ByteArray.empty_data
# Loading theorem ByteArray.size_empty
# Loading theorem ByteArray.push_data
# Loading theorem ByteArray.size_push
# Loading theorem ByteArray.set_data
# Loading theorem ByteArray.size_set
# Loading theorem ByteArray.get_set_eq
# Loading theorem ByteArray.copySlice_data
# Loading theorem ByteArray.append_eq
# Loading theorem ByteArray.append_data
# Loading theorem ByteArray.size_append
# Loading theorem ByteArray.get_append_left
# Loading theorem ByteArray.get_append_right
# Loading theorem ByteArray.extract_data
# Loading theorem ByteArray.size_extract
# Loading theorem ByteArray.get_extract_aux
# Loading theorem ByteArray.get_extract
# Loading theorem ByteArray.ofFn_data
# Loading theorem ByteArray.size_ofFn
# Loading theorem ByteArray.get_ofFn
# Loading theorem ByteArray.getElem_ofFn
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Algebra__Category__ModuleCat__Presheaf__Pushforward.lean.pkl
# Loading theorem PresheafOfModules.pushforward_obj_obj
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__LinearAlgebra__GeneralLinearGroup.lean.pkl
# Loading theorem LinearMap.GeneralLinearGroup.generalLinearEquiv_to_linearMap
# Loading theorem LinearMap.GeneralLinearGroup.coeFn_generalLinearEquiv
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__RingTheory__QuotientNilpotent.lean.pkl
# Loading theorem Ideal.isRadical_iff_quotient_reduced
# Loading theorem Ideal.IsNilpotent.induction_on
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Data__List__Sublists.lean.pkl
# Loading theorem List.sublists'_nil
# Loading theorem List.sublists'_singleton
# Loading theorem List.sublists'Aux_eq_array_foldl
# Loading theorem List.sublists'_eq_sublists'Aux
# Loading theorem List.sublists'_cons
# Loading theorem List.mem_sublists'
# Loading theorem List.sublists_nil
# Loading theorem List.sublists_singleton
# Loading theorem List.sublistsAux_eq_array_foldl
# Loading theorem List.sublists_eq_sublistsFast
# Loading theorem List.sublists_append
# Loading theorem List.sublists_cons
# Loading theorem List.sublists_concat
# Loading theorem List.sublists_reverse
# Loading theorem List.sublists_eq_sublists'
# Loading theorem List.sublists'_reverse
# Loading theorem List.sublists'_eq_sublists
# Loading theorem List.mem_sublists
# Loading theorem List.length_sublists
# Loading theorem List.map_pure_sublist_sublists
# Loading theorem List.sublistsLenAux_eq
# Loading theorem List.sublistsLenAux_zero
# Loading theorem List.sublistsLen_succ_nil
# Loading theorem List.sublistsLen_succ_cons
# Loading theorem List.sublistsLen_sublist_of_sublist
# Loading theorem List.mem_sublistsLen_self
# Loading theorem List.pairwise_sublists
# Loading theorem List.nodup_sublists'
# Loading theorem List.nodup_sublistsLen
# Loading theorem List.sublists_perm_sublists'
# Loading theorem List.revzip_sublists
# Loading theorem List.revzip_sublists'
# Loading theorem List.range_bind_sublistsLen_perm
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Geometry__Manifold__Algebra__Structures.lean.pkl
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Topology__MetricSpace__Infsep.lean.pkl
# Loading theorem Set.le_einfsep_iff
# Loading theorem Set.einfsep_zero
# Loading theorem Set.einfsep_pos
# Loading theorem Set.einfsep_top
# Loading theorem Set.einfsep_lt_top
# Loading theorem Set.einfsep_ne_top
# Loading theorem Set.einfsep_lt_iff
# Loading theorem Set.nontrivial_of_einfsep_lt_top
# Loading theorem Set.Subsingleton.einfsep
# Loading theorem Set.le_einfsep_image_iff
# Loading theorem Set.einfsep_iUnion_mem_option
# Loading theorem Set.einfsep_insert_le
# Loading theorem Set.le_einfsep_pair
# Loading theorem Set.einfsep_pair_le_right
# Loading theorem Set.einfsep_eq_iInf
# Loading theorem Set.einfsep_of_fintype
# Loading theorem Set.Finite.einfsep
# Loading theorem Set.Finset.coe_einfsep
# Loading theorem Set.Nontrivial.einfsep_exists_of_finite
# Loading theorem Set.einfsep_pair
# Loading theorem Set.einfsep_insert
# Loading theorem Set.einfsep_triple
# Loading theorem Set.le_einfsep_pi_of_le
# Loading theorem Set.subsingleton_of_einfsep_eq_top
# Loading theorem Set.Nontrivial.einfsep_ne_top
# Loading theorem Set.Nontrivial.einfsep_lt_top
# Loading theorem Set.einfsep_pos_of_finite
# Loading theorem Set.relatively_discrete_of_finite
# Loading theorem Set.infsep_zero
# Loading theorem Set.infsep_pos
# Loading theorem Set.nontrivial_of_infsep_pos
# Loading theorem Set.infsep_pair_le_toReal_inf
# Loading theorem Set.infsep_pair_eq_toReal
# Loading theorem Set.Nontrivial.le_infsep_iff
# Loading theorem Set.Nontrivial.infsep_lt_iff
# Loading theorem Set.le_edist_of_le_infsep
# Loading theorem Set.infsep_pair
# Loading theorem Set.infsep_triple
# Loading theorem Set.infsep_eq_iInf
# Loading theorem Set.Nontrivial.infsep_eq_iInf
# Loading theorem Finset.coe_infsep
# Loading theorem Finset.coe_infsep_of_offDiag_nonempty
# Loading theorem Finset.coe_infsep_of_offDiag_empty
# Loading theorem Set.Nontrivial.infsep_exists_of_finite
# Loading theorem Set.infsep_zero_iff_subsingleton_of_finite
# Loading theorem Set.infsep_pos_iff_nontrivial_of_finite
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__MeasureTheory__Measure__Lebesgue__VolumeOfBalls.lean.pkl
# Loading theorem MeasureTheory.measure_unitBall_eq_integral_div_gamma
# Loading theorem MeasureTheory.measure_le_eq_lt
# Loading theorem MeasureTheory.volume_sum_rpow_lt_one
# Loading theorem MeasureTheory.volume_sum_rpow_lt
# Loading theorem MeasureTheory.volume_sum_rpow_le
# Loading theorem Complex.volume_sum_rpow_lt_one
# Loading theorem Complex.volume_sum_rpow_lt
# Loading theorem Complex.volume_sum_rpow_le
# Loading theorem EuclideanSpace.volume_ball
# Loading theorem EuclideanSpace.volume_closedBall
# Loading theorem InnerProductSpace.volume_ball
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Analysis__Normed__Group__SemiNormedGroupCat__Completion.lean.pkl
# Loading theorem SemiNormedGroupCat.completion.norm_incl_eq
# Loading theorem SemiNormedGroupCat.completion.map_zero
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__RingTheory__Prime.lean.pkl
# Loading theorem mul_eq_mul_prime_prod
# Loading theorem mul_eq_mul_prime_pow
# Loading theorem Prime.neg
# Loading theorem Prime.abs
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Algebra__Homology__ImageToKernel.lean.pkl
# Loading theorem subobject_ofLE_as_imageToKernel
# Loading theorem imageToKernel_arrow
# Loading theorem imageToKernel_arrow_apply
# Loading theorem factorThruImageSubobject_comp_imageToKernel
# Loading theorem imageToKernel_zero_left
# Loading theorem imageToKernel_zero_right
# Loading theorem imageToKernel_comp_right
# Loading theorem imageToKernel_comp_left
# Loading theorem imageToKernel_comp_mono
# Loading theorem imageToKernel_epi_comp
# Loading theorem imageToKernel_comp_hom_inv_comp
# Loading theorem homology'.π_desc
# Loading theorem imageSubobjectMap_comp_imageToKernel
# Loading theorem homology'.π_map
# Loading theorem homology'.π_map_apply
# Loading theorem homology'.map_desc
# Loading theorem homology'.map_id
# Loading theorem homology'.comp_right_eq_comp_left
# Loading theorem homology'.map_comp
# Loading theorem imageSubobjectIso_imageToKernel'
# Loading theorem imageToKernel'_kernelSubobjectIso
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__CategoryTheory__Iso.lean.pkl
# Loading theorem CategoryTheory.Iso.symm_hom
# Loading theorem CategoryTheory.Iso.symm_inv
# Loading theorem CategoryTheory.Iso.symm_mk
# Loading theorem CategoryTheory.Iso.symm_symm_eq
# Loading theorem CategoryTheory.Iso.symm_eq_iff
# Loading theorem CategoryTheory.Iso.nonempty_iso_symm
# Loading theorem CategoryTheory.Iso.nonempty_iso_refl
# Loading theorem CategoryTheory.Iso.refl_symm
# Loading theorem CategoryTheory.Iso.trans_mk
# Loading theorem CategoryTheory.Iso.trans_symm
# Loading theorem CategoryTheory.Iso.trans_assoc
# Loading theorem CategoryTheory.Iso.refl_trans
# Loading theorem CategoryTheory.Iso.trans_refl
# Loading theorem CategoryTheory.Iso.symm_self_id
# Loading theorem CategoryTheory.Iso.self_symm_id
# Loading theorem CategoryTheory.Iso.symm_self_id_assoc
# Loading theorem CategoryTheory.Iso.self_symm_id_assoc
# Loading theorem CategoryTheory.Iso.inv_comp_eq
# Loading theorem CategoryTheory.Iso.eq_inv_comp
# Loading theorem CategoryTheory.Iso.comp_inv_eq
# Loading theorem CategoryTheory.Iso.eq_comp_inv
# Loading theorem CategoryTheory.Iso.hom_comp_eq_id
# Loading theorem CategoryTheory.Iso.comp_hom_eq_id
# Loading theorem CategoryTheory.Iso.comp_inv_eq_id
# Loading theorem CategoryTheory.Iso.hom_eq_inv
# Loading theorem CategoryTheory.IsIso.hom_inv_id_assoc
# Loading theorem CategoryTheory.IsIso.inv_hom_id_assoc
# Loading theorem CategoryTheory.Iso.isIso_hom
# Loading theorem CategoryTheory.Iso.isIso_inv
# Loading theorem CategoryTheory.asIso_hom
# Loading theorem CategoryTheory.asIso_inv
# Loading theorem CategoryTheory.IsIso.inv_eq_of_hom_inv_id
# Loading theorem CategoryTheory.IsIso.inv_eq_of_inv_hom_id
# Loading theorem CategoryTheory.IsIso.eq_inv_of_hom_inv_id
# Loading theorem CategoryTheory.IsIso.eq_inv_of_inv_hom_id
# Loading theorem CategoryTheory.IsIso.inv_id
# Loading theorem CategoryTheory.IsIso.inv_comp
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__NumberTheory__Zsqrtd__QuadraticReciprocity.lean.pkl
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240621/Mathlib__Analysis__SpecialFunctions__Gamma__Basic.lean.pkl
# Loading theorem Real.Gamma_integrand_isLittleO
# Loading theorem Real.GammaIntegral_convergent
# Loading theorem Complex.GammaIntegral_convergent
# Loading theorem Complex.GammaIntegral_conj
# Loading theorem Complex.GammaIntegral_one
# ...
# Loading theorem csInf_univ
# Loading theorem isLUB_csSup'
# Loading theorem le_ciSup_iff'
# Loading theorem csInf_le'
# Loading theorem ciInf_le'
# Loading theorem exists_lt_of_lt_csSup'
# Loading theorem exists_lt_of_lt_ciSup'
# Loading theorem WithTop.isLUB_sSup'
# Loading theorem WithTop.isLUB_sSup
# Loading theorem WithTop.isGLB_sInf'
# Loading theorem WithTop.isGLB_sInf
# Loading theorem WithTop.coe_sSup
# Loading theorem WithTop.coe_sInf
# Loading theorem Monotone.csInf_image_le
# Loading theorem Monotone.le_csInf_image
# Loading theorem GaloisConnection.l_csSup'
# Loading theorem GaloisConnection.l_ciSup
# Loading theorem GaloisConnection.l_ciSup_set
# Loading theorem csSup_image2_eq_csSup_csSup
# Loading theorem WithTop.iSup_coe_eq_top
# Loading theorem WithTop.iInf_coe_eq_top
# Loading theorem WithTop.iInf_coe_lt_top
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240623/Mathlib__Topology__MetricSpace__Antilipschitz.lean.pkl
# Loading theorem antilipschitzWith_iff_le_mul_nndist
# Loading theorem antilipschitzWith_iff_le_mul_dist
# Loading theorem AntilipschitzWith.mul_le_nndist
# Loading theorem AntilipschitzWith.mul_le_edist
# Loading theorem AntilipschitzWith.id
# Loading theorem AntilipschitzWith.restrict
# Loading theorem AntilipschitzWith.codRestrict
# Loading theorem AntilipschitzWith.to_rightInverse
# Loading theorem AntilipschitzWith.comap_uniformity_le
# Loading theorem AntilipschitzWith.subtype_coe
# Loading theorem AntilipschitzWith.properSpace
# Loading theorem AntilipschitzWith.isBounded_of_image2_left
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240623/Mathlib__Order__Extension__Linear.lean.pkl
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240623/Mathlib__Order__Estimator.lean.pkl
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240623/Mathlib__Algebra__Order__Monoid__ToMulBot.lean.pkl
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240623/Mathlib__Data__Finset__Pointwise.lean.pkl
# Loading theorem Finset.preimage_mul_left_one'
# Loading theorem Finset.preimage_mul_right_one'
# Loading theorem Finset.smul_def
# Loading theorem Finset.image_smul_product
# Loading theorem Finset.smul_mem_smul
# Loading theorem Finset.empty_smul
# Loading theorem Finset.smul_empty
# Loading theorem Finset.smul_eq_empty
# Loading theorem Finset.smul_nonempty_iff
# Loading theorem Finset.Nonempty.smul
# Loading theorem Finset.Nonempty.of_smul_left
# Loading theorem Finset.Nonempty.of_smul_right
# Loading theorem Finset.smul_singleton
# Loading theorem Finset.singleton_smul_singleton
# Loading theorem Finset.vsub_def
# Loading theorem Finset.image_vsub_product
# Loading theorem Finset.vsub_card_le
# Loading theorem Finset.empty_vsub
# Loading theorem Finset.vsub_empty
# Loading theorem Finset.vsub_eq_empty
# Loading theorem Finset.vsub_nonempty
# Loading theorem Finset.Nonempty.vsub
# Loading theorem Finset.Nonempty.of_vsub_left
# Loading theorem Finset.Nonempty.of_vsub_right
# Loading theorem Finset.vsub_singleton
# Loading theorem Finset.singleton_vsub
# Loading theorem Finset.singleton_vsub_singleton
# Loading theorem Finset.smul_finset_def
# Loading theorem Finset.image_smul
# Loading theorem Finset.mem_smul_finset
# Loading theorem Finset.smul_finset_card_le
# Loading theorem Finset.smul_finset_empty
# Loading theorem Finset.smul_finset_eq_empty
# Loading theorem Finset.Nonempty.smul_finset
# Loading theorem Finset.singleton_smul
# Loading theorem Finset.smul_finset_singleton
# Loading theorem Finset.op_smul_finset_smul_eq_smul_smul_finset
# Loading theorem Finset.pairwiseDisjoint_smul_iff
# Loading theorem Finset.singleton_mul_inter
# Loading theorem Finset.inter_mul_singleton
# Loading theorem Finset.image_smul_comm
# Loading theorem Finset.image_smul_distrib
# Loading theorem Finset.smul_mem_smul_finset_iff
# Loading theorem Finset.inv_smul_mem_iff
# Loading theorem Finset.mem_inv_smul_finset_iff
# Loading theorem Finset.smul_finset_subset_smul_finset_iff
# Loading theorem Finset.smul_finset_subset_iff
# Loading theorem Finset.subset_smul_finset_iff
# Loading theorem Finset.smul_finset_univ
# Loading theorem Finset.smul_univ
# Loading theorem Finset.inv_smul_finset_distrib
# Loading theorem Finset.inv_op_smul_finset_distrib
# Loading theorem Finset.smul_zero_subset
# Loading theorem Finset.zero_mem_smul_finset
# Loading theorem Finset.zero_mem_smul_finset_iff
# Loading theorem Finset.zero_smul_subset
# Loading theorem Finset.zero_smul_finset
# Loading theorem Finset.zero_smul_finset_subset
# Loading theorem Finset.zero_mem_smul_iff
# Loading theorem Finset.smul_mem_smul_finset_iff₀
# Loading theorem Finset.smul_finset_subset_smul_finset_iff₀
# Loading theorem Finset.inv_zero
# Loading theorem Finset.inv_smul_finset_distrib₀
# Loading theorem Finset.inv_op_smul_finset_distrib₀
# Loading theorem Finset.smul_finset_neg
# Loading theorem Finset.smul_neg
# Loading theorem Finset.neg_smul_finset
# Loading theorem Finset.neg_smul
# Loading theorem Finset.prod_inv_index
# Loading theorem Finset.prod_neg_index
# Loading theorem Set.toFinset_one
# Loading theorem Set.Finite.toFinset_one
# Loading theorem Set.toFinset_mul
# Loading theorem Set.Finite.toFinset_mul
# Loading theorem Set.toFinset_smul
# Loading theorem Set.Finite.toFinset_smul
# Loading theorem Set.toFinset_smul_set
# Loading theorem Set.Finite.toFinset_smul_set
# Loading theorem Set.toFinset_vsub
# Loading theorem Set.card_mul_le
# Loading theorem Set.card_inv
# Loading theorem Set.card_div_le
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240623/Mathlib__Order__MinMax.lean.pkl
# Loading theorem max_lt_max
# Loading theorem min_lt_min
# Loading theorem min_right_comm
# Loading theorem Max.right_comm
# Loading theorem Monotone.map_max
# Loading theorem Antitone.map_max
# Loading theorem min_choice
# Loading theorem le_of_max_le_left
# Loading theorem le_of_max_le_right
# Loading theorem max_commutative
# Loading theorem max_associative
# Loading theorem min_commutative
# Loading theorem min_associative
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240623/Mathlib__CategoryTheory__Limits__Preserves__Shapes__Equalizers.lean.pkl
# Loading theorem CategoryTheory.Limits.PreservesEqualizer.iso_hom
# Loading theorem CategoryTheory.Limits.PreservesEqualizer.iso_inv_ι
# Loading theorem CategoryTheory.Limits.PreservesCoequalizer.iso_hom
# Loading theorem CategoryTheory.Limits.map_π_preserves_coequalizer_inv
# Loading theorem CategoryTheory.Limits.map_π_preserves_coequalizer_inv_desc
# Loading theorem CategoryTheory.Limits.map_π_preserves_coequalizer_inv_colimMap
# Loading theorem CategoryTheory.Limits.map_π_preserves_coequalizer_inv_colimMap_desc
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240623/Mathlib__CategoryTheory__Preadditive__HomOrthogonal.lean.pkl
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240623/.lake__packages__lean4__src__lean__Init__Control__ExceptCps.lean.pkl
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240623/Mathlib__NumberTheory__Harmonic__Int.lean.pkl
# Loading theorem padicValRat_two_harmonic
# Loading theorem padicNorm_two_harmonic
# Loading theorem harmonic_not_int
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240623/Mathlib__Order__Interval__Set__OrderEmbedding.lean.pkl
# Loading theorem OrderEmbedding.preimage_Ici
# Loading theorem OrderEmbedding.preimage_Iic
# Loading theorem OrderEmbedding.preimage_Ioi
# Loading theorem OrderEmbedding.preimage_Iio
# Loading theorem OrderEmbedding.preimage_Icc
# Loading theorem OrderEmbedding.preimage_Ico
# Loading theorem OrderEmbedding.preimage_Ioc
# Loading theorem OrderEmbedding.preimage_Ioo
# Loading theorem OrderEmbedding.preimage_uIcc
# Loading theorem OrderEmbedding.preimage_uIoc
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240623/Mathlib__ModelTheory__ElementaryMaps.lean.pkl
# Loading theorem FirstOrder.Language.ElementaryEmbedding.map_boundedFormula
# Loading theorem FirstOrder.Language.ElementaryEmbedding.map_formula
# Loading theorem FirstOrder.Language.ElementaryEmbedding.map_sentence
# Loading theorem FirstOrder.Language.ElementaryEmbedding.theory_model_iff
# Loading theorem FirstOrder.Language.ElementaryEmbedding.injective
# Loading theorem FirstOrder.Language.ElementaryEmbedding.map_fun
# Loading theorem FirstOrder.Language.ElementaryEmbedding.toEmbedding_toHom
# Loading theorem FirstOrder.Language.ElementaryEmbedding.coe_toHom
# Loading theorem FirstOrder.Language.ElementaryEmbedding.coe_toEmbedding
# Loading theorem FirstOrder.Language.ElementaryEmbedding.coe_injective
# Loading theorem FirstOrder.Language.ElementaryEmbedding.ext
# Loading theorem FirstOrder.Language.ElementaryEmbedding.ext_iff
# Loading theorem FirstOrder.Language.ElementaryEmbedding.refl_apply
# Loading theorem FirstOrder.Language.ElementaryEmbedding.comp_apply
# Loading theorem FirstOrder.Language.ElementaryEmbedding.comp_assoc
# Loading theorem FirstOrder.Language.Embedding.isElementary_of_exists
# Loading theorem FirstOrder.Language.Equiv.toElementaryEmbedding_toEmbedding
# Loading theorem FirstOrder.Language.Equiv.coe_toElementaryEmbedding
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240623/Mathlib__Data__Int__Associated.lean.pkl
# Loading theorem Int.natAbs_eq_iff_associated
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240623/Mathlib__Algebra__Order__Interval__Basic.lean.pkl
# Loading theorem NonemptyInterval.toProd_one
# Loading theorem NonemptyInterval.fst_one
# Loading theorem NonemptyInterval.snd_one
# Loading theorem NonemptyInterval.coe_one_interval
# Loading theorem NonemptyInterval.pure_one
# Loading theorem Interval.pure_one
# Loading theorem Interval.one_ne_bot
# Loading theorem Interval.bot_ne_one
# Loading theorem NonemptyInterval.one_mem_one
# Loading theorem Interval.one_mem_one
# Loading theorem NonemptyInterval.toProd_mul
# Loading theorem NonemptyInterval.fst_mul
# Loading theorem NonemptyInterval.snd_mul
# Loading theorem NonemptyInterval.coe_mul_interval
# Loading theorem NonemptyInterval.pure_mul_pure
# Loading theorem Interval.bot_mul
# Loading theorem Interval.mul_bot
# Loading theorem NonemptyInterval.toProd_pow
# Loading theorem NonemptyInterval.fst_pow
# Loading theorem NonemptyInterval.snd_pow
# Loading theorem NonemptyInterval.pure_pow
# Loading theorem NonemptyInterval.fst_sub
# Loading theorem NonemptyInterval.snd_sub
# Loading theorem NonemptyInterval.coe_sub_interval
# Loading theorem NonemptyInterval.pure_sub_pure
# Loading theorem Interval.bot_sub
# Loading theorem Interval.sub_bot
# Loading theorem NonemptyInterval.fst_div
# Loading theorem NonemptyInterval.snd_div
# Loading theorem NonemptyInterval.coe_div_interval
# Loading theorem NonemptyInterval.pure_div_pure
# Loading theorem Interval.bot_div
# Loading theorem Interval.div_bot
# Loading theorem NonemptyInterval.fst_inv
# Loading theorem NonemptyInterval.snd_inv
# Loading theorem NonemptyInterval.coe_inv_interval
# Loading theorem NonemptyInterval.inv_mem_inv
# Loading theorem NonemptyInterval.inv_pure
# Loading theorem Interval.inv_bot
# Loading theorem NonemptyInterval.mul_eq_one_iff
# Loading theorem Interval.mul_eq_one_iff
# Loading theorem NonemptyInterval.length_nonneg
# Loading theorem NonemptyInterval.length_pure
# Loading theorem NonemptyInterval.length_zero
# Loading theorem NonemptyInterval.length_neg
# Loading theorem NonemptyInterval.length_sub
# Loading theorem Interval.length_zero
# Loading theorem Interval.length_sub_le
# Loading theorem Interval.length_sum_le
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240623/Mathlib__CategoryTheory__Limits__KanExtension.lean.pkl
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240623/Mathlib__Analysis__Convex__Cone__Proper.lean.pkl
# Loading theorem ProperCone.toPointedCone_injective
# Loading theorem ProperCone.mem_coe
# Loading theorem ProperCone.mem_positive
# Loading theorem ProperCone.coe_positive
# Loading theorem ProperCone.mem_zero
# Loading theorem ProperCone.coe_zero
# Loading theorem ProperCone.pointed_zero
# Loading theorem ProperCone.pointed
# Loading theorem ProperCone.coe_map
# Loading theorem ProperCone.mem_map
# Loading theorem ProperCone.coe_dual
# Loading theorem ProperCone.mem_dual
# Loading theorem ProperCone.coe_comap
# Loading theorem ProperCone.comap_id
# Loading theorem ProperCone.comap_comap
# Loading theorem ProperCone.mem_comap
# Loading theorem ProperCone.hyperplane_separation_of_nmem
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240623/Mathlib__CategoryTheory__Limits__Final__ParallelPair.lean.pkl
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240623/Mathlib__Order__Hom__Bounded.lean.pkl
# Loading theorem map_eq_top_iff
# Loading theorem map_eq_bot_iff
# Loading theorem TopHom.ext
# Loading theorem TopHom.coe_copy
# Loading theorem TopHom.copy_eq
# Loading theorem TopHom.coe_id
# Loading theorem TopHom.id_apply
# Loading theorem TopHom.coe_comp
# Loading theorem TopHom.comp_apply
# Loading theorem TopHom.comp_assoc
# Loading theorem TopHom.comp_id
# Loading theorem TopHom.id_comp
# Loading theorem TopHom.cancel_left
# Loading theorem TopHom.coe_top
# Loading theorem TopHom.top_apply
# Loading theorem TopHom.coe_inf
# Loading theorem TopHom.inf_apply
# Loading theorem TopHom.coe_sup
# Loading theorem TopHom.sup_apply
# Loading theorem BotHom.ext
# Loading theorem BotHom.coe_copy
# Loading theorem BotHom.copy_eq
# Loading theorem BotHom.coe_id
# Loading theorem BotHom.id_apply
# Loading theorem BotHom.coe_comp
# Loading theorem BotHom.comp_apply
# Loading theorem BotHom.comp_assoc
# Loading theorem BotHom.comp_id
# Loading theorem BotHom.id_comp
# Loading theorem BotHom.cancel_right
# Loading theorem BotHom.cancel_left
# Loading theorem BotHom.coe_bot
# Loading theorem BotHom.bot_apply
# Loading theorem BotHom.coe_inf
# Loading theorem BotHom.inf_apply
# Loading theorem BotHom.coe_sup
# Loading theorem BotHom.sup_apply
# Loading theorem BoundedOrderHom.ext
# Loading theorem BoundedOrderHom.coe_copy
# Loading theorem BoundedOrderHom.copy_eq
# Loading theorem BoundedOrderHom.coe_id
# Loading theorem BoundedOrderHom.id_apply
# Loading theorem BoundedOrderHom.coe_comp
# Loading theorem BoundedOrderHom.comp_apply
# Loading theorem BoundedOrderHom.coe_comp_orderHom
# Loading theorem BoundedOrderHom.coe_comp_topHom
# Loading theorem BoundedOrderHom.coe_comp_botHom
# Loading theorem BoundedOrderHom.comp_assoc
# Loading theorem BoundedOrderHom.comp_id
# Loading theorem BoundedOrderHom.id_comp
# Loading theorem TopHom.dual_id
# Loading theorem TopHom.dual_comp
# Loading theorem TopHom.symm_dual_id
# Loading theorem TopHom.symm_dual_comp
# Loading theorem BotHom.dual_id
# Loading theorem BotHom.dual_comp
# Loading theorem BotHom.symm_dual_id
# Loading theorem BotHom.symm_dual_comp
# Loading theorem BoundedOrderHom.dual_id
# Loading theorem BoundedOrderHom.dual_comp
# Loading theorem BoundedOrderHom.symm_dual_id
# Loading theorem BoundedOrderHom.symm_dual_comp
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240623/Mathlib__AlgebraicTopology__CechNerve.lean.pkl
# Loading theorem CategoryTheory.CechNerveTerminalFrom.wideCospan.limitIsoPi_hom_comp_pi
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240623/Mathlib__CategoryTheory__Localization__Adjunction.lean.pkl
# Ran out of input
# Summarizing data ...
# Done
# Loading /home/mcwave/code/automath/atp/datasets/provability/rag_20240623/Mathlib__MeasureTheory__Function__LpSeminorm__TriangleInequality.lean.pkl
# Ran out of input
# Summarizing data ...
# Done

# %%
import os
import pickle

fin = open('/home/mcwave/code/automath/atp/datasets/provability/rag_20240621_20240622_state_proof.pkl', 'rb')
all_proof_list = pickle.load(fin)
fin.close()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[3], line 5
#       2 import pickle
#       4 fin = open('/home/mcwave/code/automath/atp/datasets/provability/rag_20240621_20240622_state_proof.pkl', 'wb')
# ----> 5 all_proof_list = pickle.load(fin)
#       6 fin.close()
#
# UnsupportedOperation: read

# %%
idx = -108

print(provability_list[idx])

[x for x in next_tac_list if x[2] == provability_list[idx][2]]
# Out:
# ('Mathlib/Order/BoundedOrder.lean', 'bot_eq_false', 'case a.a.refl\nα : Type u\nβ : Type v\nγ : Type u_1\nδ : Type u_2\nnvar0 : false = true\n⊢ ⊥ = true\n\ncase a.a\nα : Type u\nβ : Type v\nγ : Type u_1\nδ : Type u_2\nnvar0 : false = true\n⊢ ⊥ ≤ true', -1)
# []

# %%
import torch
from transformers import T5ForConditionalGeneration, T5Tokenizer
from transformers import Trainer, TrainingArguments
from datasets import Dataset

# Assuming you have your question-answer pairs in a list called 'qa_pairs'
# qa_pairs = [("Question 1", "Answer 1"), ("Question 2", "Answer 2"), ...]

# Prepare the dataset
def prepare_dataset(qa_pairs):
    return Dataset.from_dict({
        "question": [pair[0] for pair in qa_pairs],
        "answer": [pair[1] for pair in qa_pairs]
    })

dataset = prepare_dataset(qa_pairs)

# Load the model and tokenizer
model_name = "google/flan-t5-base"
model = T5ForConditionalGeneration.from_pretrained(model_name)
tokenizer = T5Tokenizer.from_pretrained(model_name)

# Tokenize the dataset
def preprocess_function(examples):
    inputs = tokenizer(examples["question"], padding="max_length", truncation=True, max_length=512)
    outputs = tokenizer(examples["answer"], padding="max_length", truncation=True, max_length=512)
    
    inputs["labels"] = outputs["input_ids"]
    return inputs

tokenized_dataset = dataset.map(preprocess_function, batched=True)

# Define training arguments
training_args = TrainingArguments(
    output_dir="./results",
    num_train_epochs=3,
    per_device_train_batch_size=8,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir="./logs",
)

# Initialize Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
)

# Train the model
trainer.train()

# Save the model
model.save_pretrained("./flan-t5-qa-model")
tokenizer.save_pretrained("./flan-t5-qa-model")

# Function to generate answer for a new question
def generate_answer(question):
    input_text = f"question: {question}"
    input_ids = tokenizer(input_text, return_tensors="pt").input_ids
    
    outputs = model.generate(input_ids, max_length=512, num_return_sequences=1)
    answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
    
    return answer

# Example usage
new_question = "What is the capital of France?"
generated_answer = generate_answer(new_question)
print(f"Question: {new_question}")
print(f"Generated Answer: {generated_answer}")
# Out:
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
# 50 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 50 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 50 proofs
#
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
# 50 proofs
#
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
# 50 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 50 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
# 50 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 50 proofs
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = true
# 43 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = true
# 43 proofs
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 43 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
# 31 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
# 31 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
# 50 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 50 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 50 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 50 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
# 50 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
# 50 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 50 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 50 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true = ⊤
# 50 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true = ⊤
# 50 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true = ⊤
# 50 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar1 : ⊤ = true
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true = ⊤
# 50 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
# 50 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 15 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 15 proofs
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
# 27 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
# 27 proofs
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 27 proofs
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 27 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
# 27 proofs
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 27 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 27 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
# 27 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 15 proofs
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
# 21 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
# 50 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
# 50 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
# 50 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
# 21 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 15 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 15 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 15 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 15 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 15 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 15 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 15 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 15 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 15 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 15 proofs
#
# case a.refl.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 15 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 15 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 15 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a.refl.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 15 proofs
#
# case a.refl.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 15 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 15 proofs
#
# case a.intro
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
# 6 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ ⊤ = true
# 18 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ ⊤ = true
# 18 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 18 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 18 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ true = ⊤
# 18 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 18 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ true = ⊤
# 18 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
# 50 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.intro
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
# 6 proofs
#
# case a.intro
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 6 proofs
#
# case a.intro
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 6 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true ≤ ⊤
# 16 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true ≤ ⊤
# 16 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ = true
# 32 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ = true
# 32 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 32 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 32 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true = ⊤
# 32 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true = ⊤
# 32 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 32 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ ≤ true
# 16 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ = true
# 24 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true ≤ ⊤
# 16 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ true
# 14 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ true
# 14 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true = true
# 45 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true = true
# 45 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 45 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
# 16 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
# 16 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 3 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 19 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 19 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 19 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 19 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true ≤ true
# 15 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true ≤ true
# 15 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ ⊤ = true
# 6 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
# 15 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
# 15 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ ≤ true
# 15 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true = ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
# 15 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
# 15 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
# 15 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
# 15 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 16 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ ¬⊤ = true
# 1 proofs
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = true
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
# 1 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar1 : ⊤ = true
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
# 1 proofs
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true = ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# nvar1 : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0✝ : true = true
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ = true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ = true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ = true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true = ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝¹ : true = true
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ = true
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = true
# 1 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.refl.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true = true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true = true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar1 : true = true
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
# 1 proofs
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# nvar1 : true = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0✝ : ⊤ = true
# nvar0 : true = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# a✝ : true = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true = true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true = true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true = true
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# nvar0 : true = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝¹ : ⊤ = true
# a✝ : true = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.refl.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ true
# 1 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true = true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ true
# 1 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true = true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ ¬true = ⊤
# 1 proofs
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ¬⊤ = true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ ¬True
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ ¬true = true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ ¬⊤ = ⊤
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ¬⊤ = true
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# nvar1 : true = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0✝ : ⊤ = true
# nvar0 : true = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# a✝ : true = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
# 1 proofs
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = true
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
# 1 proofs
#
# case a.refl.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.refl.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ = true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# nvar0 : true = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝¹ : ⊤ = true
# a✝ : true = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true ≤ true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
# 1 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ true
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
# 1 proofs
#
# case a.refl.a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ true
#
# case a.refl.a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true ≤ true
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
# 1 proofs
#
# case a.refl.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.refl.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.refl.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.refl.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a.refl.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.refl.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
#
# case a.refl.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.refl.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true ≤ true
#
# case a.refl.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true ≤ true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# nvar1 : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0✝ : true = true
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.intro.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.intro.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar1 : ⊤ = true
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ ⊤ = true
# 1 proofs
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ ⊤ = true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ ⊤ = true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ ⊤ = true
# 1 proofs
#
# case a.a.intro
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ true = ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# nvar1 : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0✝ : True
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝¹ : true = true
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.refl
# α : Type u
# β : Type v
# ...
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0✝ nvar0 : true = true
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 a✝ : true = true
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ ⊤ ≤ true
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true = ⊤
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# nvar1 : ⊤ = true
# ⊢ true = true
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true = true
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0✝ : true = true
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar1 : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
# 1 proofs
#
# case a.a.refl.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
# 1 proofs
#
# case a.a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ ≤ true
#
# case a.a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0✝ : true = true
# nvar0 : True
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0✝ nvar0 : true = true
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0✝ nvar0 : true = true
# ⊢ ⊤ = true
# 1 proofs
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0✝ nvar0 : true = true
# ⊢ ⊤ ≤ true
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0✝ nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : true = true
# nvar0 : True
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 a✝ : true = true
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 a✝ : true = true
# ⊢ ⊤ = true
# 1 proofs
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 a✝ : true = true
# ⊢ ⊤ ≤ true
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 a✝ : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar1 : true = true
# nvar0 : True
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 nvar1 : true = true
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 nvar1 : true = true
# ⊢ ⊤ = true
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar1 : true = true
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# nvar1 : True
# ⊢ ⊤ = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 nvar1 : true = true
# ⊢ ⊤ ≤ true
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 nvar1 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 nvar1 : true = true
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0✝ nvar0 : true = true
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 a✝ : true = true
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar1 : ⊤ = true
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar1 : ⊤ = true
# ⊢ true ≤ true
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar1 : ⊤ = true
# ⊢ true ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true ≤ true
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# a✝ : ⊤ = true
# ⊢ true ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ true
#
# case a.a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.intro
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ true ≤ ⊤
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true = true
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
#
# case a.a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : ⊤ = true
# ⊢ true ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : True
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 nvar1 : true = true
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0✝ nvar0 : true = true
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 a✝ : true = true
# ⊢ ⊤ = true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a.a.refl
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true = ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs
#
# case a.a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ true ≤ ⊤
#
# case a.a.refl.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
#
# case a.a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# nvar0 : true = true
# ⊢ true ≤ ⊤
#
# case a
# α : Type u
# β : Type v
# γ : Type u_1
# δ : Type u_2
# ⊢ ⊤ ≤ true
# 1 proofs

# %%
results[0][2]
# Out:
# Theorem(repo=LeanGitRepo(url='https://github.com/leanprover-community/mathlib4', commit='27c6744e1c0e25d676be5eb252cd4b6d30c6acc7'), file_path=PosixPath('Mathlib/Order/BoundedOrder.lean'), full_name='eq_bot_iff')

# %%
state_pps[keys[7]]
# Out:
# [['swap', 'norm_cast', 'congr'],
#  ['cases nvar0', 'swap', 'simp', 'classical simp [imp_false]'],
#  ['cases nvar0', 'swap', 'simp', 'rw [eq_comm]'],
#  ['cases nvar0', 'swap', 'simp', 'simp only [if_true]'],
#  ['cases nvar0', 'swap', 'simp', 'apply le_antisymm', 'norm_cast', 'rfl'],
#  ['cases nvar0', 'swap', 'simp', 'simp only [eq_self_iff_true]'],
#  ['swap', 'norm_cast', 'apply le_antisymm', 'simpa', 'simp_all'],
#  ['cases nvar0', 'swap', 'simp', 'congr 1'],
#  ['cases nvar0', 'swap', 'simp', 'apply le_antisymm', 'norm_cast', 'simpa'],
#  ['swap', 'norm_cast', 'simpa'],
#  ['swap', 'norm_cast', 'rfl'],
#  ['swap', 'norm_cast', 'simp only [not_false_eq_true]'],
#  ['swap', 'norm_cast', 'apply le_antisymm', 'simpa', 'simp [←nvar0]'],
#  ['swap', 'norm_cast', 'apply le_antisymm', 'simpa', 'simp [*]'],
#  ['swap', 'norm_cast', 'classical simp [imp_false]'],
#  ['swap', 'norm_cast', 'simp [true_ne_false]'],
#  ['swap', 'norm_cast', 'simp [top_ne_bot]'],
#  ['cases nvar0', 'swap', 'simp', 'simp_all'],
#  ['swap', 'norm_cast', 'simp [nvar0]'],
#  ['cases nvar0', 'swap', 'simp', 'decide'],
#  ['swap', 'norm_cast', 'assumption'],
#  ['cases nvar0', 'swap', 'simp', 'simp [false_and_iff]'],
#  ['swap', 'norm_cast', 'apply le_antisymm', 'simpa', 'simp [true_ne_false]'],
#  ['swap', 'norm_cast', 'decide'],
#  ['cases nvar0', 'swap', 'simp', 'simp only [not_false_eq_true]'],
#  ['swap', 'norm_cast', 'apply le_antisymm', 'simpa', 'simp [← nvar0]'],
#  ['cases nvar0', 'swap', 'simp', 'simp'],
#  ['cases nvar0',
#   'swap',
#   'simp',
#   'apply le_antisymm',
#   'norm_cast',
#   'simp [top_ne_bot]'],
#  ['swap', 'norm_cast', 'simp only [if_true]'],
#  ['cases nvar0', 'swap', 'simp', 'dsimp'],
#  ['swap', 'norm_cast', 'dsimp'],
#  ['swap', 'norm_cast', 'simp only [not_false_iff]'],
#  ['swap', 'norm_cast', 'constructor'],
#  ['swap', 'norm_cast', 'simp_all only [not_false_eq_true]'],
#  ['swap', 'norm_cast', 'congr 1'],
#  ['cases nvar0', 'swap', 'simp', 'simp_all only [not_true_eq_false]'],
#  ['cases nvar0', 'swap', 'simp', 'simpa'],
#  ['cases nvar0', 'swap', 'simp', 'rfl'],
#  ['cases nvar0', 'swap', 'simp', 'dsimp only'],
#  ['cases nvar0', 'swap', 'simp', 'simp [_root_.not_or]'],
#  ['cases nvar0',
#   'swap',
#   'simp',
#   'apply le_antisymm',
#   'norm_cast',
#   'simp [true_ne_false]'],
#  ['cases nvar0',
#   'swap',
#   'simp',
#   'apply le_antisymm',
#   'norm_cast',
#   'simp [_root_.not_or]'],
#  ['swap', 'norm_cast', 'simp only [not_true_eq_false]'],
#  ['cases nvar0',
#   'swap',
#   'simp',
#   'apply le_antisymm',
#   'norm_cast',
#   'simp [not_false_iff]'],
#  ['swap', 'norm_cast', 'simp [not_false_iff]'],
#  ['swap', 'norm_cast', 'apply le_antisymm', 'simpa', 'simp [not_false_iff]'],
#  ['cases nvar0', 'swap', 'simp', 'simp only [imp_false]'],
#  ['swap', 'norm_cast', 'apply nvar0'],
#  ['swap', 'norm_cast', 'simp only [imp_false]'],
#  ['cases nvar0', 'swap', 'simp', 'simp [true_ne_false]']]
