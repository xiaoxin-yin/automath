# %%
import os

os.environ['GITHUB_ACCESS_TOKEN'] = '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'

print(os.getenv("GITHUB_ACCESS_TOKEN", None))

from lean_dojo import *
# Out:
# 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

# %%
repo = LeanGitRepo(
    "https://github.com/xiaoxin-yin/math-in-lean",
    "582b82ce041cd8130da516a1636e4d7769d1c72e"
)

repo
# Out:
# LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='582b82ce041cd8130da516a1636e4d7769d1c72e')

# %%
repo.get_config("lean-toolchain")

traced_repo = trace(repo)

print(traced_repo.traced_files_graph)

print("len(traced_repo.traced_files):", len(traced_repo.traced_files))
# Out:
# 2024-04-26 22:44:25.515 | INFO     | lean_dojo.data_extraction.trace:get_traced_repo_path:80 - Tracing LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='582b82ce041cd8130da516a1636e4d7769d1c72e')
# cmd: python build_lean4_repo.py math-in-lean
# 2024-04-26 22:44:28.636 | INFO     | __main__:main:165 - Building math-in-lean
# info: mathlib: cloning https://github.com/leanprover-community/mathlib4 to './.lake/packages/mathlib'
# info: std: cloning https://github.com/leanprover/std4 to './.lake/packages/std'
# info: Qq: cloning https://github.com/leanprover-community/quote4 to './.lake/packages/Qq'
# info: aesop: cloning https://github.com/leanprover-community/aesop to './.lake/packages/aesop'
# info: proofwidgets: cloning https://github.com/leanprover-community/ProofWidgets4 to './.lake/packages/proofwidgets'
# info: Cli: cloning https://github.com/leanprover/lean4-cli to './.lake/packages/Cli'
# info: importGraph: cloning https://github.com/leanprover-community/import-graph.git to './.lake/packages/importGraph'
# [0/2] Downloading proofwidgets cloud release
# [0/40] Building Std.Lean.Command
# [0/64] Building Std.Tactic.Unreachable
# [0/64] Building Std.Lean.TagAttribute
# [0/64] Building Std.Lean.Parser
# [0/64] Building Std.Util.TermUnsafe
# [0/64] Building Std.Classes.Dvd
# [0/64] Building Std.Data.Array.Init.Basic
# [0/64] Building Std.Lean.Name
# [0/64] Building Std.Lean.Syntax
# [0/64] Building Std.Tactic.ByCases
# [0/66] Building Std.Data.Json
# [0/66] Building Std.Lean.LocalContext
# [0/66] Building Std.Util.ProofWanted
# [0/66] Building Std.Lean.Position
# [0/66] Building Std.Lean.Meta.Expr
# [0/66] Building Std.Tactic.SeqFocus
# [0/66] Building Std.Lean.Tactic
# [0/66] Building Std.Lean.InfoTree
# [0/68] Building Std.Data.Ord
# [2/170] Building Std.Lean.PersistentHashMap
# [2/170] Building Std.Lean.Delaborator
# [3/289] Building Std.Tactic.OpenPrivate
# [4/302] Building Std.Util.LibraryNote
# [5/1969] Building Std.Util.ExtendedBinder
# [6/1969] Building Std.Tactic.RCases
# [7/1969] Building Std.Data.Option.Init.Lemmas
# [8/1969] Building Std.Tactic.HaveI
# [9/1969] Building Std.Data.Fin.Init.Lemmas
# [10/1969] Building Std.Data.List.Init.Basic
# [11/1969] Building Std.Lean.NameMapAttribute
# [12/1969] Building Std.Lean.Elab.Tactic
# [14/1969] Building Std.Lean.Expr
# [14/1969] Building Std.Tactic.Change
# [15/1969] Building Std.Classes.BEq
# [16/1969] Building Std.Control.ForInStep.Basic
# [17/1969] Building Std.Data.MLList.Basic
# [19/1969] Building Std.Tactic.LeftRight
# [19/1969] Building Std.Tactic.Replace
# [20/1969] Building Std.Tactic.Omega.Config
# [21/1969] Building Std.Data.DList
# [22/1969] Building Std.Lean.CoreM
# [23/1969] Building Std.Lean.Except
# [24/1969] Building Std.Lean.Float
# [25/1969] Building Std.Lean.HashMap
# [26/1969] Building Std.Lean.IO.Process
# [27/1969] Building Std.Lean.Meta.Inaccessible
# [28/1969] Building Std.Lean.MonadBacktrack
# [29/1969] Building Std.Lean.NameMap
# [30/1969] Building Std.Lean.PersistentHashSet
# [31/1969] Building Std.Lean.SMap
# [32/1969] Building Std.Lean.Util.Path
# [33/1969] Building Std.Tactic.Case
# [34/1969] Building Std.Tactic.Classical
# [35/1969] Building Std.Tactic.Exact
# [36/1969] Building Std.Tactic.Instances
# [37/1969] Building Std.Tactic.LabelAttr
# [38/1969] Building Std.Tactic.Where
# [39/1969] Building Std.WF
# [40/1969] Building Std.Lean.AttributeExtra
# [41/1969] Building Qq.ForLean.ReduceEval
# [42/1969] Building Qq.ForLean.ToExpr
# [43/1969] Building Qq.Typ
# [44/1969] Building Qq.ForLean.Do
# [45/1969] Building Qq.SortLocalDecls
# [46/1969] Building Aesop.Check
# [47/1969] Building Aesop.Nanos
# [48/1969] Building Aesop.Options.Public
# [49/1969] Building Aesop.Percent
# [50/1969] Building Aesop.Frontend.Basic
# [51/1969] Building Aesop.Frontend.ElabM
# [52/1969] Building ImportGraph.RequiredModules
# [53/1969] Building Std.Lean.Meta.Basic
# [54/1969] Building Std.Data.Int.Basic
# [55/1969] Building Std.Data.Nat.Basic
# [56/1969] Building Std.Tactic.RunCmd
# [57/1969] Building Std.Util.Pickle
# [58/1969] Building Std.Tactic.Lint.Basic
# [59/1969] Building Std.CodeAction.Attr
# [60/1969] Building Std.Tactic.GuardExpr
# [61/1969] Building Std.Tactic.PrintDependents
# [62/1969] Building Std.Tactic.CoeExt
# [63/1969] Building Std.Tactic.Relation.Rfl
# [64/1969] Building Std.Control.ForInStep.Lemmas
# [65/1969] Building Std.Lean.Json
# [66/1969] Building Std.Linter.UnreachableTactic
# [67/1969] Building Std.Lean.Meta.Simp
# [68/1969] Building Std.Lean.Format
# [69/1969] Building Std.Tactic.NoMatch
# [70/1969] Building Std.Test.Internal.DummyLabelAttr
# [71/1969] Building Std.Linter.UnnecessarySeqFocus
# [72/1969] Building Aesop.Constants
# [73/1969] Building Aesop.Options.Internal
# [74/1969] Building ImportGraph.Imports
# [75/1969] Building Std.Control.ForInStep
# [76/1969] Building Qq.Macro
# [77/1969] Building Std.Classes.SetNotation
# [78/1969] Building Std.Tactic.Lint.Frontend
# [79/1969] Building Std.Tactic.Lint.TypeClass
# [80/1969] Building Std.Tactic.Lint.Misc
# [81/1969] Building Std.Tactic.Lint.Simp
# [82/1969] Building Std.Tactic.TryThis
# [83/1969] Building Aesop.Options
# [84/1969] Building Std.Data.MLList.Heartbeats
# [85/1969] Building Std.Tactic.NormCast.Ext
# [86/1969] Building Std.Classes.Cast
# [90/1969] Building Std.Linter
# [91/1969] Building Std.CodeAction.Basic
# [91/1969] Building Std.CodeAction.Misc
# [98/1969] Building Std.Lean.Meta.InstantiateMVars
# [98/1969] Building Std.Tactic.Relation.Symm
# [98/1969] Building Std.Tactic.FalseOrByContra
# [98/1969] Building Std.Lean.Meta.SavedState
# [98/1969] Building Std.Lean.Meta.Clear
# [98/1969] Building Std.Lean.Meta.AssertHypotheses
# [99/1969] Building Std.Tactic.NormCast.Lemmas
# [99/1969] Building Std.Tactic.NormCast
# [101/1969] Building Aesop.Util.EqualUpToIds
# [105/1969] Building Std.Lean.HashSet
# [105/1969] Building Std.Data.Option.Basic
# [108/1969] Building Std.Lean.Util.EnvSearch
# [108/1969] Building Std.Control.Nondet.Basic
# [108/1969] Building Std.Tactic.Lint
# [110/1969] Building Std.Tactic.SimpTrace
# [110/1969] Building Std.Tactic.ShowTerm
# [110/1969] Building Std.Tactic.Simpa
# [112/1969] Building Std.Tactic.GuardMsgs
# [112/1969] Building Std.CodeAction.Deprecated
# [113/1969] Building Std.Tactic.PrintPrefix
# [117/1969] Building Std.CodeAction
# [119/1969] Building Std.Tactic.Alias
# [124/1969] Building Std.Data.Prod.Lex
# [125/1969] Building Std.Tactic.SqueezeScope
# [125/1969] Building Std.Tactic.Basic
# [127/1969] Building Std.Data.Prod
# [129/1969] Building Std.Data.Bool
# [129/1969] Unpacking proofwidgets cloud release
# [130/1969] Building ProofWidgets.Compat
# [130/1969] Building Mathlib.Tactic.ReduceModChar.Ext
# [130/1969] Building Mathlib.Tactic.TypeCheck
# [130/1969] Building Mathlib.Util.CountHeartbeats
# [130/1969] Building Mathlib.Util.DischargerAsTactic
# [130/1969] Building Mathlib.Util.AtomM
# [130/1969] Building Mathlib.Tactic.SimpIntro
# [130/1969] Building Mathlib.Init.Data.Sigma.Basic
# [130/1969] Building Mathlib.Tactic.UnsetOption
# [130/1969] Building Mathlib.Util.SynthesizeUsing
# [130/1969] Building Mathlib.Tactic.SuccessIfFailWithMsg
# [130/1969] Building Mathlib.Tactic.Explode.Datatypes
# [130/1969] Building Mathlib.Tactic.Variable
# [130/1969] Building Mathlib.Tactic.Monotonicity.Attr
# [131/1969] Building Mathlib.Tactic.Existsi
# [132/1969] Building Mathlib.Tactic.GuardHypNums
# [133/1969] Building Mathlib.Tactic.SuppressCompilation
# [134/1969] Building Mathlib.Tactic.FunProp.ToStd
# [135/1969] Building Mathlib.Tactic.Clear!
# [136/1969] Building Mathlib.Tactic.Clear_
# [138/1969] Building Mathlib.Tactic.NthRewrite
# [138/1969] Building Mathlib.Tactic.Have
# [139/1969] Building Mathlib.Tactic.Trace
# [140/1969] Building Mathlib.Tactic.Recover
# [141/1969] Building Mathlib.Lean.Meta.Basic
# [143/1969] Building Mathlib.Tactic.Constructor
# [143/1969] Building Mathlib.Tactic.Clean
# [144/1969] Building Mathlib.Util.Tactic
# [145/1969] Building Mathlib.Tactic.SudoSetOption
# [146/1969] Building Mathlib.Tactic.CasesM
# [147/1969] Building Mathlib.Tactic.Set
# [148/1969] Building Mathlib.Lean.PrettyPrinter.Delaborator
# [149/1969] Building Mathlib.Tactic.InferParam
# [150/1969] Building Mathlib.Lean.EnvExtension
# [151/1969] Building Mathlib.Tactic.ExtractGoal
# [152/1969] Building Mathlib.Tactic.Relation.Rfl
# [153/1969] Building Mathlib.Tactic.HaveI
# [154/1969] Building Mathlib.Mathport.Rename
# [155/1969] Building Mathlib.Util.WhatsNew
# [156/1969] Building Mathlib.Data.Array.Defs
# [157/1969] Building Mathlib.Tactic.FailIfNoProgress
# [158/1969] Building Mathlib.Tactic.Substs
# [159/1969] Building Mathlib.Lean.Elab.Term
# [160/1969] Building Mathlib.Tactic.Relation.Symm
# [161/1969] Building Mathlib.Tactic.ProjectionNotation
# [162/1969] Building Mathlib.Tactic.Spread
# [163/1969] Building Mathlib.Tactic.Coe
# [164/1969] Building Mathlib.Util.MemoFix
# [165/1969] Building Mathlib.Tactic.Attr.Register
# [166/1969] Building Mathlib.Util.AddRelatedDecl
# [167/1969] Building Mathlib.Tactic.HelpCmd
# [168/1969] Building Mathlib.Lean.Expr.Traverse
# [169/1969] Building Mathlib.Tactic.Lint
# [170/1969] Building Mathlib.Tactic.Simps.NotationClass
# [171/1969] Building Mathlib.Tactic.ApplyWith
# [172/1969] Building Mathlib.Tactic.ClearExcept
# [173/1969] Building Mathlib.Mathport.Attributes
# [174/1969] Building Mathlib.Tactic.Lemma
# [175/1969] Building Mathlib.Init.Data.Nat.Notation
# [176/1969] Building Mathlib.Tactic.Recall
# [177/1969] Building Mathlib.Util.AssertExists
# [178/1969] Building Mathlib.Tactic.Widget.SelectInsertParamsClass
# [179/1969] Building Mathlib.Tactic.Rename
# [180/1969] Building Mathlib.Tactic.RunCmd
# [181/1969] Building Mathlib.Tactic.PPWithUniv
# [182/1969] Building Mathlib.Util.Delaborators
# [183/1969] Building Mathlib.Tactic.Eqns
# [184/1969] Building Mathlib.Tactic.SimpRw
# [185/1969] Building Mathlib.Util.WithWeakNamespace
# [186/1969] Building Mathlib.Tactic.ExtendDoc
# [187/1969] Building Mathlib.Tactic.GuardGoalNums
# [188/1969] Building Mathlib.Tactic.FunProp.StateList
# [189/1969] Building ProofWidgets.Component.Basic
# [190/1969] Building Mathlib.Tactic.GCongr.ForwardAttr
# [191/1969] Building Mathlib.Tactic.Explode.Pretty
# [192/1969] Building Std.Classes.Order
# [193/1969] Building Mathlib.Tactic.SwapVar
# [194/1969] Building Mathlib.Tactic.ApplyAt
# [195/1969] Building Mathlib.Tactic.Replace
# [196/1969] Building Mathlib.Lean.Meta.DiscrTree
# [197/1969] Building Mathlib.Tactic.HigherOrder
# [198/1969] Building Mathlib.Init.Data.Fin.Basic
# [199/1969] Building Mathlib.CategoryTheory.ConcreteCategory.Bundled
# [200/1969] Building Mathlib.Init.Set
# [201/1969] Building Mathlib.Init.Data.Sigma.Lex
# [202/1969] Building Mathlib.Init.Quot
# [203/1969] Building Mathlib.Control.ULift
# [204/1969] Building Mathlib.Init.Data.Ordering.Basic
# [205/1969] Building Mathlib.Lean.Expr.ReplaceRec
# [206/1969] Building Std.Logic
# [207/1969] Building Mathlib.Tactic.ScopedNS
# [208/1969] Building Mathlib.Tactic.ToLevel
# [209/1969] Building Mathlib.Tactic.Explode
# [210/1969] Building ProofWidgets.Data.Html
# [211/1969] Building ProofWidgets.Component.MakeEditLink
# [212/1969] Building Mathlib.Tactic.Hint
# [213/1969] Building Mathlib.Util.CompileInductive
# [214/1969] Building Mathlib.Tactic.Conv
# [220/1969] Building Mathlib.Tactic.DeriveToExpr
# [226/1969] Building Qq.Delab
# [227/1969] Building Mathlib.Tactic.ApplyCongr
# [229/1969] Building Std.Data.Sum.Basic
# [229/1969] Building Std.Data.Nat.Init.Lemmas
# [229/1969] Building Mathlib.Tactic.Attr.Core
# [229/1969] Building Std.Data.Fin.Iterate
# [229/1969] Building Std.Tactic.Omega.Logic
# [229/1969] Building Mathlib.Init.Data.Quot
# [229/1969] Building Mathlib.Init.Propext
# [229/1969] Building Mathlib.Init.Data.Subtype.Basic
# [229/1969] Building Std.Classes.LawfulMonad
# [229/1969] Building Mathlib.Tactic.Use
# [229/1969] Building Std.Data.RBMap.Basic
# [229/1969] Building Std.Data.PairingHeap
# [231/1969] Building Mathlib.Init.Data.Prod
# [238/1969] Building Std.Data.Fin.Basic
# [238/1969] Building Std.Lean.Meta.LazyDiscrTree
# [238/1969] Building Std.Data.List.Init.Lemmas
# [238/1969] Building Std.Data.Nat.Lemmas
# [240/1969] Building Mathlib.Mathport.Notation
# [242/1969] Building ProofWidgets.Presentation.Expr
# [242/1969] Building ProofWidgets.Component.OfRpcMethod
# [242/1969] Building ProofWidgets.Component.PenroseDiagram
# [244/1969] Building Mathlib.Tactic.ToExpr
# [245/1969] Building Qq.MetaM
# [246/1969] Building Mathlib.Tactic.Widget.SelectPanelUtils
# [248/1969] Building Mathlib.Tactic.FBinop
# [252/1969] Building Qq.AssertInstancesCommute
# [252/1969] Building Qq.Match
# [257/1969] Building Std.Data.RBMap.WF
# [258/1969] Building Std.Data.List.Init.Attach
# [258/1969] Building Mathlib.Init.Control.Combinators
# [258/1969] Building Std.Data.Array.Init.Lemmas
# [262/1969] Building Std.Data.Array.Basic
# [263/1969] Building Mathlib.Data.SProd
# [265/1969] Building Std.Data.BinomialHeap.Basic
# [265/1969] Building Std.Data.Nat.Bitwise
# [265/1969] Building Std.Data.Int.Lemmas
# [265/1969] Building Std.Data.Array.Merge
# [265/1969] Building Std.Data.Nat.Gcd
# [268/1969] Building Std.Data.Array.Match
# [268/1969] Building Std.Data.List.Basic
# [269/1969] Building Std.Data.Nat
# [269/1969] Building Std.Data.BitVec.Basic
# [271/1969] Building Std.Data.Int.Order
# [272/1969] Building Qq
# [273/1969] Building Std.Data.String.Basic
# [274/1969] Building Aesop.Util.UnorderedArraySet
# [274/1969] Building Std.Lean.Meta.DiscrTree
# [275/1969] Building Mathlib.Tactic.FunProp.Decl
# [275/1969] Building Mathlib.Util.Qq
# [280/1969] Building Std.Lean.Meta.UnusedNames
# [280/1969] Building Mathlib.Tactic.Says
# [282/1969] Building Mathlib.Lean.Meta.Simp
# [282/1969] Building Std.Util.Cache
# [282/1969] Building Std.Tactic.Ext.Attr
# [285/1969] Building Std.Data.UInt
# [285/1969] Building Std.Tactic.Ext
# [285/1969] Building Std.Data.Option.Lemmas
# [285/1969] Building Std.Data.Char
# [286/1969] Building Mathlib.Init.Data.Int.Basic
# [286/1969] Building Std.Tactic.Omega.Int
# [286/1969] Building Std.Data.Int.DivMod
# [287/1969] Building Mathlib.Tactic.Find
# [292/1969] Building Std.Data.BinomialHeap.Lemmas
# [293/1969] Building Std.Data.BinomialHeap
# [296/1969] Building Mathlib.Lean.Thunk
# [296/1969] Building Std.Control.Lemmas
# [297/1969] Building Std.Tactic.Congr
# [297/1969] Building Std.Data.Sum.Lemmas
# [297/1969] Building Std.Data.Fin.Lemmas
# [298/1969] Building Std.Data.Option
# [298/1969] Building Std.Tactic.Omega.MinNatAbs
# [303/1969] Building Std.Data.Sum
# [306/1969] Building Std.Tactic.PermuteGoals
# [306/1969] Building Mathlib.Data.String.Defs
# [306/1969] Building Mathlib.Init.Data.List.Basic
# [306/1969] Building Mathlib.Lean.Meta
# [306/1969] Building Std.Tactic.SolveByElim.Backtrack
# [306/1969] Building Std.Data.AssocList
# [306/1969] Building Mathlib.Tactic.FunProp.RefinedDiscrTree
# [306/1969] Building Std.Data.List.Lemmas
# [307/1969] Building Std.Data.Rat.Basic
# [307/1969] Building Std.Data.Int.Gcd
# [307/1969] Building Std.Tactic.Omega.IntList
# [308/1969] Building Mathlib.Tactic.Widget.Conv
# [308/1969] Building Mathlib.Tactic.Widget.Calc
# [311/1969] Building Std.Data.Int
# [312/1969] Building Mathlib.Lean.Elab.Tactic.Basic
# [312/1969] Building Mathlib.Lean.Meta.CongrTheorems
# [313/1969] Building Std.Data.Fin
# [317/1969] Building Std.Data.HashMap.Basic
# [318/1969] Building Mathlib.Data.Rat.Init
# [318/1969] Building Std.Classes.RatCast
# [318/1969] Building Mathlib.Lean.Expr.Basic
# [318/1969] Building Std.Data.Rat.Lemmas
# [320/1969] Building Std.Tactic.Omega.Coeffs.IntList
# [321/1969] Building Std.Tactic.SolveByElim
# [322/1969] Building Mathlib.Tactic.Relation.Trans
# [324/1969] Building Std.Tactic.Omega.Constraint
# [324/1969] Building Std.Tactic.Omega.LinearCombo
# [325/1969] Building Std.Data.RBMap.Alter
# [327/1969] Building Mathlib.Tactic.Congr!
# [328/1969] Building Std.Tactic.Omega.OmegaM
# [329/1969] Building Mathlib.Tactic.GeneralizeProofs
# [329/1969] Building Mathlib.Tactic.RenameBVar
# [329/1969] Building Mathlib.Tactic.Cases
# [329/1969] Building Mathlib.Tactic.Simps.Basic
# [329/1969] Building Mathlib.Tactic.Core
# [331/1969] Building Std.Data.HashMap.Lemmas
# [331/1969] Building Mathlib.Lean.Name
# [331/1969] Building Aesop.Util.UnionFind
# [331/1969] Building Mathlib.Data.HashMap
# [331/1969] Building Mathlib.Data.MLList.Dedup
# [333/1969] Building Mathlib.Tactic.Monotonicity.Basic
# [333/1969] Building Mathlib.Tactic.LibrarySearch
# [333/1969] Building Std.Tactic.LibrarySearch
# [338/1969] Building Aesop.Util.Basic
# [340/1969] Building Std.Tactic.Omega.Core
# [344/1969] Building Mathlib.Tactic.WLOG
# [344/1969] Building Mathlib.Tactic.Propose
# [344/1969] Building Mathlib.Tactic.SplitIfs
# [345/1969] Building Std.Data.Rat
# [346/1969] Building Mathlib.Tactic.Observe
# [347/1969] Building Mathlib.Tactic.Convert
# [351/1969] Building Mathlib.Init.Core
# [351/1969] Building Mathlib.Init.Logic
# [352/1969] Building Aesop.Tracing
# [352/1969] Building Aesop.Rule.Name
# [352/1969] Building Aesop.Util.Tactic
# [352/1969] Building Aesop.Index.Basic
# [356/1969] Building Std.Tactic.Omega.Frontend
# [360/1969] Building Aesop.Index
# [361/1969] Building Aesop.Script
# [362/1969] Building Mathlib.Init.CCLemmas
# [362/1969] Building Mathlib.Init.Data.Bool.Lemmas
# [362/1969] Building Mathlib.Init.Align
# [362/1969] Building Mathlib.Init.Algebra.Classes
# [369/1969] Building Mathlib.Tactic.ToAdditive
# [370/1969] Building Std.Data.List.Count
# [370/1969] Building Std.Data.Range.Lemmas
# [370/1969] Building Std.Lean.System.IO
# [370/1969] Building Mathlib.Init.Data.List.Instances
# [370/1969] Building Mathlib.Init.Data.List.Lemmas
# [370/1969] Building Std.Data.Array.Lemmas
# [370/1969] Building Std.Data.String.Lemmas
# [371/1969] Building Aesop.RuleTac.Basic
# [372/1969] Building Std.Data.RBMap.Lemmas
# [373/1969] Building Std.Data.MLList.IO
# [375/1969] Building Std.Data.MLList
# [376/1969] Building Aesop.RuleTac.Preprocess
# [376/1969] Building Aesop.RuleTac.Tactic
# [376/1969] Building Aesop.RuleTac.Forward
# [376/1969] Building Aesop.RuleTac.Cases
# [376/1969] Building Aesop.RuleTac.Apply
# [376/1969] Building Aesop.Rule.Basic
# [380/1969] Building Aesop.Search.Expansion.Basic
# [380/1969] Building Aesop.Rule
# [382/1969] Building Std.Data.Range
# [383/1969] Building Std.Data.List.Pairwise
# [384/1969] Building Aesop.Builder.Basic
# [384/1969] Building Aesop.Tree.UnsafeQueue
# [389/1969] Building Aesop.Tree.Data
# [390/1969] Building Aesop.RuleTac
# [391/1969] Building Aesop.Builder.Forward
# [391/1969] Building Aesop.Builder.Unfold
# [391/1969] Building Aesop.Builder.Apply
# [391/1969] Building Aesop.Builder.Tactic
# [391/1969] Building Aesop.Builder.NormSimp
# [391/1969] Building Aesop.Builder.Cases
# [393/1969] Building Std.Tactic.Omega
# [396/1969] Building Aesop.Builder.Constructors
# [400/1969] Building Aesop.Builder.Default
# [401/1969] Building Std.Data.BitVec.Lemmas
# [402/1969] Building Aesop.Tree.RunMetaM
# [402/1969] Building Aesop.Profiling
# [402/1969] Building Aesop.Tree.Traversal
# [403/1969] Building Aesop.Builder
# [404/1969] Building Std.Data.List.Perm
# [405/1969] Building Mathlib.Init.ZeroOne
# [406/1969] Building Aesop.Tree.TreeM
# [406/1969] Building Aesop.Tree.Tracing
# [408/1969] Building Aesop.Tree.State
# [409/1969] Building Aesop.RuleSet
# [410/1969] Building Mathlib.Init.Data.Nat.Basic
# [412/1969] Building Std.Data.BitVec.Folds
# [413/1969] Building Aesop.Tree.Free
# [413/1969] Building Aesop.Tree.ExtractScript
# [413/1969] Building Aesop.Tree.AddRapp
# [414/1969] Building Std.Data.RBMap
# [415/1969] Building Aesop.Tree.Check
# [418/1969] Building Std.Data.BitVec.Bitblast
# [420/1969] Building Std.Data.ByteArray
# [420/1969] Building Std.Data.Array
# [420/1969] Building Std.Data.HashMap.WF
# [421/1969] Building Aesop.Tree.ExtractProof
# [425/1969] Building Aesop.Frontend.Extension.Init
# [425/1969] Building Aesop.Search.Expansion.Simp
# [425/1969] Building Aesop.Frontend.RuleExpr
# [426/1969] Building Std.Data.BitVec
# [427/1969] Building Aesop.Frontend.Extension
# [428/1969] Building Aesop.Tree
# [431/1969] Building Aesop.Search.Queue.Class
# [433/1969] Building Aesop.Search.SearchM
# [433/1969] Building Aesop.Search.Queue
# [435/1969] Building Std.Data.List
# [436/1969] Building Aesop.Search.RuleSelection
# [439/1969] Building Aesop.Search.Expansion.Norm
# [440/1969] Building Std.Data.HashMap
# [442/1969] Building Aesop.Frontend.Attribute
# [443/1969] Building Std.Data.String
# [444/1969] Building Std
# [445/1969] Building Aesop.BuiltinRules.Intros
# [445/1969] Building Aesop.BuiltinRules.Subst
# [445/1969] Building Aesop.BuiltinRules.Assumption
# [445/1969] Building Aesop.Frontend.Command
# [445/1969] Building Aesop.BuiltinRules.Ext
# [445/1969] Building Aesop.Frontend.Tactic
# [445/1969] Building Aesop.BuiltinRules.ApplyHyps
# [445/1969] Building Aesop.BuiltinRules.Split
# [445/1969] Building Aesop.BuiltinRules.DestructProducts
# [446/1969] Building Mathlib.Tactic.TypeStar
# [449/1969] Building Mathlib.Data.Bracket
# [449/1969] Building Mathlib.Tactic.Basic
# [449/1969] Building Mathlib.Data.Option.Defs
# [449/1969] Building Mathlib.Data.List.TFAE
# [449/1969] Building Mathlib.Tactic.Inhabit
# [449/1969] Building Mathlib.Init.Order.Defs
# [449/1969] Building Mathlib.Tactic.MkIffOfInductiveProp
# [449/1969] Building Mathlib.Algebra.Group.Defs
# [454/1969] Building Aesop.Search.Expansion
# [458/1969] Building Mathlib.Tactic.TFAE
# [459/1969] Building Aesop.Frontend
# [462/1969] Building Mathlib.Tactic.RSuffices
# [462/1969] Building Mathlib.Init.Control.Lawful
# [462/1969] Building Mathlib.Tactic.LiftLets
# [462/1969] Building Mathlib.Tactic.Change
# [462/1969] Building Mathlib.Tactic.ExtractLets
# [462/1969] Building Mathlib.Tactic.Lift
# [462/1969] Building Mathlib.Tactic.DefEqTransformations
# [462/1969] Building Mathlib.Order.Notation
# [462/1969] Building Mathlib.Init.Function
# [463/1969] Building Aesop.BuiltinRules
# [468/1969] Building Mathlib.Init.Order.LinearOrder
# [468/1969] Building Mathlib.Init.Data.Int.Order
# [468/1969] Building Mathlib.Init.Data.Nat.Lemmas
# [468/1969] Building Mathlib.Tactic.GCongr.Core
# [471/1969] Building Mathlib.Data.Prod.PProd
# [471/1969] Building Mathlib.Logic.Nonempty
# [471/1969] Building Mathlib.Logic.Nontrivial.Defs
# [471/1969] Building Mathlib.Data.Option.NAry
# [471/1969] Building Mathlib.Logic.Relator
# [471/1969] Building Mathlib.Control.Basic
# [471/1969] Building Mathlib.Logic.Basic
# [478/1969] Building Mathlib.Data.Int.Defs
# [482/1969] Building Mathlib.Tactic.Rewrites
# [482/1969] Building Mathlib.Control.Functor
# [484/1969] Building Aesop.Search.ExpandSafePrefix
# [487/1969] Building Mathlib.Control.Traversable.Basic
# [487/1969] Building Mathlib.Data.List.Defs
# [488/1969] Building Mathlib.Data.Bool.Basic
# [489/1969] Building Mathlib.Algebra.Invertible.Defs
# [489/1969] Building Mathlib.Algebra.Group.Commutator
# [489/1969] Building Mathlib.Data.List.BigOperators.Defs
# [489/1969] Building Mathlib.Algebra.Group.Semiconj.Defs
# [489/1969] Building Mathlib.Control.Applicative
# [489/1969] Building Mathlib.Data.Nat.Cast.Defs
# [490/1969] Building Mathlib.Algebra.NeZero
# [490/1969] Building Mathlib.Tactic.Tauto
# [490/1969] Building Mathlib.Logic.Lemmas
# [490/1969] Building Mathlib.Tactic.TermCongr
# [490/1969] Building Mathlib.Tactic.PushNeg
# [490/1969] Building Mathlib.Logic.Function.Basic
# [491/1969] Building Aesop.Search.Main
# [499/1969] Building Mathlib.Data.Int.Cast.Defs
# [499/1969] Building Mathlib.Data.Nat.Cast.NeZero
# [501/1969] Building Mathlib.Control.Traversable.Lemmas
# [502/1969] Building Mathlib.Init.Data.Nat.Bitwise
# [507/1969] Building Mathlib.Tactic.DeriveTraversable
# [508/1969] Building Mathlib.Data.Num.Basic
# [508/1969] Building Mathlib.Init.Data.Int.Bitwise
# [509/1969] Building Mathlib.Algebra.GroupWithZero.Defs
# [509/1969] Building Mathlib.Logic.IsEmpty
# [509/1969] Building Mathlib.Tactic.FunProp.Types
# [509/1969] Building Mathlib.Data.Sigma.Basic
# [509/1969] Building Mathlib.Data.FunLike.Basic
# [509/1969] Building Mathlib.Data.Subtype
# [509/1969] Building Mathlib.Tactic.Choose
# [509/1969] Building Mathlib.Algebra.CharZero.Defs
# [509/1969] Building Mathlib.Data.Sum.Basic
# [509/1969] Building Mathlib.Data.Prod.Basic
# [509/1969] Building Mathlib.Logic.Function.Conjugate
# [509/1969] Building Mathlib.Logic.Relation
# [509/1969] Building Mathlib.Algebra.Group.Basic
# [513/1969] Building Mathlib.Logic.Unique
# [514/1969] Building Mathlib.Logic.Function.Iterate
# [515/1969] Building Mathlib.Tactic.FunProp.Mor
# [515/1969] Building Mathlib.Data.FunLike.Embedding
# [517/1969] Building Mathlib.Tactic.Contrapose
# [517/1969] Building Mathlib.Tactic.ByContra
# [517/1969] Building Mathlib.Data.Nat.Defs
# [519/1969] Building Mathlib.Tactic.IrreducibleDef
# [519/1969] Building Mathlib.Data.Set.Defs
# [520/1969] Building Mathlib.Algebra.GroupWithZero.NeZero
# [520/1969] Building Mathlib.Algebra.Ring.Defs
# [521/1969] Building Mathlib.Algebra.Group.Hom.Defs
# [522/1969] Building Mathlib.Tactic.Congrm
# [525/1969] Building Mathlib.Data.FunLike.Equiv
# [526/1969] Building Mathlib.Data.Quot
# [528/1969] Building Mathlib.Logic.Nontrivial.Basic
# [528/1969] Building Mathlib.Data.Pi.Algebra
# [528/1969] Building Mathlib.Order.Basic
# [532/1969] Building Mathlib.Algebra.Invertible.GroupWithZero
# [533/1969] Building Mathlib.Tactic.FunProp.FunctionData
# [534/1969] Building Mathlib.Tactic.Widget.Congrm
# [535/1969] Building Mathlib.Tactic.Nontriviality.Core
# [537/1969] Building Mathlib.Lean.Expr.ExtraRecognizers
# [539/1969] Building Mathlib.Tactic.FunProp.Theorems
# [540/1969] Building Mathlib.Init.Classical
# [543/1969] Building Mathlib.Logic.Equiv.Defs
# [545/1969] Building Mathlib.Tactic.Nontriviality
# [546/1969] Building Mathlib.Algebra.Ring.Semiconj
# [546/1969] Building Mathlib.Algebra.Field.Defs
# [550/1969] Building Mathlib.Tactic.FunProp.Attr
# [550/1969] Building Mathlib.Tactic.FunProp.Core
# [553/1969] Building Aesop.Main
# [554/1969] Building Mathlib.Algebra.Group.Semiconj.Basic
# [554/1969] Building Mathlib.Data.Int.Cast.Basic
# [554/1969] Building Mathlib.Tactic.MoveAdd
# [557/1969] Building Mathlib.Order.ULift
# [557/1969] Building Mathlib.Data.Tree
# [557/1969] Building Mathlib.Algebra.Order.ZeroLEOne
# [557/1969] Building Mathlib.Order.RelClasses
# [557/1969] Building Mathlib.Data.PNat.Defs
# [558/1969] Building Aesop
# [562/1969] Building Mathlib.Tactic.Zify
# [562/1969] Building Mathlib.Algebra.Group.InjSurj
# [564/1969] Building Mathlib.Tactic.Measurability.Init
# [564/1969] Building Mathlib.CategoryTheory.Category.Init
# [564/1969] Building Mathlib.Tactic.Continuity.Init
# [564/1969] Building Mathlib.Tactic.SetLike
# [564/1969] Building Mathlib.Data.Option.Basic
# [564/1969] Building Mathlib.Tactic.Common
# [567/1969] Building Mathlib.Data.Opposite
# [567/1969] Building Mathlib.Control.Monad.Basic
# [567/1969] Building Mathlib.Tactic.ProdAssoc
# [567/1969] Building Mathlib.Tactic.ProxyType
# [567/1969] Building Mathlib.Data.Finite.Defs
# [567/1969] Building Mathlib.Order.Synonym
# [567/1969] Building Mathlib.Algebra.Opposites
# [567/1969] Building Mathlib.Control.Monad.Writer
# [567/1969] Building Mathlib.Logic.Small.Defs
# [568/1969] Building Mathlib.Control.EquivFunctor
# [569/1969] Building Mathlib.Logic.Equiv.Basic
# [570/1969] Building Mathlib.Tactic.Measurability
# [571/1969] Building Mathlib.Algebra.Field.IsField
# [572/1969] Building Mathlib.Logic.Pairwise
# [573/1969] Building Mathlib.Control.Bifunctor
# [574/1969] Building Mathlib.Algebra.Quotient
# [575/1969] Building Mathlib.Algebra.Group.Hom.Basic
# [576/1969] Building Mathlib.Tactic.Continuity
# [577/1969] Building Mathlib.Data.Sigma.Lex
# [578/1969] Building Mathlib.Algebra.Group.TypeTags
# [579/1969] Building Mathlib.Logic.UnivLE
# [580/1969] Building Mathlib.Combinatorics.Quiver.Basic
# [581/1969] Building Mathlib.Data.Countable.Defs
# [582/1969] Building Mathlib.Algebra.Group.OrderSynonym
# [583/1969] Building Mathlib.Order.Compare
# [584/1969] Building Mathlib.Order.Max
# [585/1969] Building Mathlib.Control.Monad.Cont
# [586/1969] Building Mathlib.Logic.Equiv.Option
# [589/1969] Building Mathlib.Algebra.Ring.Basic
# [591/1969] Building Mathlib.Logic.Equiv.Functor
# [597/1969] Building Mathlib.Combinatorics.Quiver.Push
# [597/1969] Building Mathlib.Combinatorics.Quiver.Path
# [597/1969] Building Mathlib.CategoryTheory.Category.Basic
# [598/1969] Building Mathlib.Algebra.Ring.OrderSynonym
# [598/1969] Building Mathlib.Algebra.GroupWithZero.Basic
# [600/1969] Building Mathlib.Order.Monotone.Basic
# [602/1969] Building Mathlib.Data.Nat.Basic
# [603/1969] Building Mathlib.Algebra.Ring.Hom.Defs
# [605/1969] Building Mathlib.Algebra.Group.Commute.Defs
# [608/1969] Building Mathlib.Data.Nat.Bits
# [608/1969] Building Mathlib.Data.List.EditDistance.Defs
# [608/1969] Building Mathlib.Tactic.Sat.FromLRAT
# [608/1969] Building Mathlib.Tactic.NormNum.Result
# [609/1969] Building Mathlib.Combinatorics.Quiver.Symmetric
# [610/1969] Building Mathlib.Algebra.GroupWithZero.InjSurj
# [612/1969] Building Mathlib.Algebra.Group.Commute.Basic
# [612/1969] Building Mathlib.Algebra.Group.Commute.Hom
# [615/1969] Building Mathlib.Tactic.Widget.CommDiag
# [615/1969] Building Mathlib.Tactic.CategoryTheory.Slice
# [615/1969] Building Mathlib.CategoryTheory.Functor.Basic
# [616/1969] Building Mathlib.Algebra.GroupPower.Basic
# [621/1969] Building Mathlib.Algebra.Ring.InjSurj
# [622/1969] Building Mathlib.Tactic.CategoryTheory.Reassoc
# [624/1969] Building Mathlib.Control.ULiftable
# [624/1969] Building Mathlib.Data.ULift
# [624/1969] Building Mathlib.Logic.Embedding.Basic
# [624/1969] Building Mathlib.Algebra.Group.Equiv.Basic
# [625/1969] Building Mathlib.CategoryTheory.NatTrans
# [625/1969] Building Mathlib.CategoryTheory.Iso
# [626/1969] Building Mathlib.Data.Int.Basic
# [626/1969] Building Mathlib.Order.Iterate
# [626/1969] Building Mathlib.Algebra.CovariantAndContravariant
# [626/1969] Building Mathlib.Order.Lattice
# [631/1969] Building Mathlib.Tactic.NormNum.Core
# [633/1969] Building Mathlib.Algebra.GroupPower.Hom
# [633/1969] Building Mathlib.Algebra.Divisibility.Basic
# [633/1969] Building Mathlib.Algebra.Group.Hom.Instances
# [633/1969] Building Mathlib.Algebra.Group.Units
# [634/1969] Building Mathlib.Algebra.Order.Ring.Lemmas
# [635/1969] Building Mathlib.Algebra.Group.Embedding
# [635/1969] Building Mathlib.Order.RelIso.Basic
# [635/1969] Building Mathlib.GroupTheory.GroupAction.Defs
# [639/1969] Building Mathlib.Algebra.EuclideanDomain.Defs
# [640/1969] Building Mathlib.CategoryTheory.Functor.Category
# [642/1969] Building Mathlib.Order.MinMax
# [642/1969] Building Mathlib.Order.BoundedOrder
# [643/1969] Building Mathlib.Algebra.Group.Equiv.TypeTags
# [643/1969] Building Mathlib.Algebra.Ring.Divisibility.Basic
# [643/1969] Building Mathlib.Algebra.Group.ULift
# [643/1969] Building Mathlib.Data.Nat.Cast.Basic
# [645/1969] Building Mathlib.Tactic.FunProp.Elab
# [647/1969] Building Mathlib.Tactic.FunProp
# [650/1969] Building Mathlib.Algebra.Order.Monoid.Lemmas
# [652/1969] Building Mathlib.Data.Prod.Lex
# [652/1969] Building Mathlib.Order.Disjoint
# [652/1969] Building Mathlib.Order.WithBot
# [655/1969] Building Mathlib.CategoryTheory.Thin
# [655/1969] Building Mathlib.CategoryTheory.NatIso
# [656/1969] Building Mathlib.GroupTheory.GroupAction.Ring
# [659/1969] Building Mathlib.Algebra.Divisibility.Units
# [659/1969] Building Mathlib.Data.Nat.Units
# [659/1969] Building Mathlib.Algebra.Group.Units.Hom
# [659/1969] Building Mathlib.Algebra.Group.Semiconj.Units
# [659/1969] Building Mathlib.GroupTheory.GroupAction.Units
# [659/1969] Building Mathlib.Algebra.GroupWithZero.Units.Basic
# [659/1969] Building Mathlib.Algebra.Group.Opposite
# [665/1969] Building Mathlib.Algebra.Group.Commute.Units
# [666/1969] Building Mathlib.CategoryTheory.Bicategory.Basic
# [666/1969] Building Mathlib.CategoryTheory.Functor.FullyFaithful
# [668/1969] Building Mathlib.Algebra.GroupWithZero.Divisibility
# [669/1969] Building Mathlib.Algebra.Ring.Units
# [669/1969] Building Mathlib.Algebra.Group.Units.Equiv
# [670/1969] Building Mathlib.Algebra.GroupWithZero.Semiconj
# [672/1969] Building Mathlib.Algebra.GroupWithZero.Commute
# [673/1969] Building Mathlib.Order.PropInstances
# [675/1969] Building Mathlib.Algebra.GroupWithZero.Units.Lemmas
# [676/1969] Building Mathlib.Algebra.Group.WithOne.Defs
# [676/1969] Building Mathlib.Order.Hom.Basic
# [677/1969] Building Mathlib.Algebra.GroupWithZero.Units.Equiv
# [678/1969] Building Mathlib.Data.Int.Units
# [678/1969] Building Mathlib.Algebra.Ring.Commute
# [680/1969] Building Mathlib.Algebra.Ring.Opposite
# [680/1969] Building Mathlib.GroupTheory.GroupAction.Opposite
# [680/1969] Building Mathlib.Algebra.Group.Prod
# [681/1969] Building Mathlib.Order.Heyting.Basic
# [682/1969] Building Mathlib.CategoryTheory.FullSubcategory
# [682/1969] Building Mathlib.CategoryTheory.Whiskering
# [684/1969] Building Mathlib.Data.Nat.Cast.Commute
# [686/1969] Building Mathlib.Algebra.GroupPower.IterateHom
# [687/1969] Building Mathlib.Algebra.Order.Monoid.NatCast
# [687/1969] Building Mathlib.Algebra.Order.Monoid.Defs
# [687/1969] Building Mathlib.Algebra.Order.Monoid.MinMax
# [687/1969] Building Mathlib.Algebra.Regular.Basic
# [687/1969] Building Mathlib.Algebra.Order.Sub.Defs
# [688/1969] Building Mathlib.CategoryTheory.EssentialImage
# [689/1969] Building Mathlib.Algebra.Invertible.Basic
# [689/1969] Building Mathlib.Data.Int.Cast.Field
# [689/1969] Building Mathlib.Algebra.Field.Basic
# [696/1969] Building Mathlib.Algebra.Ring.Regular
# [698/1969] Building Mathlib.Algebra.Order.Monoid.OrderDual
# [698/1969] Building Mathlib.Algebra.Order.Monoid.Canonical.Defs
# [699/1969] Building Mathlib.CategoryTheory.Bicategory.Functor
# [700/1969] Building Mathlib.Algebra.Order.Group.Defs
# [701/1969] Building Mathlib.Algebra.EuclideanDomain.Basic
# [702/1969] Building Mathlib.Algebra.Order.Monoid.Basic
# [702/1969] Building Mathlib.Tactic.ApplyFun
# [702/1969] Building Mathlib.Algebra.Order.Monoid.Units
# [702/1969] Building Mathlib.Order.Hom.Bounded
# [702/1969] Building Mathlib.Order.Antisymmetrization
# [702/1969] Building Mathlib.Data.Sum.Order
# [703/1969] Building Mathlib.Algebra.GroupPower.CovariantClass
# [704/1969] Building Mathlib.Tactic.NormNum.Basic
# [705/1969] Building Mathlib.Data.Nat.Cast.Prod
# [705/1969] Building Mathlib.GroupTheory.GroupAction.Prod
# [708/1969] Building Mathlib.Algebra.Order.Monoid.Prod
# [708/1969] Building Mathlib.Algebra.Order.Monoid.WithZero.Defs
# [708/1969] Building Mathlib.Algebra.Order.Sub.Canonical
# [708/1969] Building Mathlib.Algebra.Order.Monoid.TypeTags
# [708/1969] Building Mathlib.Algebra.Order.Monoid.WithTop
# [709/1969] Building Mathlib.Data.Int.Cast.Prod
# [718/1969] Building Mathlib.CategoryTheory.Equivalence
# [722/1969] Building Mathlib.Algebra.SMulWithZero
# [724/1969] Building Mathlib.Order.BooleanAlgebra
# [724/1969] Building Mathlib.Order.Estimator
# [725/1969] Building Mathlib.Algebra.Order.Sub.WithTop
# [725/1969] Building Mathlib.Data.Nat.Cast.WithTop
# [726/1969] Building Mathlib.Algebra.Regular.SMul
# [730/1969] Building Mathlib.Algebra.Order.Group.WithTop
# [730/1969] Building Mathlib.Algebra.Order.Group.Units
# [730/1969] Building Mathlib.Algebra.Order.Group.Instances
# [730/1969] Building Mathlib.Algebra.Order.Group.InjSurj
# [730/1969] Building Mathlib.Algebra.Order.Group.OrderIso
# [730/1969] Building Mathlib.Algebra.Order.Group.Prod
# [730/1969] Building Mathlib.Algebra.Order.Group.TypeTags
# [730/1969] Building Mathlib.Algebra.Order.Ring.Defs
# [732/1969] Building Mathlib.Algebra.Order.WithZero
# [736/1969] Building Mathlib.Algebra.Order.Group.Lattice
# [739/1969] Building Mathlib.Algebra.Order.Group.Abs
# [741/1969] Building Mathlib.Order.SymmDiff
# [743/1969] Building Mathlib.CategoryTheory.Bicategory.Free
# [744/1969] Building Mathlib.CategoryTheory.Category.Preorder
# [744/1969] Building Mathlib.CategoryTheory.Opposites
# [744/1969] Building Mathlib.CategoryTheory.Adjunction.Basic
# [745/1969] Building Mathlib.Order.Hom.Lattice
# [745/1969] Building Mathlib.Data.Set.Basic
# [746/1969] Building Mathlib.Algebra.Order.Group.MinMax
# [749/1969] Building Mathlib.Algebra.Order.Ring.CharZero
# [749/1969] Building Mathlib.Algebra.Order.Field.Defs
# [749/1969] Building Mathlib.Algebra.Order.Ring.InjSurj
# [749/1969] Building Mathlib.Algebra.Order.Positive.Ring
# [749/1969] Building Mathlib.Algebra.Order.Ring.Canonical
# [750/1969] Building Mathlib.Algebra.Order.Ring.WithTop
# [750/1969] Building Mathlib.Data.Nat.Order.Basic
# [752/1969] Building Mathlib.Algebra.Order.Field.Canonical.Defs
# [755/1969] Building Mathlib.Algebra.Order.Field.Canonical.Basic
# [756/1969] Building Mathlib.CategoryTheory.Functor.Const
# [756/1969] Building Mathlib.CategoryTheory.EqToHom
# [757/1969] Building Mathlib.Algebra.Order.Field.InjSurj
# [759/1969] Building Mathlib.Tactic.CategoryTheory.BicategoryCoherence
# [761/1969] Building Mathlib.CategoryTheory.Comma.Basic
# [761/1969] Building Mathlib.CategoryTheory.Category.ULift
# [761/1969] Building Mathlib.CategoryTheory.Bicategory.Strict
# [761/1969] Building Mathlib.CategoryTheory.DiscreteCategory
# [763/1969] Building Mathlib.CategoryTheory.Products.Basic
# [765/1969] Building Mathlib.Algebra.Ring.Hom.Basic
# [765/1969] Building Mathlib.Data.PEquiv
# [765/1969] Building Mathlib.Order.Circular
# [765/1969] Building Mathlib.Data.SetLike.Basic
# [765/1969] Building Mathlib.Data.Set.BoolIndicator
# [765/1969] Building Mathlib.Order.WellFounded
# [765/1969] Building Mathlib.Data.Part
# [765/1969] Building Mathlib.Data.Set.Image
# [765/1969] Building Mathlib.Data.Set.Intervals.Basic
# [767/1969] Building Mathlib.Data.Nat.Cast.Order
# [767/1969] Building Mathlib.Data.Nat.ForSqrt
# [767/1969] Building Mathlib.Data.Vector
# [767/1969] Building Mathlib.Data.Nat.MaxPowDiv
# [767/1969] Building Mathlib.Algebra.GroupPower.Ring
# [767/1969] Building Mathlib.Data.Nat.WithBot
# [768/1969] Building Mathlib.Data.PNat.Basic
# [769/1969] Building Mathlib.Data.Int.Order.Basic
# [770/1969] Building Mathlib.Data.Nat.Order.Lemmas
# [771/1969] Building Mathlib.Data.List.Basic
# [774/1969] Building Mathlib.CategoryTheory.PUnit
# [774/1969] Building Mathlib.CategoryTheory.PEmpty
# [779/1969] Building Mathlib.Tactic.Linarith.Lemmas
# [779/1969] Building Mathlib.Algebra.Order.Invertible
# [780/1969] Building Mathlib.Algebra.GroupPower.Order
# [780/1969] Building Mathlib.Algebra.Order.Ring.Pow
# [784/1969] Building Mathlib.Data.Nat.GCD.Basic
# [785/1969] Building Mathlib.Data.Int.Dvd.Basic
# [785/1969] Building Mathlib.Data.Int.Range
# [785/1969] Building Mathlib.Algebra.GroupWithZero.Power
# [785/1969] Building Mathlib.Data.Int.LeastGreatest
# [785/1969] Building Mathlib.Algebra.EuclideanDomain.Instances
# [785/1969] Building Mathlib.Data.Int.Cast.Lemmas
# [785/1969] Building Mathlib.Data.Rat.Defs
# [793/1969] Building Mathlib.Data.Int.Div
# [795/1969] Building Mathlib.Logic.Embedding.Set
# [795/1969] Building Mathlib.Data.Bool.Set
# [795/1969] Building Mathlib.Data.Nat.Set
# [795/1969] Building Mathlib.Data.Set.Prod
# [795/1969] Building Mathlib.Data.Set.Sigma
# [795/1969] Building Mathlib.Order.Directed
# [802/1969] Building Mathlib.Data.Rat.Basic
# [803/1969] Building Mathlib.Order.RelIso.Set
# [806/1969] Building Mathlib.Data.Nat.Pow
# [806/1969] Building Mathlib.Algebra.Order.Ring.Abs
# [806/1969] Building Mathlib.Data.Nat.Size
# [809/1969] Building Mathlib.Data.Nat.Factorial.Basic
# [811/1969] Building Mathlib.Data.Set.Intervals.WithBotTop
# [811/1969] Building Mathlib.Data.Set.Intervals.Instances
# [811/1969] Building Mathlib.Order.Bounded
# [811/1969] Building Mathlib.Data.Nat.Log
# [812/1969] Building Mathlib.Data.Int.Order.Lemmas
# [812/1969] Building Mathlib.Algebra.Parity
# [812/1969] Building Mathlib.Data.Int.Order.Units
# [813/1969] Building Mathlib.Tactic.Positivity.Core
# [813/1969] Building Mathlib.Algebra.Field.Opposite
# [813/1969] Building Mathlib.Data.Rat.Order
# [813/1969] Building Mathlib.Data.Set.Intervals.Group
# [813/1969] Building Mathlib.Tactic.NormNum.Pow
# [813/1969] Building Mathlib.Data.Rat.Lemmas
# [816/1969] Building Mathlib.Data.Nat.Choose.Basic
# [817/1969] Building Mathlib.Data.Set.NAry
# [817/1969] Building Mathlib.Data.Set.Function
# [824/1969] Building Mathlib.CategoryTheory.Pi.Basic
# [824/1969] Building Mathlib.CategoryTheory.Functor.Currying
# [824/1969] Building Mathlib.CategoryTheory.Monoidal.Category
# [825/1969] Building Mathlib.Order.Bounds.Basic
# [827/1969] Building Mathlib.Data.Nat.Sqrt
# [827/1969] Building Mathlib.Algebra.Associated
# [829/1969] Building Mathlib.Data.Rat.Cast.Defs
# [832/1969] Building Mathlib.Tactic.FieldSimp
# [833/1969] Building Mathlib.Tactic.NormNum.OfScientific
# [834/1969] Building Mathlib.Data.Set.Intervals.Monoid
# [834/1969] Building Mathlib.Data.Set.Intervals.Image
# [834/1969] Building Mathlib.Data.Set.Pairwise.Basic
# [834/1969] Building Mathlib.Algebra.Group.Pi
# [834/1969] Building Mathlib.Logic.Equiv.PartialEquiv
# [834/1969] Building Mathlib.Logic.Equiv.Set
# [835/1969] Building Mathlib.Order.LatticeIntervals
# [835/1969] Building Mathlib.Data.Int.GCD
# [836/1969] Building Mathlib.Data.Set.List
# [836/1969] Building Mathlib.Data.List.Pairwise
# [836/1969] Building Mathlib.Data.List.Lex
# [836/1969] Building Mathlib.Data.List.Infix
# [836/1969] Building Mathlib.Data.List.Lattice
# [837/1969] Building Mathlib.Data.List.MinMax
# [838/1969] Building Mathlib.Data.List.Palindrome
# [839/1969] Building Mathlib.Data.Nat.Bitwise
# [840/1969] Building Mathlib.CategoryTheory.Comma.Arrow
# [848/1969] Building Mathlib.Data.Set.Intervals.UnorderedInterval
# [850/1969] Building Mathlib.Data.List.Forall2
# [851/1969] Building Mathlib.Logic.Small.Basic
# [851/1969] Building Mathlib.Order.InitialSeg
# [851/1969] Building Mathlib.Order.Hom.Set
# [851/1969] Building Mathlib.Algebra.Ring.Equiv
# [852/1969] Building Mathlib.Algebra.Ring.Pi
# [852/1969] Building Mathlib.GroupTheory.GroupAction.Pi
# [852/1969] Building Mathlib.Data.Pi.Lex
# [852/1969] Building Mathlib.GroupTheory.Perm.Basic
# [853/1969] Building Mathlib.CategoryTheory.CommSq
# [856/1969] Building Mathlib.Data.Int.Bitwise
# [857/1969] Building Mathlib.Order.Bounds.OrderIso
# [857/1969] Building Mathlib.Order.Antichain
# [857/1969] Building Mathlib.Data.Fin.Basic
# [857/1969] Building Mathlib.Order.CompleteLattice
# [857/1969] Building Mathlib.Data.Set.Intervals.OrderIso
# [858/1969] Building Mathlib.Data.List.EditDistance.Bounds
# [859/1969] Building Mathlib.Data.List.Chain
# [860/1969] Building Mathlib.Data.List.BigOperators.Basic
# [861/1969] Building Mathlib.Data.List.Nodup
# [862/1969] Building Mathlib.Algebra.Order.Field.Basic
# [863/1969] Building Mathlib.Algebra.Order.Pi
# [864/1969] Building Mathlib.CategoryTheory.LiftingProperties.Basic
# [868/1969] Building Mathlib.Data.Set.Intervals.OrderEmbedding
# [869/1969] Building Mathlib.CategoryTheory.LiftingProperties.Adjunction
# [870/1969] Building Mathlib.Data.List.EditDistance.Estimator
# [872/1969] Building Mathlib.Algebra.GroupWithZero.Bitwise
# [872/1969] Building Mathlib.Data.Int.Lemmas
# [874/1969] Building Mathlib.Algebra.GCDMonoid.Basic
# [874/1969] Building Mathlib.Data.Nat.Prime
# [876/1969] Building Mathlib.Algebra.Group.Aut
# [876/1969] Building Mathlib.Dynamics.FixedPoints.Basic
# [876/1969] Building Mathlib.GroupTheory.Perm.ViaEmbedding
# [877/1969] Building Mathlib.Data.Prod.TProd
# [877/1969] Building Mathlib.Data.List.Duplicate
# [880/1969] Building Mathlib.Algebra.Ring.ULift
# [880/1969] Building Mathlib.Algebra.Ring.CompTypeclasses
# [880/1969] Building Mathlib.Algebra.Ring.Prod
# [882/1969] Building Mathlib.CategoryTheory.Groupoid
# [889/1969] Building Mathlib.CategoryTheory.EpiMono
# [891/1969] Building Mathlib.GroupTheory.GroupAction.Group
# [891/1969] Building Mathlib.Algebra.Group.Conj
# [892/1969] Building Mathlib.Data.List.Count
# [892/1969] Building Mathlib.Data.List.Join
# [892/1969] Building Mathlib.Data.List.Zip
# [892/1969] Building Mathlib.Algebra.FreeMonoid.Basic
# [892/1969] Building Mathlib.Data.List.BigOperators.Lemmas
# [893/1969] Building Mathlib.CategoryTheory.Monoidal.Functor
# [894/1969] Building Mathlib.CategoryTheory.Balanced
# [894/1969] Building Mathlib.CategoryTheory.Types
# [895/1969] Building Mathlib.Data.PNat.Prime
# [895/1969] Building Mathlib.Tactic.NormNum.Prime
# [897/1969] Building Mathlib.Data.List.Dedup
# [897/1969] Building Mathlib.CategoryTheory.Limits.Shapes.StrongEpi
# [898/1969] Building Mathlib.Control.Random
# [898/1969] Building Mathlib.Data.Fin.Tuple.Basic
# [899/1969] Building Mathlib.Algebra.Order.Kleene
# [901/1969] Building Mathlib.Data.List.Permutation
# [905/1969] Building Mathlib.Testing.SlimCheck.Gen
# [906/1969] Building Mathlib.Order.CompleteBooleanAlgebra
# [906/1969] Building Mathlib.Order.GaloisConnection
# [907/1969] Building Mathlib.CategoryTheory.Functor.EpiMono
# [908/1969] Building Mathlib.CategoryTheory.Category.Cat
# [908/1969] Building Mathlib.CategoryTheory.Functor.Hom
# [912/1969] Building Mathlib.Testing.SlimCheck.Sampleable
# [913/1969] Building Mathlib.CategoryTheory.Yoneda
# [914/1969] Building Mathlib.Data.List.Range
# [914/1969] Building Mathlib.Data.List.Rotate
# [915/1969] Building Mathlib.Data.List.Perm
# [917/1969] Building Mathlib.Data.List.NatAntidiagonal
# [918/1969] Building Mathlib.Algebra.GroupRingAction.Basic
# [919/1969] Building Mathlib.CategoryTheory.Functor.ReflectsIso
# [920/1969] Building Mathlib.Testing.SlimCheck.Testable
# [921/1969] Building Mathlib.CategoryTheory.IsomorphismClasses
# [924/1969] Building Mathlib.Data.Setoid.Basic
# [924/1969] Building Mathlib.Order.Hom.Order
# [926/1969] Building Mathlib.Algebra.Ring.Aut
# [927/1969] Building Mathlib.CategoryTheory.Skeletal
# [928/1969] Building Mathlib.Data.Nat.Cast.Field
# [928/1969] Building Mathlib.Tactic.CancelDenoms.Core
# [929/1969] Building Mathlib.Order.FixedPoints
# [930/1969] Building Mathlib.Tactic.SlimCheck
# [932/1969] Building Mathlib.Algebra.Star.Basic
# [934/1969] Building Mathlib.Data.Set.Lattice
# [936/1969] Building Mathlib.Data.Fin.VecNotation
# [936/1969] Building Mathlib.Data.List.OfFn
# [939/1969] Building Mathlib.CategoryTheory.EssentiallySmall
# [940/1969] Building Mathlib.CategoryTheory.Monoidal.Free.Basic
# [941/1969] Building Mathlib.Data.List.Sublists
# [941/1969] Building Mathlib.Data.List.Prime
# [941/1969] Building Mathlib.Data.Multiset.Basic
# [942/1969] Building Mathlib.Logic.Equiv.Fin
# [945/1969] Building Mathlib.Data.List.Sort
# [945/1969] Building Mathlib.Data.List.FinRange
# [945/1969] Building Mathlib.Data.List.Indexes
# [945/1969] Building Mathlib.Data.Vector.Basic
# [946/1969] Building Mathlib.CategoryTheory.Limits.Cones
# [951/1969] Building Mathlib.Algebra.Ring.Fin
# [952/1969] Building Mathlib.Algebra.Star.Pi
# [952/1969] Building Mathlib.Algebra.Star.Prod
# [954/1969] Building Mathlib.Data.Nat.Factors
# [954/1969] Building Mathlib.Data.List.NodupEquivFin
# [957/1969] Building Mathlib.Tactic.CategoryTheory.Coherence
# [959/1969] Building Mathlib.Data.Set.Intervals.Disjoint
# [959/1969] Building Mathlib.Tactic.Monotonicity.Lemmas
# [959/1969] Building Mathlib.Data.Set.Accumulate
# [959/1969] Building Mathlib.Data.Set.Intervals.OrdConnected
# [959/1969] Building Mathlib.Data.Set.Intervals.Pi
# [959/1969] Building Mathlib.Data.Set.UnionLift
# [959/1969] Building Mathlib.Topology.Defs.Basic
# [959/1969] Building Mathlib.Data.Nat.Pairing
# [959/1969] Building Mathlib.Data.Set.Functor
# [959/1969] Building Mathlib.Order.Chain
# [959/1969] Building Mathlib.Order.Closure
# [959/1969] Building Mathlib.Order.Hom.CompleteLattice
# [959/1969] Building Mathlib.Data.Set.Pointwise.Basic
# [959/1969] Building Mathlib.GroupTheory.Subsemigroup.Basic
# [959/1969] Building Mathlib.Order.ConditionallyCompleteLattice.Basic
# [961/1969] Building Mathlib.Tactic.Monotonicity
# [965/1969] Building Mathlib.Data.Set.Intervals.ProjIcc
# [965/1969] Building Mathlib.Order.Cover
# [965/1969] Building Mathlib.Data.Set.Intervals.OrdConnectedComponent
# [965/1969] Building Mathlib.Order.UpperLower.Basic
# [968/1969] Building Mathlib.Order.OmegaCompletePartialOrder
# [968/1969] Building Mathlib.Order.Zorn
# [970/1969] Building Mathlib.Logic.Equiv.Nat
# [971/1969] Building Mathlib.GroupTheory.Subsemigroup.Membership
# [971/1969] Building Mathlib.GroupTheory.Submonoid.Basic
# [971/1969] Building Mathlib.GroupTheory.Subsemigroup.Operations
# [972/1969] Building Mathlib.Data.Countable.Basic
# [972/1969] Building Mathlib.Logic.Encodable.Basic
# [975/1969] Building Mathlib.SetTheory.Cardinal.SchroederBernstein
# [982/1969] Building Mathlib.Algebra.Function.Support
# [982/1969] Building Mathlib.Order.ModularLattice
# [982/1969] Building Mathlib.Order.SuccPred.Basic
# [985/1969] Building Mathlib.Logic.Encodable.Lattice
# [985/1969] Building Mathlib.Data.Rat.Encodable
# [986/1969] Building Mathlib.GroupTheory.Submonoid.MulOpposite
# [987/1969] Building Mathlib.Order.Atoms
# [988/1969] Building Mathlib.Data.Set.Pointwise.ListOfFn
# [988/1969] Building Mathlib.Data.Set.Semiring
# [988/1969] Building Mathlib.Data.Set.Pointwise.Interval
# [991/1969] Building Mathlib.Algebra.Function.Indicator
# [991/1969] Building Mathlib.Data.Int.CharZero
# [991/1969] Building Mathlib.Algebra.CharZero.Lemmas
# [992/1969] Building Mathlib.GroupTheory.Subsemigroup.Center
# [992/1969] Building Mathlib.GroupTheory.Submonoid.Operations
# [995/1969] Building Mathlib.Data.Rat.Cast.CharZero
# [995/1969] Building Mathlib.Tactic.Positivity.Basic
# [995/1969] Building Mathlib.Tactic.Qify
# [996/1969] Building Mathlib.Data.Nat.SuccPred
# [996/1969] Building Mathlib.Order.SuccPred.Relation
# [996/1969] Building Mathlib.Order.SuccPred.Limit
# ...
# [1778/1969] Building Mathlib.RingTheory.FiniteType
# [1780/1969] Building Mathlib.LinearAlgebra.Matrix.Nondegenerate
# [1780/1969] Building Mathlib.LinearAlgebra.Matrix.SpecialLinearGroup
# [1781/1969] Building Mathlib.RingTheory.JacobsonIdeal
# [1784/1969] Building Mathlib.FieldTheory.Finiteness
# [1784/1969] Building Mathlib.LinearAlgebra.Dimension.DivisionRing
# [1786/1969] Building Mathlib.RingTheory.Ideal.LocalRing
# [1787/1969] Building Mathlib.RingTheory.FinitePresentation
# [1788/1969] Building Mathlib.Analysis.NormedSpace.IsROrC
# [1788/1969] Building Mathlib.Analysis.NormedSpace.Banach
# [1788/1969] Building Mathlib.Analysis.NormedSpace.Completion
# [1788/1969] Building Mathlib.Analysis.Calculus.FDeriv.Basic
# [1788/1969] Building Mathlib.Analysis.NormedSpace.Multilinear.Basic
# [1792/1969] Building Mathlib.Data.Polynomial.Expand
# [1792/1969] Building Mathlib.RingTheory.Localization.AtPrime
# [1792/1969] Building Mathlib.RingTheory.PowerSeries.Basic
# [1793/1969] Building Mathlib.LinearAlgebra.Dimension.LinearMap
# [1793/1969] Building Mathlib.LinearAlgebra.FiniteDimensional
# [1799/1969] Building Mathlib.Analysis.Calculus.FDeriv.RestrictScalars
# [1799/1969] Building Mathlib.Analysis.Calculus.Deriv.Basic
# [1799/1969] Building Mathlib.Analysis.Calculus.FDeriv.Comp
# [1801/1969] Building Mathlib.LinearAlgebra.AffineSpace.FiniteDimensional
# [1801/1969] Building Mathlib.RingTheory.TensorProduct
# [1801/1969] Building Mathlib.LinearAlgebra.Matrix.NonsingularInverse
# [1803/1969] Building Mathlib.Analysis.Calculus.Deriv.Slope
# [1803/1969] Building Mathlib.Analysis.Calculus.Deriv.Comp
# [1806/1969] Building Mathlib.Analysis.Convex.Between
# [1808/1969] Building Mathlib.LinearAlgebra.UnitaryGroup
# [1808/1969] Building Mathlib.LinearAlgebra.Matrix.GeneralLinearGroup
# [1808/1969] Building Mathlib.LinearAlgebra.Determinant
# [1808/1969] Building Mathlib.LinearAlgebra.Matrix.Block
# [1808/1969] Building Mathlib.Topology.Instances.Matrix
# [1811/1969] Building Mathlib.LinearAlgebra.Vandermonde
# [1812/1969] Building Mathlib.RingTheory.HahnSeries
# [1814/1969] Building Mathlib.Analysis.NormedSpace.Multilinear.Curry
# [1814/1969] Building Mathlib.Analysis.NormedSpace.BoundedLinearMaps
# [1815/1969] Building Mathlib.Analysis.Convex.Normed
# [1816/1969] Building Mathlib.LinearAlgebra.Matrix.ToLinearEquiv
# [1817/1969] Building Mathlib.Analysis.Convex.StrictConvexSpace
# [1818/1969] Building Mathlib.Analysis.Convex.Uniform
# [1819/1969] Building Mathlib.LinearAlgebra.Matrix.SesquilinearForm
# [1821/1969] Building Mathlib.RingTheory.MatrixAlgebra
# [1822/1969] Building Mathlib.Analysis.Calculus.FDeriv.Linear
# [1823/1969] Building Mathlib.Topology.Algebra.Module.Determinant
# [1824/1969] Building Mathlib.Analysis.Calculus.Deriv.Linear
# [1824/1969] Building Mathlib.Analysis.Calculus.FDeriv.Prod
# [1824/1969] Building Mathlib.Analysis.Calculus.FDeriv.Add
# [1824/1969] Building Mathlib.Analysis.Calculus.FDeriv.Equiv
# [1827/1969] Building Mathlib.RingTheory.PolynomialAlgebra
# [1828/1969] Building Mathlib.Analysis.Calculus.Deriv.Inverse
# [1829/1969] Building Mathlib.RingTheory.LaurentSeries
# [1830/1969] Building Mathlib.LinearAlgebra.Matrix.Charpoly.Basic
# [1831/1969] Building Mathlib.Analysis.Calculus.FDeriv.Bilinear
# [1833/1969] Building Mathlib.Analysis.Calculus.Deriv.Add
# [1833/1969] Building Mathlib.Analysis.Calculus.Conformal.NormedSpace
# [1833/1969] Building Mathlib.Analysis.Calculus.FDeriv.Pi
# [1834/1969] Building Mathlib.Analysis.Calculus.FormalMultilinearSeries
# [1837/1969] Building Mathlib.LinearAlgebra.Matrix.Charpoly.Coeff
# [1838/1969] Building Mathlib.FieldTheory.RatFunc
# [1839/1969] Building Mathlib.Analysis.Calculus.FDeriv.Mul
# [1840/1969] Building Mathlib.Analysis.Calculus.LocalExtr.Basic
# [1840/1969] Building Mathlib.Analysis.Calculus.Deriv.AffineMap
# [1842/1969] Building Mathlib.Analysis.Calculus.LocalExtr.Rolle
# [1844/1969] Building Mathlib.Analysis.Calculus.ContDiff.Defs
# [1846/1969] Building Mathlib.LinearAlgebra.Matrix.Charpoly.LinearMap
# [1847/1969] Building Mathlib.RingTheory.IntegralClosure
# [1848/1969] Building Mathlib.FieldTheory.Minpoly.Basic
# [1848/1969] Building Mathlib.RingTheory.Algebraic
# [1849/1969] Building Mathlib.Analysis.Calculus.Deriv.Mul
# [1851/1969] Building Mathlib.FieldTheory.Minpoly.Field
# [1851/1969] Building Mathlib.RingTheory.Localization.Integral
# [1853/1969] Building Mathlib.Analysis.Calculus.Deriv.Pow
# [1853/1969] Building Mathlib.Analysis.Calculus.Deriv.Inv
# [1853/1969] Building Mathlib.Analysis.Calculus.MeanValue
# [1855/1969] Building Mathlib.RingTheory.PowerBasis
# [1855/1969] Building Mathlib.LinearAlgebra.Charpoly.Basic
# [1856/1969] Building Mathlib.RingTheory.IntegrallyClosed
# [1856/1969] Building Mathlib.RingTheory.Ideal.Over
# [1858/1969] Building Mathlib.Algebra.GCDMonoid.IntegrallyClosed
# [1858/1969] Building Mathlib.RingTheory.Polynomial.RationalRoot
# [1859/1969] Building Mathlib.LinearAlgebra.FreeModule.StrongRankCondition
# [1860/1969] Building Mathlib.LinearAlgebra.FreeModule.Finite.Matrix
# [1860/1969] Building Mathlib.LinearAlgebra.Dual
# [1863/1969] Building Mathlib.FieldTheory.Tower
# [1863/1969] Building Mathlib.Topology.Algebra.Module.FiniteDimension
# [1865/1969] Building Mathlib.Analysis.Calculus.IteratedDeriv.Defs
# [1865/1969] Building Mathlib.Analysis.Calculus.ContDiff.IsROrC
# [1865/1969] Building Mathlib.Analysis.Calculus.ContDiff.Basic
# [1866/1969] Building Mathlib.RingTheory.DedekindDomain.Basic
# [1867/1969] Building Mathlib.Data.Complex.Module
# [1867/1969] Building Mathlib.FieldTheory.IntermediateField
# [1870/1969] Building Mathlib.LinearAlgebra.Matrix.Charpoly.Minpoly
# [1870/1969] Building Mathlib.FieldTheory.Separable
# [1870/1969] Building Mathlib.RingTheory.AdjoinRoot
# [1870/1969] Building Mathlib.RingTheory.Adjoin.PowerBasis
# [1874/1969] Building Mathlib.Analysis.Complex.Basic
# [1875/1969] Building Mathlib.FieldTheory.Finite.Basic
# [1876/1969] Building Mathlib.MeasureTheory.Constructions.BorelSpace.ContinuousLinearMap
# [1876/1969] Building Mathlib.Analysis.NormedSpace.FiniteDimension
# [1879/1969] Building Mathlib.NumberTheory.LegendreSymbol.QuadraticChar.Basic
# [1880/1969] Building Mathlib.NumberTheory.LegendreSymbol.Basic
# [1882/1969] Building Mathlib.Data.IsROrC.Lemmas
# [1884/1969] Building Mathlib.Analysis.SpecialFunctions.Exp
# [1884/1969] Building Mathlib.Analysis.InnerProductSpace.Basic
# [1885/1969] Building Mathlib.Analysis.SpecialFunctions.Log.Basic
# [1885/1969] Building Mathlib.Analysis.Complex.Circle
# [1885/1969] Building Mathlib.Analysis.SpecialFunctions.Trigonometric.Basic
# [1886/1969] Building Mathlib.RingTheory.Adjoin.Field
# [1887/1969] Building Mathlib.LinearAlgebra.Contraction
# [1887/1969] Building Mathlib.LinearAlgebra.BilinearForm.Properties
# [1888/1969] Building Mathlib.Analysis.Complex.Isometry
# [1889/1969] Building Mathlib.FieldTheory.SplittingField.IsSplittingField
# [1890/1969] Building Mathlib.FieldTheory.SplittingField.Construction
# [1890/1969] Building Mathlib.FieldTheory.Adjoin
# [1891/1969] Building Mathlib.Tactic.FunProp.Continuous
# [1893/1969] Building Mathlib.Analysis.SpecialFunctions.Trigonometric.Inverse
# [1893/1969] Building Mathlib.Analysis.SpecialFunctions.Trigonometric.Angle
# [1894/1969] Building Mathlib.Analysis.Complex.Conformal
# [1895/1969] Building Mathlib.FieldTheory.Perfect
# [1895/1969] Building Mathlib.RingTheory.Polynomial.GaussLemma
# [1896/1969] Building Mathlib.LinearAlgebra.Trace
# [1898/1969] Building Mathlib.LinearAlgebra.BilinearForm.Orthogonal
# [1898/1969] Building Mathlib.LinearAlgebra.BilinearForm.DualLattice
# [1898/1969] Building Mathlib.LinearAlgebra.Matrix.BilinearForm
# [1901/1969] Building Mathlib.FieldTheory.Minpoly.IsIntegrallyClosed
# [1903/1969] Building Mathlib.Analysis.SpecialFunctions.Complex.Arg
# [1905/1969] Building Mathlib.RingTheory.RootsOfUnity.Minpoly
# [1908/1969] Building Mathlib.Tactic.FunProp.Measurable
# [1908/1969] Building Mathlib.Analysis.Complex.RealDeriv
# [1908/1969] Building Mathlib.Analysis.Calculus.IteratedDeriv.Lemmas
# [1909/1969] Building Mathlib.Analysis.SpecialFunctions.Complex.Log
# [1912/1969] Building Mathlib.Analysis.SpecialFunctions.Pow.Complex
# [1912/1969] Building Mathlib.RingTheory.RootsOfUnity.Complex
# [1913/1969] Building Mathlib.Analysis.SpecialFunctions.ExpDeriv
# [1914/1969] Building Mathlib.RingTheory.Polynomial.Cyclotomic.Basic
# [1915/1969] Building Mathlib.Analysis.SpecialFunctions.Pow.Real
# [1916/1969] Building Mathlib.Analysis.SpecialFunctions.Log.Deriv
# [1917/1969] Building Mathlib.RingTheory.Polynomial.Cyclotomic.Roots
# [1918/1969] Building Mathlib.FieldTheory.Extension
# [1919/1969] Building Mathlib.Analysis.Convex.SpecificFunctions.Basic
# [1919/1969] Building Mathlib.Analysis.SpecialFunctions.Pow.NNReal
# [1920/1969] Building Mathlib.Analysis.Complex.Arg
# [1920/1969] Building Mathlib.Analysis.InnerProductSpace.Symmetric
# [1920/1969] Building Mathlib.Analysis.InnerProductSpace.Orthogonal
# [1921/1969] Building Mathlib.RingTheory.Polynomial.Cyclotomic.Expand
# [1923/1969] Building Mathlib.RingTheory.Polynomial.Cyclotomic.Eval
# [1924/1969] Building Mathlib.Tactic.FunProp.Differentiable
# [1927/1969] Building Mathlib.Tactic.FunProp.ContDiff
# [1929/1969] Building Mathlib.Analysis.MeanInequalities
# [1930/1969] Building Mathlib.Analysis.InnerProductSpace.Projection
# [1933/1969] Building Mathlib.FieldTheory.Normal
# [1934/1969] Building Mathlib.Analysis.NormedSpace.PiLp
# [1936/1969] Building Mathlib.FieldTheory.NormalClosure
# [1936/1969] Building Mathlib.FieldTheory.IsAlgClosed.Basic
# [1936/1969] Building Mathlib.FieldTheory.Fixed
# [1939/1969] Building Mathlib.FieldTheory.IsAlgClosed.AlgebraicClosure
# [1940/1969] Building Mathlib.Analysis.InnerProductSpace.PiL2
# [1941/1969] Building Mathlib.FieldTheory.PrimitiveElement
# [1942/1969] Building Mathlib.FieldTheory.Minpoly.MinpolyDiv
# [1942/1969] Building Mathlib.FieldTheory.Galois
# [1944/1969] Building Mathlib.FieldTheory.Finite.GaloisField
# [1944/1969] Building Mathlib.RingTheory.Norm
# [1944/1969] Building Mathlib.RingTheory.Trace
# [1945/1969] Building Mathlib.MeasureTheory.Measure.Haar.OfBasis
# [1947/1969] Building Mathlib.Tactic.FunProp.AEMesurable
# [1950/1969] Building Mathlib.FieldTheory.Finite.Trace
# [1950/1969] Building Mathlib.RingTheory.DedekindDomain.IntegralClosure
# [1952/1969] Building Mathlib.NumberTheory.NumberField.Basic
# [1953/1969] Building Mathlib.NumberTheory.Cyclotomic.Basic
# [1954/1969] Building Mathlib.NumberTheory.Cyclotomic.PrimitiveRoots
# [1955/1969] Building Mathlib.NumberTheory.LegendreSymbol.AddCharacter
# [1956/1969] Building Mathlib.NumberTheory.LegendreSymbol.GaussSum
# [1957/1969] Building Mathlib.NumberTheory.LegendreSymbol.QuadraticChar.GaussSum
# [1958/1969] Building Mathlib.NumberTheory.LegendreSymbol.QuadraticReciprocity
# [1959/1969] Building Mathlib.NumberTheory.LegendreSymbol.JacobiSymbol
# [1960/1969] Building Mathlib.Tactic.NormNum.LegendreSymbol
# [1961/1969] Building Mathlib.Tactic
# [1962/1969] Building MIL.Common
# [1963/1969] Building MIL.C02_Basics.solutions.Solutions_S05_Proving_Facts_about_Algebraic_Structures
# [1963/1969] Building MIL.C03_Logic.solutions.Solutions_S02_The_Existential_Quantifier
# [1963/1969] Building MIL.C02_Basics.solutions.Solutions_S04_More_on_Order_and_Divisibility
# [1963/1969] Building MIL.C03_Logic.solutions.Solutions_S01_Implication_and_the_Universal_Quantifier
# [1963/1969] Building MIL.C02_Basics.solutions.Solutions_S03_Using_Theorems_and_Lemmas
# stdout:
# min_le_left a b : min a b ≤ a
# min_le_right a b : min a b ≤ b
# le_min : c ≤ a → c ≤ b → c ≤ min a b
# Nat.gcd_zero_right n : Nat.gcd n 0 = n
# Nat.gcd_zero_left n : Nat.gcd 0 n = n
# Nat.lcm_zero_right n : Nat.lcm n 0 = 0
# Nat.lcm_zero_left n : Nat.lcm 0 n = 0
# stdout:
# ./././MIL/C03_Logic/solutions/Solutions_S01_Implication_and_the_Universal_Quantifier.lean:56:6: warning: unused variable `a` [linter.unusedVariables]
# ./././MIL/C03_Logic/solutions/Solutions_S01_Implication_and_the_Universal_Quantifier.lean:56:8: warning: unused variable `b` [linter.unusedVariables]
# ./././MIL/C03_Logic/solutions/Solutions_S01_Implication_and_the_Universal_Quantifier.lean:65:6: warning: unused variable `a` [linter.unusedVariables]
# ./././MIL/C03_Logic/solutions/Solutions_S01_Implication_and_the_Universal_Quantifier.lean:65:8: warning: unused variable `b` [linter.unusedVariables]
# ./././MIL/C03_Logic/solutions/Solutions_S01_Implication_and_the_Universal_Quantifier.lean:103:18: warning: unused variable `x` [linter.unusedVariables]
# stdout:
# inf_sup_left : x ⊓ (y ⊔ z) = x ⊓ y ⊔ x ⊓ z
# inf_sup_right : (x ⊔ y) ⊓ z = x ⊓ z ⊔ y ⊓ z
# sup_inf_left : x ⊔ y ⊓ z = (x ⊔ y) ⊓ (x ⊔ z)
# sup_inf_right : x ⊓ y ⊔ z = (x ⊔ z) ⊓ (y ⊔ z)
# [1968/1969] Building MIL
# 2024-04-26 22:59:07.880 | INFO     | __main__:main:188 - Tracing math-in-lean
# 2024-04-26 22:59:07.913 | DEBUG    | __main__:main:193 - /home/mcwave/.elan/bin/lake env lean --threads 20 --run ExtractData.lean
#  98%|█████████▊| 2688/2736 [22:01<00:11,  4.31it/s]2024-04-26 23:21:14,423	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2729/2729 [02:50<00:00, 16.04it/s]
# 2024-04-26 23:24:17.727 | WARNING  | lean_dojo.data_extraction.lean:__post_init__:442 - LeanGitRepo(url='https://github.com/leanprover-community/quote4', commit='1c88406514a636d241903e2e288d21dc6d861e01') relies on an unsupported Lean version: ec941735c80dc54c53948e30c428905b6600f95a
# 2024-04-26 23:24:19.672 | WARNING  | lean_dojo.data_extraction.lean:__post_init__:442 - LeanGitRepo(url='https://github.com/leanprover/lean4-cli', commit='a751d21d4b68c999accb6fc5d960538af26ad5ec') relies on an unsupported Lean version: ec941735c80dc54c53948e30c428905b6600f95a
# 2024-04-26 23:24:47.047 | WARNING  | lean_dojo.data_extraction.lean:__post_init__:442 - LeanGitRepo(url='https://github.com/leanprover/lean4-cli', commit='be8fa79a28b8b6897dce0713ef50e89c4a0f6ef5') relies on an unsupported Lean version: ec941735c80dc54c53948e30c428905b6600f95a
# 2024-04-26 23:25:04.991 | WARNING  | lean_dojo.data_extraction.lean:__post_init__:442 - LeanGitRepo(url='https://github.com/xubaiw/CMark.lean', commit='0077cbbaa92abf855fc1c0413e158ffd8195ec77') relies on an unsupported Lean version: 8fc1af650ad6d31cf766d9bc84119149330e7d4e
# Following Github server redirection from /repos/mhuisi/lean4-cli to /repositories/341363356
# 2024-04-26 23:25:20.509 | WARNING  | lean_dojo.data_extraction.lean:__post_init__:442 - LeanGitRepo(url='https://github.com/mhuisi/lean4-cli', commit='39229f3630d734af7d9cfb5937ddc6b41d3aa6aa') relies on an unsupported Lean version: 216d2460e0adec8317fdeeb6f2543cb7442564fd
# 2024-04-26 23:25:31.586 | WARNING  | lean_dojo.data_extraction.lean:__post_init__:442 - LeanGitRepo(url='https://github.com/fgdorais/lean4-unicode-basic', commit='280d75fdfe7be8eb337be7f1bf8479b4aac09f71') relies on an unsupported Lean version: 0d7051497ea09b2b4a4ef608e371b8f317487c3c
# 2024-04-26 23:25:37.658 | WARNING  | lean_dojo.data_extraction.lean:__post_init__:442 - LeanGitRepo(url='https://github.com/hargonix/LeanInk', commit='2447df5cc6e48eb965c3c3fba87e46d353b5e9f1') relies on an unsupported Lean version: f6cd6c069587cfe62dd68cb6330f9ad794a56724
# 2024-04-26 23:25:59,395	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2729/2729 [00:44<00:00, 61.19it/s]
# 2024-04-26 23:26:50.747 | INFO     | lean_dojo.data_extraction.trace:trace:117 - Loading the traced repo from /home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-582b82ce041cd8130da516a1636e4d7769d1c72e/math-in-lean
# 2024-04-26 23:26:53,215	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2729/2729 [03:58<00:00, 11.44it/s]
# DiGraph with 2729 nodes and 11268 edges
# len(traced_repo.traced_files): 2729

# %%
traced_repo.traced_files
# Out:
# [TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Component/MakeEditLink.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Demos/Svg.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Demos/Jsx.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Demos/Macro.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Component/HtmlDisplay.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Component/Basic.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Demos/Dynkin.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Data/Html.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Demos/RbTree.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Demos/LazyComputation.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Demos/InteractiveSvg.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/lake/Lake.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Demos/ExprPresentation.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Init.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Demos/SelectInsertConv.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Component/Recharts.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Component/InteractiveSvg.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Demos/Rubiks.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Log.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/LoadDynlib.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Component/Panel/Basic.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Demos/Venn.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Compat.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Component/Panel/GoalTypePanel.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Component/OfRpcMethod.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Component/PenroseDiagram.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Demos/Plot.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Presentation/Expr.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Demos/Euclidean.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/KeyedDeclsAttribute.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/ScopedEnvExtension.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/ParserCompiler.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Structure.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Declaration.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/SubExpr.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Parser.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Data/Svg.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/AuxRecursor.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Util.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Meta.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Widget.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Eval.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Server.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Component/Panel/SelectionPanel.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Elab.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/ImportingFlag.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Linter.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/ProjFns.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/LazyInitExtension.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Attributes.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Runtime.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Hygiene.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/LocalContext.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Compiler.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Class.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/DeclarationRange.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/InternalExceptionId.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/DocString.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/ReducibilityAttrs.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Modifiers.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/PrettyPrinter.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/ResolveName.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Syntax.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Rat.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/CoreM.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/HeadIndex.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/ToExpr.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Position.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/proofwidgets/ProofWidgets/Demos/Conv.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Format.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/NameTrie.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Replay.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/AssocList.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Exception.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/MonadEnv.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/HashSet.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/OpenDecl.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Parsec.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Trie.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/SSet.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/LBool.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Array.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/RBTree.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Lsp.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Level.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/SMap.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Message.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/NameMap.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/HashMap.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/PersistentHashSet.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/PrefixTree.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/RBMap.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Name.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/LOption.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Lsp/Diagnostics.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Lsp/TextSync.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Xml.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Json.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Options.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/FuzzyMatching.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Lsp/Ipc.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Lsp/Basic.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Lsp/CodeActions.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Lsp/Internal.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Environment.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Lsp/Communication.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/PersistentHashMap.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/PersistentArray.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Xml/Basic.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Json/Printer.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/JsonRpc.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Lsp/Capabilities.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Lsp/Extra.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/KVMap.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Util/HasConstCache.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Lsp/Workspace.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Lsp/Utf16.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Lsp/InitShutdown.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Util/FindExpr.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Json/Basic.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Json/Stream.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Lsp/Client.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Util/FoldConsts.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Util/LakePath.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Data/Json/Parser.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/MetavarContext.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Util/Recognizers.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Expr.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Util/PPExt.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/lean4/src/lean/Lean/Util/RecDepth.lean'))),
# ...
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Finite/Basic.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Set/Pairwise/Basic.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Set/Pointwise/Basic.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Finite/Defs.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Bool/Set.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Finite/Card.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Multiset/Basic.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Finsupp/Antidiagonal.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Multiset/FinsetOps.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Multiset/Sum.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Pi/Algebra.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/ENat/Lattice.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Finsupp/Interval.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Set/Lattice.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Set/Basic.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Multiset/Sort.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Sym/Basic.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Finsupp/ToDFinsupp.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Bool/Basic.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Finsupp/Indicator.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/PNat/Defs.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Finsupp/PWO.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Finsupp/Multiset.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Multiset/Powerset.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Finsupp/Fintype.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Finsupp/Encodable.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/List/Defs.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/List/Permutation.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/List/Palindrome.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/List/MinMax.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/FunLike/Basic.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Finsupp/Fin.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/List/Count.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Finite/Set.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/List/OfFn.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/List/NatAntidiagonal.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/Finsupp/Basic.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/List/Duplicate.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/List/Indexes.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/List/Prime.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/List/Lattice.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/FunLike/Equiv.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/List/Join.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-d39f713cf4df02df419c7d70e8824b89f792922f/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='d39f713cf4df02df419c7d70e8824b89f792922f'), lean_file=LeanFile(path=PosixPath('.lake/packages/mathlib/Mathlib/Data/List/Forall2.lean'))),
#  ...]

# %%
traced_file = traced_repo.get_traced_file("MIL/C03_Logic/solutions/Solutions_S01_Implication_and_the_Universal_Quantifier.lean")

print(traced_file)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 traced_file = traced_repo.get_traced_file("MIL/C03_Logic/solutions/Solutions_S01_Implication_and_the_Universal_Quantifier.lean")
#       3 print(traced_file)
#
# File ~/anaconda3/envs/atp/lib/python3.10/site-packages/lean_dojo/data_extraction/traced_data.py:1122, in TracedRepo.get_traced_file(self, path)
#    1120 def get_traced_file(self, path: Union[str, Path]) -> TracedFile:
#    1121     """Return a traced file by its path."""
# -> 1122     return self.traced_files_graph.nodes[str(path)]["traced_file"]
#
# File ~/anaconda3/envs/atp/lib/python3.10/site-packages/networkx/classes/reportviews.py:194, in NodeView.__getitem__(self, n)
#     189 if isinstance(n, slice):
#     190     raise nx.NetworkXError(
#     191         f"{type(self).__name__} does not support slicing, "
#     192         f"try list(G.nodes)[{n.start}:{n.stop}:{n.step}]"
#     193     )
# --> 194 return self._nodes[n]
#
# KeyError: 'MIL/C03_Logic/solutions/Solutions_S01_Implication_and_the_Universal_Quantifier.lean'

# %%
traced_file.get_premise_definitions()
# Out:
# [{'full_name': 'chineseMap',
#   'code': 'def chineseMap (I : ι → Ideal R) : (R ⧸ ⨅ i, I i) →+* Π i, R ⧸ I i :=\n  sorry',
#   'start': [83, 1],
#   'end': [86, 8],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'chineseMap_mk',
#   'code': 'lemma chineseMap_mk (I : ι → Ideal R) (x : R) :\n    chineseMap I (Quotient.mk _ x) = fun i : ι ↦ Ideal.Quotient.mk (I i) x :=\n  sorry',
#   'start': [88, 1],
#   'end': [90, 8],
#   'kind': 'lemma'},
#  {'full_name': "chineseMap_mk'",
#   'code': "lemma chineseMap_mk' (I : ι → Ideal R) (x : R) (i : ι) :\n    chineseMap I (mk _ x) i = mk (I i) x :=\n  sorry",
#   'start': [92, 1],
#   'end': [94, 8],
#   'kind': 'lemma'},
#  {'full_name': 'chineseMap_inj',
#   'code': 'lemma chineseMap_inj (I : ι → Ideal R) : Injective (chineseMap I) := by\n  sorry',
#   'start': [98, 1],
#   'end': [99, 8],
#   'kind': 'lemma'},
#  {'full_name': 'isCoprime_Inf',
#   'code': 'theorem isCoprime_Inf {I : Ideal R} {J : ι → Ideal R} {s : Finset ι}\n    (hf : ∀ j ∈ s, IsCoprime I (J j)) : IsCoprime I (⨅ j ∈ s, J j)',
#   'start': [110, 1],
#   'end': [124, 44],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'chineseMap_surj',
#   'code': "lemma chineseMap_surj [Fintype ι] {I : ι → Ideal R}\n    (hI : ∀ i j, i ≠ j → IsCoprime (I i) (I j)) : Surjective (chineseMap I) := by\n  classical\n  intro g\n  choose f hf using fun i ↦ Ideal.Quotient.mk_surjective (g i)\n  have key : ∀ i, ∃ e : R, mk (I i) e = 1 ∧ ∀ j, j ≠ i → mk (I j) e = 0 := by\n    intro i\n    have hI' : ∀ j ∈ ({i} : Finset ι)ᶜ, IsCoprime (I i) (I j) := by\n      sorry\n    sorry\n  choose e he using key\n  use mk _ (∑ i, f i * e i)\n  sorry",
#   'start': [125, 1],
#   'end': [137, 8],
#   'kind': 'lemma'},
#  {'full_name': 'chineseIso',
#   'code': 'noncomputable def chineseIso [Fintype ι] (f : ι → Ideal R)\n    (hf : ∀ i j, i ≠ j → IsCoprime (f i) (f j)) : (R ⧸ ⨅ i, f i) ≃+* Π i, R ⧸ f i :=\n  { Equiv.ofBijective _ ⟨chineseMap_inj f, chineseMap_surj hf⟩,\n    chineseMap f with }',
#   'start': [139, 1],
#   'end': [142, 24],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'circleEquation',
#   'code': 'def circleEquation : MvPolynomial (Fin 2) ℝ := X 0 ^ 2 + X 1 ^ 2 - 1',
#   'start': [219, 1],
#   'end': [219, 69],
#   'kind': 'commanddeclaration'}]

# %%
thm = traced_file.get_traced_theorem("isCoprime_Inf")

print(thm.theorem)

proof_node = thm.get_proof_node()
proof = proof_node.lean_file[proof_node.start : proof_node.end]
print(proof)

traced_tactics = thm.get_traced_tactics()
print("\ntraced_tactics:\n", traced_tactics)

tac = traced_tactics[1]
print("\ntac:\n", tac)
# Out:
# Theorem(repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='2d4380e95b86bb0211b7b8662780212d993af7e0'), file_path=PosixPath('MIL/C08_Groups_and_Rings/S02_Rings.lean'), full_name='isCoprime_Inf')
# by
#   classical
#   simp_rw [isCoprime_iff_add] at *
#   induction s using Finset.induction with
#   | empty =>
#       simp
#   | @insert i s _ hs =>
#       rw [Finset.iInf_insert, inf_comm, one_eq_top, eq_top_iff, ← one_eq_top]
#       set K := ⨅ j ∈ s, J j
#       calc
#         1 = I + K                  := sorry
#         _ = I + K * (I + J i)      := sorry
#         _ = (1 + K) * I + K * J i  := sorry
#         _ ≤ I + K ⊓ J i            := sorry
#
# traced_tactics:
#  [TracedTactic(tactic=classical
# simp_rw [isCoprime_iff_add] at *
# induction s using Finset.induction with
# | empty =>
#     simp
# | @insert i s _ hs =>
#     rw [Finset.iInf_insert, inf_comm, one_eq_top, eq_top_iff, ← one_eq_top]
#     set K := ⨅ j ∈ s, J j
#     calc
#       1 = I + K                  := sorry
#       _ = I + K * (I + J i)      := sorry
#       _ = (1 + K) * I + K * J i  := sorry
#       _ ≤ I + K ⊓ J i            := sorry, state_before=ι : Type u_1
# R : Type u_2
# inst✝ : CommRing R
# I : Ideal R
# J : ι → Ideal R
# s : Finset ι
# hf : ∀ j ∈ s, IsCoprime I (J j)
# ⊢ IsCoprime I (⨅ j ∈ s, J j), state_after=no goals), TracedTactic(tactic=simp_rw [isCoprime_iff_add] at *, state_before=ι : Type u_1
# R : Type u_2
# inst✝ : CommRing R
# I : Ideal R
# J : ι → Ideal R
# s : Finset ι
# hf : ∀ j ∈ s, IsCoprime I (J j)
# ⊢ IsCoprime I (⨅ j ∈ s, J j), state_after=ι : Type u_1
# R : Type u_2
# inst✝ : CommRing R
# I : Ideal R
# J : ι → Ideal R
# s : Finset ι
# hf : ∀ j ∈ s, I + J j = 1
# ⊢ I + ⨅ j ∈ s, J j = 1), TracedTactic(tactic=induction s using Finset.induction with
# | empty =>
#     simp
# | @insert i s _ hs =>
#     rw [Finset.iInf_insert, inf_comm, one_eq_top, eq_top_iff, ← one_eq_top]
#     set K := ⨅ j ∈ s, J j
#     calc
#       1 = I + K                  := sorry
#       _ = I + K * (I + J i)      := sorry
#       _ = (1 + K) * I + K * J i  := sorry
#       _ ≤ I + K ⊓ J i            := sorry, state_before=ι : Type u_1
# R : Type u_2
# inst✝ : CommRing R
# I : Ideal R
# J : ι → Ideal R
# s : Finset ι
# hf : ∀ j ∈ s, I + J j = 1
# ⊢ I + ⨅ j ∈ s, J j = 1, state_after=no goals), TracedTactic(tactic=simp, state_before=case empty
# ι : Type u_1
# R : Type u_2
# inst✝ : CommRing R
# I : Ideal R
# J : ι → Ideal R
# hf : ∀ j ∈ ∅, I + J j = 1
# ⊢ I + ⨅ j ∈ ∅, J j = 1, state_after=no goals), TracedTactic(tactic=rw [Finset.iInf_insert, inf_comm, one_eq_top, eq_top_iff, ← one_eq_top], state_before=case insert
# ι : Type u_1
# R : Type u_2
# inst✝ : CommRing R
# I : Ideal R
# J : ι → Ideal R
# i : ι
# s : Finset ι
# a✝ : i ∉ s
# hs : (∀ j ∈ s, I + J j = 1) → I + ⨅ j ∈ s, J j = 1
# hf : ∀ j ∈ insert i s, I + J j = 1
# ⊢ I + ⨅ j ∈ insert i s, J j = 1, state_after=case insert
# ι : Type u_1
# R : Type u_2
# inst✝ : CommRing R
# I : Ideal R
# J : ι → Ideal R
# i : ι
# s : Finset ι
# a✝ : i ∉ s
# hs : (∀ j ∈ s, I + J j = 1) → I + ⨅ j ∈ s, J j = 1
# hf : ∀ j ∈ insert i s, I + J j = 1
# ⊢ 1 ≤ I + (⨅ x ∈ s, J x) ⊓ J i), TracedTactic(tactic=set K := ⨅ j ∈ s, J j, state_before=case insert
# ι : Type u_1
# R : Type u_2
# inst✝ : CommRing R
# I : Ideal R
# J : ι → Ideal R
# i : ι
# s : Finset ι
# a✝ : i ∉ s
# hs : (∀ j ∈ s, I + J j = 1) → I + ⨅ j ∈ s, J j = 1
# hf : ∀ j ∈ insert i s, I + J j = 1
# ⊢ 1 ≤ I + (⨅ x ∈ s, J x) ⊓ J i, state_after=case insert
# ι : Type u_1
# R : Type u_2
# inst✝ : CommRing R
# I : Ideal R
# J : ι → Ideal R
# i : ι
# s : Finset ι
# a✝ : i ∉ s
# hf : ∀ j ∈ insert i s, I + J j = 1
# K : Ideal R := ⨅ j ∈ s, J j
# hs : (∀ j ∈ s, I + J j = 1) → I + K = 1
# ⊢ 1 ≤ I + K ⊓ J i), TracedTactic(tactic=calc
#   1 = I + K                  := sorry
#   _ = I + K * (I + J i)      := sorry
#   _ = (1 + K) * I + K * J i  := sorry
#   _ ≤ I + K ⊓ J i            := sorry, state_before=case insert
# ι : Type u_1
# R : Type u_2
# inst✝ : CommRing R
# I : Ideal R
# J : ι → Ideal R
# i : ι
# s : Finset ι
# a✝ : i ∉ s
# hf : ∀ j ∈ insert i s, I + J j = 1
# K : Ideal R := ⨅ j ∈ s, J j
# hs : (∀ j ∈ s, I + J j = 1) → I + K = 1
# ⊢ 1 ≤ I + K ⊓ J i, state_after=no goals)]
#
# tac:
#  TracedTactic(tactic=simp_rw [isCoprime_iff_add] at *, state_before=ι : Type u_1
# R : Type u_2
# inst✝ : CommRing R
# I : Ideal R
# J : ι → Ideal R
# s : Finset ι
# hf : ∀ j ∈ s, IsCoprime I (J j)
# ⊢ IsCoprime I (⨅ j ∈ s, J j), state_after=ι : Type u_1
# R : Type u_2
# inst✝ : CommRing R
# I : Ideal R
# J : ι → Ideal R
# s : Finset ι
# hf : ∀ j ∈ s, I + J j = 1
# ⊢ I + ⨅ j ∈ s, J j = 1)

# %%
def parse_lean_state_and_tactic(state_before, tactic):
    import re

    # Step 1: Parse the state_before to create a dictionary of definitions
    definition_dict = {}
    lines = state_before.split("\n")
    for line in lines:
        line = line.strip()
        if ":" in line and not line.startswith("⊢"):  # ignore the goal line
            name_type_pair = line.split(" : ")
            name = name_type_pair[0].strip()
            type_def = name_type_pair[1].strip()
            definition_dict[name] = type_def

    # Step 2: Parse the tactic
    tactic_parts = re.split(r"\s+", tactic, 1)  # split into keyword and the rest
    if len(tactic_parts) == 1:  # tactic without arguments
        return tactic  # no transformation needed
    
    keyword = tactic_parts[0]
    arguments = tactic_parts[1]

    # Step 3: Check and transform arguments
    if "[" in arguments:  # Handle bracketed arguments like in 'rw [ef, eg]'
        transformed_arguments = re.sub(r'\[(.*?)\]', lambda m: transform_bracket_contents(m.group(1), definition_dict), arguments)
    else:  # Handle single or space-separated arguments like in 'apply hfa'
        transformed_arguments = " ".join("{" + definition_dict[arg] + "}" if arg in definition_dict else arg for arg in arguments.split())

    # Join the transformed arguments with the keyword
    transformed_tactic = keyword + " " + transformed_arguments
    return transformed_tactic

def transform_bracket_contents(contents, definition_dict):
    # Split the contents within the brackets by commas and strip spaces
    items = map(str.strip, contents.split(","))
    transformed = []
    for item in items:
        if item in definition_dict:
            transformed.append("{" + definition_dict[item] + "}")
        else:
            transformed.append(item)
    return "[" + ", ".join(transformed) + "]"

# Example usage for both scenarios
state_before_1 = """
case h₁
f g : ℝ → ℝ
a b : ℝ
hfa : FnUb f a
hgb : FnUb g b
x : ℝ
⊢ f x ≤ a

case h₂
f g : ℝ → ℝ
a b : ℝ
hfa : FnUb f a
hgb : FnUb g b
x : ℝ
⊢ g x ≤ b
"""
tactic_1 = "apply hfa"
print(parse_lean_state_and_tactic(state_before_1, tactic_1))  # should be "apply {FnUb f a}"

state_before_2 = """
f g : ℝ → ℝ
ef : FnEven f
eg : FnEven g
x : ℝ
⊢ f x + g x = f (-x) + g (-x)
"""
tactic_2 = "rw [ef, eg]"
print(parse_lean_state_and_tactic(state_before_2, tactic_2))  # should be "rw [{FnEven f}, {FnEven g}]"
# Out:
# apply {FnUb f a}
# rw [{FnEven f}, {FnEven g}]

# %%
premises = traced_file.get_premise_definitions()

for premise in premises:
    if premise['code'].startswith('theorem'):
        thm_name = premise['full_name']
        print("Theorem", thm_name, '\n')
        thm = traced_file.get_traced_theorem(thm_name)
        traced_tactics = thm.get_traced_tactics()
        for step in traced_tactics:
            print(step.state_before)
            print(step.tactic)
            tac = parse_lean_state_and_tactic(step.state_before, step.tactic)
            print("TAC:")
            print(tac)
            print()
# Out:
# Theorem C03S03.S03_Negation_ex1
#
# a b : ℝ
# h : a < b
# ⊢ ¬b < a
# intro h'
# TAC:
# intro h'
#
# a b : ℝ
# h : a < b
# h' : b < a
# ⊢ False
# have : a < a := lt_trans h h'
# TAC:
# have : a < a := lt_trans {a < b} {b < a}
#
# a b : ℝ
# h : a < b
# h' : b < a
# this : a < a
# ⊢ False
# apply lt_irrefl a this
# TAC:
# apply lt_irrefl a {a < a}
#
# Theorem C03S03.S03_Negation_ex2
#
# a b : ℝ
# f : ℝ → ℝ
# h : ∀ (a : ℝ), ∃ x, f x > a
# ⊢ ¬FnHasUb f
# intro fnub
# TAC:
# intro fnub
#
# a b : ℝ
# f : ℝ → ℝ
# h : ∀ (a : ℝ), ∃ x, f x > a
# fnub : FnHasUb f
# ⊢ False
# rcases fnub with ⟨a, fnuba⟩
# TAC:
# rcases {FnHasUb f} with ⟨a, fnuba⟩
#
# case intro
# a✝ b : ℝ
# f : ℝ → ℝ
# h : ∀ (a : ℝ), ∃ x, f x > a
# a : ℝ
# fnuba : FnUb f a
# ⊢ False
# rcases h a with ⟨x, hx⟩
# TAC:
# rcases {∀ (a} {ℝ} with ⟨x, hx⟩
#
# case intro.intro
# a✝ b : ℝ
# f : ℝ → ℝ
# h : ∀ (a : ℝ), ∃ x, f x > a
# a : ℝ
# fnuba : FnUb f a
# x : ℝ
# hx : f x > a
# ⊢ False
# have : f x ≤ a := fnuba x
# TAC:
# have : {ℝ → ℝ} {ℝ} ≤ {ℝ} := {FnUb f a} {ℝ}
#
# case intro.intro
# a✝ b : ℝ
# f : ℝ → ℝ
# h : ∀ (a : ℝ), ∃ x, f x > a
# a : ℝ
# fnuba : FnUb f a
# x : ℝ
# hx : f x > a
# this : f x ≤ a
# ⊢ False
# linarith
# TAC:
# linarith
#
# Theorem C03S03.S03_Negation_ex3
#
# Theorem C03S03.S03_Negation_ex4
#
# Theorem C03S03.S03_Negation_ex5
#
# a b : ℝ
# f : ℝ → ℝ
# h : Monotone f
# h' : f a < f b
# ⊢ a < b
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex6
#
# a b : ℝ
# f : ℝ → ℝ
# h : a ≤ b
# h' : f b < f a
# ⊢ ¬Monotone f
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex7
#
# a b : ℝ
# f : ℝ → ℝ
# ⊢ ¬∀ {f : ℝ → ℝ}, Monotone f → ∀ {a b : ℝ}, f a ≤ f b → a ≤ b
# intro h
# TAC:
# intro h
#
# a b : ℝ
# f : ℝ → ℝ
# h : ∀ {f : ℝ → ℝ}, Monotone f → ∀ {a b : ℝ}, f a ≤ f b → a ≤ b
# ⊢ False
# let f := fun x : ℝ ↦ (0 : ℝ)
# TAC:
# let {ℝ → ℝ} := fun x : ℝ ↦ (0 : ℝ)
#
# a b : ℝ
# f✝ : ℝ → ℝ
# h : ∀ {f : ℝ → ℝ}, Monotone f → ∀ {a b : ℝ}, f a ≤ f b → a ≤ b
# f : ℝ → ℝ := fun x => 0
# ⊢ False
# have monof : Monotone f := by sorry
# TAC:
# have monof : Monotone {ℝ → ℝ := fun x => 0} := by sorry
#
# a b : ℝ
# f✝ : ℝ → ℝ
# h : ∀ {f : ℝ → ℝ}, Monotone f → ∀ {a b : ℝ}, f a ≤ f b → a ≤ b
# f : ℝ → ℝ := fun x => 0
# monof : Monotone f
# ⊢ False
# have h' : f 1 ≤ f 0 := le_refl _
# TAC:
# have h' : {ℝ → ℝ := fun x => 0} 1 ≤ {ℝ → ℝ := fun x => 0} 0 := le_refl _
#
# a b : ℝ
# f✝ : ℝ → ℝ
# h : ∀ {f : ℝ → ℝ}, Monotone f → ∀ {a b : ℝ}, f a ≤ f b → a ≤ b
# f : ℝ → ℝ := fun x => 0
# monof : Monotone f
# h' : f 1 ≤ f 0
# ⊢ False
# sorry
# TAC:
# sorry
#
# a b : ℝ
# f✝ : ℝ → ℝ
# h : ∀ {f : ℝ → ℝ}, Monotone f → ∀ {a b : ℝ}, f a ≤ f b → a ≤ b
# f : ℝ → ℝ := fun x => 0
# ⊢ Monotone f
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex8
#
# a b : ℝ
# f : ℝ → ℝ
# x : ℝ
# h : ∀ ε > 0, x < ε
# ⊢ x ≤ 0
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex9
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : ¬∃ x, P x
# ⊢ ∀ (x : α), ¬P x
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex10
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : ∀ (x : α), ¬P x
# ⊢ ¬∃ x, P x
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex11
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : ¬∀ (x : α), P x
# ⊢ ∃ x, ¬P x
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex12
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : ∃ x, ¬P x
# ⊢ ¬∀ (x : α), P x
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex13
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : ¬∀ (x : α), P x
# ⊢ ∃ x, ¬P x
# by_contra h'
# TAC:
# by_contra h'
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : ¬∀ (x : α), P x
# h' : ¬∃ x, ¬P x
# ⊢ False
# apply h
# TAC:
# apply {¬∀ (x}
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : ¬∀ (x : α), P x
# h' : ¬∃ x, ¬P x
# ⊢ ∀ (x : α), P x
# intro x
# TAC:
# intro x
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : ¬∀ (x : α), P x
# h' : ¬∃ x, ¬P x
# x : α
# ⊢ P x
# by_contra h''
# TAC:
# by_contra h''
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : ¬∀ (x : α), P x
# h' : ¬∃ x, ¬P x
# x : α
# h'' : ¬P x
# ⊢ False
# exact h' ⟨x, h''⟩
# TAC:
# exact {¬∃ x, ¬P x} ⟨x, h''⟩
#
# Theorem C03S03.S03_Negation_ex14
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : ¬¬Q
# ⊢ Q
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex15
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : Q
# ⊢ ¬¬Q
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex16
#
# f : ℝ → ℝ
# h : ¬FnHasUb f
# ⊢ ∀ (a : ℝ), ∃ x, f x > a
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex17
#
# f : ℝ → ℝ
# h : ¬∀ (a : ℝ), ∃ x, f x > a
# ⊢ FnHasUb f
# push_neg at h
# TAC:
# push_neg at {¬∀ (a}
#
# f : ℝ → ℝ
# h : ∃ a, ∀ (x : ℝ), f x ≤ a
# ⊢ FnHasUb f
# exact h
# TAC:
# exact {∃ a, ∀ (x}
#
# Theorem C03S03.S03_Negation_ex18
#
# f : ℝ → ℝ
# h : ¬FnHasUb f
# ⊢ ∀ (a : ℝ), ∃ x, f x > a
# dsimp only [FnHasUb, FnUb] at h
# TAC:
# dsimp only [FnHasUb, FnUb] at h
#
# f : ℝ → ℝ
# h : ¬∃ a, ∀ (x : ℝ), f x ≤ a
# ⊢ ∀ (a : ℝ), ∃ x, f x > a
# push_neg at h
# TAC:
# push_neg at {¬∃ a, ∀ (x}
#
# f : ℝ → ℝ
# h : ∀ (a : ℝ), ∃ x, a < f x
# ⊢ ∀ (a : ℝ), ∃ x, f x > a
# exact h
# TAC:
# exact {∀ (a}
#
# Theorem C03S03.S03_Negation_ex19
#
# f : ℝ → ℝ
# h : ¬Monotone f
# ⊢ ∃ x y, x ≤ y ∧ f y < f x
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex20
#
# f : ℝ → ℝ
# h : ¬FnHasUb f
# ⊢ ∀ (a : ℝ), ∃ x, f x > a
# contrapose! h
# TAC:
# contrapose! {¬FnHasUb f}
#
# f : ℝ → ℝ
# h : ∃ a, ∀ (x : ℝ), f x ≤ a
# ⊢ FnHasUb f
# exact h
# TAC:
# exact {∃ a, ∀ (x}
#
# Theorem C03S03.S03_Negation_ex21
#
# f : ℝ → ℝ
# x : ℝ
# h : ∀ ε > 0, x ≤ ε
# ⊢ x ≤ 0
# contrapose! h
# TAC:
# contrapose! {∀ ε > 0, x ≤ ε}
#
# f : ℝ → ℝ
# x : ℝ
# h : 0 < x
# ⊢ ∃ ε > 0, ε < x
# use x / 2
# TAC:
# use {ℝ} / 2
#
# case h
# f : ℝ → ℝ
# x : ℝ
# h : 0 < x
# ⊢ x / 2 > 0 ∧ x / 2 < x
# constructor <;> linarith
# TAC:
# constructor <;> linarith
#
# Theorem C03S03.S03_Negation_ex22
#
# a : ℕ
# h : 0 < 0
# ⊢ a > 37
# exfalso
# TAC:
# exfalso
#
# a : ℕ
# h : 0 < 0
# ⊢ False
# apply lt_irrefl 0 h
# TAC:
# apply lt_irrefl 0 {0 < 0}
#
# Theorem C03S03.S03_Negation_ex23
#
# Theorem C03S03.S03_Negation_ex24
#
# a : ℕ
# h : 0 < 0
# ⊢ a > 37
# have h' : ¬0 < 0 := lt_irrefl 0
# TAC:
# have h' : ¬0 < 0 := lt_irrefl 0
#
# a : ℕ
# h : 0 < 0
# h' : ¬0 < 0
# ⊢ a > 37
# contradiction
# TAC:
# contradiction

# %%
premises = traced_file.get_premise_definitions()

premises[0]
# Out:
# {'full_name': 'C03S01.my_lemma',
#  'code': 'theorem my_lemma : ∀ x y ε : ℝ, 0 < ε → ε ≤ 1 → |x| < ε → |y| < ε → |x * y| < ε',
#  'start': [10, 1],
#  'end': [11, 8],
#  'kind': 'commanddeclaration'}

# %%
def classify_lean_element(line):
    VARIABLE_TYPES = ['ℝ']
    
    # Clean up the line
    line = line.strip()
    if not line:
        return None, None

    # Split the line around the ':'
    parts = line.split(':', 1)
    if len(parts) != 2:
        return None, None  # Skip malformed lines

    # Clean up names and types
    name_part, type_info = parts[0].strip(), parts[1].strip()

    if type_info.startswith('Type'):
        return 'type', name_part.split(), type_info
    
    if type_info.startswith('Set'):
        return 'set', name_part.split(), type_info
    
    if type_info.startswith(('∀', '∃', '¬')):
        return 'hypothesis', name_part.split(), type_info
    
    if type_info in VARIABLE_TYPES:
        return 'variable', name_part.split(), type_info
    
    # Check for function definitions or lambda functions
    if '→' in type_info or 'fun' in type_info or ':=' in type_info:
        # Check if it's a hypothesis disguised as a function (look for logical operators)
        if '∀' in type_info or '∃' in type_info:
            return 'hypothesis', name_part.split(), type_info
        return 'function', name_part.split(), type_info

    # Check for propositions or logical statements involving quantifiers
    if 'Prop' in type_info or '¬' in type_info or '∈' in type_info or '∉' in type_info:
        return 'hypothesis', name_part.split(), type_info

    # Handle multiple variables on the same line
    names = name_part.split()
    return 'unknown', names, type_info

def classify_lean_elements(lean_state):
    category_of_name = {}
    type_info_of_name = {}
    lines = lean_state.strip().split('\n')
    for line in lines:
        category, names, type_info = classify_lean_element(line)
        for name in names:
            category_of_name[name] = category
            type_info_of_name[name] = type_info
    
    names = list(category_of_name.keys())
    for name in names:
        if category_of_name[name] == 'unknown' and\
            type_info_of_name[name] in names and\
            category_of_name[type_info_of_name[name]] == 'type':
            category_of_name[name] = 'variable'

    return category_of_name, type_info_of_name

# Example usage
lean_state = """
α : Type u_1
P : α → Prop
Q : Prop
h : ¬∀ (x : α), P x
h' : ¬∃ x, ¬P x
x : α
h'' : ¬P x
a b : ℝ
f✝ : ℝ → ℝ
h1 : ∀ {f : ℝ → ℝ}, Monotone f → ∀ {a b : ℝ}, f a ≤ f b → a ≤ b
f : ℝ → ℝ := fun x => 0
α1 : Type u_1
s t : Set α
xstu : x ∈ (s \ t) \ u
xs : x ∈ s
xnt : x ∉ t
xnu : x ∉ u
xu : x ∈ u
ubf : FnHasUb f
ι : Type u_1
R : Type u_2
inst✝ : CommRing R
I : Ideal R
J : ι → Ideal R
i : ι
hs : (∀ j ∈ s, I + J j = 1) → I + ⨅ j ∈ s, J j = 1
hf : ∀ j ∈ insert i s, I + J j = 1
inst✝ : CommRing R
"""

category_of_name, _ = classify_lean_elements(lean_state)
for name, category in category_of_name.items():
    print(name, category)
# Out:
# α type
# P function
# Q hypothesis
# h hypothesis
# h' hypothesis
# x variable
# h'' hypothesis
# a variable
# b variable
# f✝ function
# h1 hypothesis
# f function
# α1 type
# s set
# t set
# xstu hypothesis
# xs hypothesis
# xnt hypothesis
# xnu hypothesis
# xu hypothesis
# ubf unknown
# ι type
# R type
# inst✝ unknown
# I unknown
# J function
# i variable
# hs hypothesis
# hf hypothesis

# %%
theorem = Theorem(repo, "MIL/C03_Logic/S01_Implication_and_the_Universal_Quantifier.lean", 
                  "C03S01.S01_Implication_and_the_Universal_Quantifier_ex1")

# For some theorems, it might take a few minutes.
dojo, state_0 = Dojo(theorem).__enter__()

print(state_0.pp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 4
#       1 theorem = Theorem(repo, "MIL/C03_Logic/S01_Implication_and_the_Universal_Quantifier.lean",
#       2                   "C03S01.S01_Implication_and_the_Universal_Quantifier_ex1")
# ----> 4 proof_node = theorem.get_proof_node()
#       5 proof = proof_node.lean_file[proof_node.start : proof_node.end]
#       6 print(proof)
#
# AttributeError: 'Theorem' object has no attribute 'get_proof_node'

# %%
state_1 = dojo.run_tac(state_0, "intro x")

print(state_1.pp)
# Out:
# f g : ℝ → ℝ
# a b : ℝ
# hfa : FnUb f a
# hgb : FnUb g b
# x : ℝ
# ⊢ (fun x => f x + g x) x ≤ a + b

# %%
state_2 = dojo.run_tac(state_1, "dsimp") 

print(state_2.pp)
# Out:
# f g : ℝ → ℝ
# a b : ℝ
# hfa : FnUb f a
# hgb : FnUb g b
# x : ℝ
# ⊢ f x + g x ≤ a + b

# %%
state_3 = dojo.run_tac(state_2, "apply add_le_add") 

print(state_3.pp)
# Out:
# case h₁
# f g : ℝ → ℝ
# a b : ℝ
# hfa : FnUb f a
# hgb : FnUb g b
# x : ℝ
# ⊢ f x ≤ a
#
# case h₂
# f g : ℝ → ℝ
# a b : ℝ
# hfa : FnUb f a
# hgb : FnUb g b
# x : ℝ
# ⊢ g x ≤ b

# %%
state_4 = dojo.run_tac(state_3, "apply hfa")

print(state_4.pp)
# Out:
# case h₂
# f g : ℝ → ℝ
# a b : ℝ
# hfa : FnUb f a
# hgb : FnUb g b
# x : ℝ
# ⊢ g x ≤ b

# %%
state_5 = dojo.run_tac(state_4, "apply hgb") 

state_5
# Out:
# ProofFinished(tactic_state_id=5, message='')

# %%
dir(dojo)
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cancel_timer',
#  '_check_alive',
#  '_cleanup',
#  '_cleanup_container',
#  '_cleanup_proc',
#  '_cleanup_tmp_dir',
#  '_exit_gracefully',
#  '_get_imports',
#  '_handle_hard_timeout',
#  '_install_handlers',
#  '_locate_traced_file',
#  '_modify_file',
#  '_modify_proof',
#  '_post_process',
#  '_read_next_line',
#  '_set_timer',
#  '_submit_request',
#  '_uninstall_handlers',
#  'additional_imports',
#  'container',
#  'entry',
#  'file_path',
#  'hard_timeout',
#  'has_timedout',
#  'is_crashed',
#  'is_successful',
#  'old_sigint',
#  'old_sigterm',
#  'origin_dir',
#  'proc',
#  'repo',
#  'run_cmd',
#  'run_tac',
#  'start_time',
#  'tmp_dir',
#  'uses_commands',
#  'uses_tactics']
