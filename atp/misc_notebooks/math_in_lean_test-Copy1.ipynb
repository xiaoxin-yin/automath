# %%
import os

os.environ['GITHUB_ACCESS_TOKEN'] = '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'

print(os.getenv("GITHUB_ACCESS_TOKEN", None))

from lean_dojo import *
# Out:
# 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

# %%
repo = LeanGitRepo(
    "https://github.com/xiaoxin-yin/math-in-lean",
    "0708e774a2050a294e83776f171235d942f46e9d"
)

repo
# Out:
# LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='0708e774a2050a294e83776f171235d942f46e9d')

# %%
repo.get_config("lean-toolchain")

traced_repo = trace(repo)

print(traced_repo.traced_files_graph)

print("len(traced_repo.traced_files):", len(traced_repo.traced_files))
# Out:
# 2024-04-26 21:51:24.830 | INFO     | lean_dojo.data_extraction.trace:get_traced_repo_path:80 - Tracing LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='0708e774a2050a294e83776f171235d942f46e9d')
# cmd: python build_lean4_repo.py math-in-lean
# 2024-04-26 21:51:28.923 | INFO     | __main__:main:165 - Building math-in-lean
# info: mathlib: cloning https://github.com/leanprover-community/mathlib4 to './.lake/packages/mathlib'
# info: std: cloning https://github.com/leanprover/std4 to './.lake/packages/std'
# info: Qq: cloning https://github.com/leanprover-community/quote4 to './.lake/packages/Qq'
# info: aesop: cloning https://github.com/leanprover-community/aesop to './.lake/packages/aesop'
# info: proofwidgets: cloning https://github.com/leanprover-community/ProofWidgets4 to './.lake/packages/proofwidgets'
# info: Cli: cloning https://github.com/leanprover/lean4-cli to './.lake/packages/Cli'
# info: importGraph: cloning https://github.com/leanprover-community/import-graph.git to './.lake/packages/importGraph'
# [0/2] Downloading proofwidgets cloud release
# [0/20] Building Std.Tactic.Unreachable
# [0/22] Building Std.Lean.TagAttribute
# [0/22] Building Std.Lean.Parser
# [0/22] Building Std.Lean.Command
# [0/24] Building Std.Tactic.OpenPrivate
# [0/36] Building Std.Lean.Name
# [0/36] Building Std.Util.TermUnsafe
# [0/36] Building Std.Lean.Syntax
# [0/36] Building Std.Tactic.ByCases
# [0/36] Building Std.Tactic.SeqFocus
# [0/36] Building Std.Data.Json
# [0/38] Building Std.Util.ProofWanted
# [0/38] Building Std.Lean.LocalContext
# [0/38] Building Std.Lean.Position
# [0/38] Building Std.Lean.Tactic
# [0/56] Building Std.Lean.InfoTree
# [0/74] Building Std.Classes.Dvd
# [0/79] Building Std.Data.Array.Init.Basic
# [0/87] Building Std.Data.Ord
# [1/1638] Building Std.Lean.Meta.Expr
# [2/1916] Building Std.Lean.PersistentHashMap
# [3/1973] Building Std.Lean.Delaborator
# [4/1973] Building Std.Util.LibraryNote
# [5/1973] Building Std.Util.ExtendedBinder
# [6/1973] Building Std.Tactic.RCases
# [7/1973] Building Std.Data.Option.Init.Lemmas
# [9/1973] Building Std.Tactic.HaveI
# [9/1973] Building Std.Data.Fin.Init.Lemmas
# [10/1973] Building Std.Data.List.Init.Basic
# [11/1973] Building Std.Lean.NameMapAttribute
# [12/1973] Building Std.Lean.Elab.Tactic
# [13/1973] Building Std.Lean.Expr
# [14/1973] Building Std.Tactic.Change
# [15/1973] Building Std.Classes.BEq
# [16/1973] Building Std.Control.ForInStep.Basic
# [17/1973] Building Std.Data.MLList.Basic
# [18/1973] Building Std.Tactic.LeftRight
# [19/1973] Building Std.Tactic.Replace
# [20/1973] Building Std.Tactic.Omega.Config
# [21/1973] Building Std.Data.DList
# [22/1973] Building Std.Lean.CoreM
# [23/1973] Building Std.Lean.Except
# [24/1973] Building Std.Lean.Float
# [25/1973] Building Std.Lean.HashMap
# [26/1973] Building Std.Lean.IO.Process
# [27/1973] Building Std.Lean.Meta.Inaccessible
# [28/1973] Building Std.Lean.MonadBacktrack
# [29/1973] Building Std.Lean.NameMap
# [30/1973] Building Std.Lean.PersistentHashSet
# [31/1973] Building Std.Lean.SMap
# [32/1973] Building Std.Lean.Util.Path
# [33/1973] Building Std.Tactic.Case
# [34/1973] Building Std.Tactic.Classical
# [35/1973] Building Std.Tactic.Exact
# [36/1973] Building Std.Tactic.Instances
# [37/1973] Building Std.Tactic.LabelAttr
# [38/1973] Building Std.Tactic.Where
# [39/1973] Building Std.WF
# [40/1973] Building Qq.ForLean.ReduceEval
# [41/1973] Building Qq.ForLean.ToExpr
# [42/1973] Building Qq.Typ
# [43/1973] Building Qq.ForLean.Do
# [44/1973] Building Qq.SortLocalDecls
# [45/1973] Building Aesop.Check
# [46/1973] Building Aesop.Nanos
# [47/1973] Building Aesop.Options.Public
# [48/1973] Building Aesop.Percent
# [49/1973] Building Aesop.Frontend.Basic
# [50/1973] Building Aesop.Frontend.ElabM
# [51/1973] Building ImportGraph.RequiredModules
# [52/1973] Building Std.Lean.AttributeExtra
# [53/1973] Building Std.Lean.Meta.Basic
# [54/1973] Building Std.Data.Int.Basic
# [55/1973] Building Std.Data.Nat.Basic
# [56/1973] Building Std.Tactic.PrintDependents
# [57/1973] Building Std.Tactic.CoeExt
# [58/1973] Building Std.Tactic.RunCmd
# [59/1973] Building Std.Util.Pickle
# [60/1973] Building Std.Tactic.Lint.Basic
# [61/1973] Building Std.CodeAction.Attr
# [63/1973] Building Std.Control.ForInStep.Lemmas
# [63/1973] Building Std.Tactic.GuardExpr
# [64/1973] Building Std.Tactic.Relation.Rfl
# [65/1973] Building Std.Lean.Json
# [66/1973] Building Std.Lean.Meta.Simp
# [67/1973] Building Std.Lean.Format
# [68/1973] Building Std.Tactic.NoMatch
# [69/1973] Building Aesop.Constants
# [70/1973] Building Std.Linter.UnreachableTactic
# [71/1973] Building Std.Test.Internal.DummyLabelAttr
# [72/1973] Building Std.Control.ForInStep
# [73/1973] Building Aesop.Options.Internal
# [74/1973] Building ImportGraph.Imports
# [75/1973] Building Std.Linter.UnnecessarySeqFocus
# [76/1973] Building Qq.Macro
# [77/1973] Building Std.Classes.SetNotation
# [78/1973] Building Aesop.Options
# [79/1973] Building Std.Tactic.TryThis
# [81/1973] Building Std.Tactic.Lint.TypeClass
# [81/1973] Building Std.Tactic.Lint.Frontend
# [82/1973] Building Std.Tactic.Lint.Misc
# [83/1973] Building Std.Tactic.Lint.Simp
# [85/1973] Building Std.Classes.Cast
# [85/1973] Building Std.Tactic.NormCast.Ext
# [86/1973] Building Std.Data.MLList.Heartbeats
# [91/1973] Building Std.CodeAction.Misc
# [91/1973] Building Std.CodeAction.Basic
# [94/1973] Building Std.Linter
# [95/1973] Building Std.Lean.Meta.AssertHypotheses
# [95/1973] Building Std.Tactic.FalseOrByContra
# [95/1973] Building Std.Lean.Meta.InstantiateMVars
# [95/1973] Building Std.Lean.Meta.SavedState
# [95/1973] Building Std.Lean.Meta.Clear
# [95/1973] Building Std.Tactic.Relation.Symm
# [100/1973] Building Std.Tactic.NormCast.Lemmas
# [100/1973] Building Std.Tactic.NormCast
# [103/1973] Building Aesop.Util.EqualUpToIds
# [104/1973] Building Std.Lean.Util.EnvSearch
# [104/1973] Building Std.Control.Nondet.Basic
# [107/1973] Building Std.Tactic.PrintPrefix
# [108/1973] Building Std.Tactic.Lint
# [109/1973] Building Std.Tactic.Simpa
# [109/1973] Building Std.Tactic.ShowTerm
# [109/1973] Building Std.Tactic.SimpTrace
# [111/1973] Building Std.Lean.HashSet
# [111/1973] Building Std.Data.Option.Basic
# [112/1973] Building Std.CodeAction.Deprecated
# [112/1973] Building Std.Tactic.GuardMsgs
# [120/1973] Building Std.Tactic.Alias
# [121/1973] Building Std.CodeAction
# [122/1973] Building Std.Data.Prod.Lex
# [125/1973] Building Std.Data.Prod
# [126/1973] Building Std.Classes.Order
# [129/1973] Building Std.Tactic.SqueezeScope
# [129/1973] Building Std.Tactic.Basic
# [131/1973] Building Std.Data.Bool
# [132/1973] Unpacking proofwidgets cloud release
# [134/1973] Building ProofWidgets.Compat
# [134/1973] Building Mathlib.Tactic.Recall
# [134/1973] Building Mathlib.Util.DischargerAsTactic
# [134/1973] Building Mathlib.Tactic.HaveI
# [134/1973] Building Mathlib.Tactic.NthRewrite
# [134/1973] Building Mathlib.Tactic.TypeCheck
# [134/1973] Building Mathlib.Tactic.GuardGoalNums
# [134/1973] Building Mathlib.Tactic.FunProp.StateList
# [134/1973] Building Mathlib.Tactic.SuppressCompilation
# [134/1973] Building Mathlib.Tactic.CasesM
# [134/1973] Building Mathlib.Init.Data.Sigma.Basic
# [134/1973] Building Mathlib.Tactic.InferParam
# [134/1973] Building Mathlib.Lean.Elab.Term
# [134/1973] Building Mathlib.Util.Delaborators
# [134/1973] Building Mathlib.Tactic.HelpCmd
# [134/1973] Building Mathlib.Tactic.Rename
# [134/1973] Building Mathlib.Tactic.ReduceModChar.Ext
# [135/1973] Building Mathlib.Tactic.Clear!
# [136/1973] Building Mathlib.Tactic.FailIfNoProgress
# [137/1973] Building Mathlib.Tactic.Attr.Register
# [138/1973] Building Mathlib.Tactic.Clean
# [139/1973] Building Mathlib.Tactic.Lint
# [141/1973] Building Mathlib.Tactic.ProjectionNotation
# [141/1973] Building Mathlib.Util.SynthesizeUsing
# [142/1973] Building Mathlib.Tactic.ExtractGoal
# [143/1973] Building Mathlib.Tactic.ExtendDoc
# [144/1973] Building Mathlib.Tactic.Clear_
# [145/1973] Building Mathlib.Tactic.UnsetOption
# [146/1973] Building Mathlib.Tactic.Eqns
# [147/1973] Building Mathlib.Tactic.Recover
# [148/1973] Building Mathlib.Tactic.ApplyWith
# [149/1973] Building Mathlib.Lean.EnvExtension
# [150/1973] Building Mathlib.Tactic.ClearExcept
# [151/1973] Building Mathlib.Util.Tactic
# [152/1973] Building Mathlib.Tactic.Constructor
# [153/1973] Building Mathlib.Tactic.Have
# [154/1973] Building Mathlib.Tactic.Lemma
# [155/1973] Building Mathlib.Util.AddRelatedDecl
# [156/1973] Building Mathlib.Tactic.Simps.NotationClass
# [157/1973] Building Mathlib.Tactic.Variable
# [158/1973] Building Mathlib.Tactic.Set
# [159/1973] Building Mathlib.Tactic.Explode.Datatypes
# [160/1973] Building Mathlib.Tactic.SimpIntro
# [161/1973] Building Mathlib.Util.MemoFix
# [162/1973] Building Mathlib.Util.WhatsNew
# [163/1973] Building Mathlib.Tactic.Relation.Symm
# [164/1973] Building Mathlib.Lean.PrettyPrinter.Delaborator
# [165/1973] Building Mathlib.Util.AssertExists
# [166/1973] Building Mathlib.Tactic.GuardHypNums
# [167/1973] Building Mathlib.Tactic.Coe
# [168/1973] Building Mathlib.Util.AtomM
# [169/1973] Building Mathlib.Tactic.Spread
# [170/1973] Building Mathlib.Mathport.Rename
# [171/1973] Building Mathlib.Tactic.Substs
# [172/1973] Building Mathlib.Tactic.SimpRw
# [173/1973] Building Mathlib.Tactic.SudoSetOption
# [174/1973] Building Mathlib.Tactic.PPWithUniv
# [175/1973] Building Mathlib.Tactic.Relation.Rfl
# [176/1973] Building Mathlib.Tactic.FunProp.ToStd
# [177/1973] Building Mathlib.Init.Data.Nat.Notation
# [178/1973] Building Mathlib.Tactic.Monotonicity.Attr
# [179/1973] Building Mathlib.Tactic.SuccessIfFailWithMsg
# [180/1973] Building Mathlib.Tactic.RunCmd
# [181/1973] Building Mathlib.Mathport.Attributes
# [182/1973] Building Mathlib.Lean.Meta.Basic
# [183/1973] Building Mathlib.Tactic.Trace
# [184/1973] Building Mathlib.Util.CountHeartbeats
# [185/1973] Building Mathlib.Util.WithWeakNamespace
# [186/1973] Building Mathlib.Lean.Expr.Traverse
# [187/1973] Building Mathlib.Data.Array.Defs
# [188/1973] Building Mathlib.Tactic.Existsi
# [189/1973] Building Mathlib.Tactic.Widget.SelectInsertParamsClass
# [190/1973] Building Mathlib.Tactic.GCongr.ForwardAttr
# [191/1973] Building ProofWidgets.Component.Basic
# [192/1973] Building Mathlib.Tactic.HigherOrder
# [193/1973] Building Mathlib.Tactic.SwapVar
# [194/1973] Building Mathlib.Tactic.Explode.Pretty
# [195/1973] Building Mathlib.Tactic.Replace
# [196/1973] Building Mathlib.Init.Data.Fin.Basic
# [197/1973] Building Std.Logic
# [198/1973] Building Mathlib.Lean.Meta.DiscrTree
# [199/1973] Building Mathlib.Tactic.ApplyAt
# [200/1973] Building Mathlib.Lean.Expr.ReplaceRec
# [201/1973] Building Mathlib.Tactic.Hint
# [202/1973] Building Mathlib.Init.Set
# [203/1973] Building Mathlib.CategoryTheory.ConcreteCategory.Bundled
# [204/1973] Building Mathlib.Init.Data.Sigma.Lex
# [205/1973] Building Mathlib.Init.Quot
# [206/1973] Building Mathlib.Control.ULift
# [207/1973] Building Mathlib.Init.Data.Ordering.Basic
# [208/1973] Building Mathlib.Tactic.ToLevel
# [209/1973] Building Mathlib.Tactic.ScopedNS
# [210/1973] Building Mathlib.Util.CompileInductive
# [211/1973] Building Mathlib.Tactic.Explode
# [212/1973] Building Mathlib.Tactic.Conv
# [213/1973] Building ProofWidgets.Data.Html
# [214/1973] Building ProofWidgets.Component.MakeEditLink
# [220/1973] Building Mathlib.Tactic.DeriveToExpr
# [227/1973] Building Mathlib.Tactic.ApplyCongr
# [228/1973] Building Qq.Delab
# [231/1973] Building Mathlib.Init.Data.Prod
# [232/1973] Building Mathlib.Mathport.Notation
# [234/1973] Building Std.Tactic.Omega.Logic
# [234/1973] Building Std.Data.Fin.Iterate
# [234/1973] Building Mathlib.Tactic.Attr.Core
# [234/1973] Building Mathlib.Init.Data.Subtype.Basic
# [234/1973] Building Mathlib.Init.Data.Quot
# [234/1973] Building Std.Data.Nat.Init.Lemmas
# [234/1973] Building Std.Classes.LawfulMonad
# [234/1973] Building Std.Data.PairingHeap
# [234/1973] Building Mathlib.Tactic.Use
# [234/1973] Building Std.Data.Sum.Basic
# [234/1973] Building Mathlib.Init.Propext
# [234/1973] Building Std.Data.RBMap.Basic
# [239/1973] Building Std.Data.Fin.Basic
# [239/1973] Building Std.Data.List.Init.Lemmas
# [239/1973] Building Std.Lean.Meta.LazyDiscrTree
# [239/1973] Building Std.Data.Nat.Lemmas
# [241/1973] Building ProofWidgets.Component.PenroseDiagram
# [241/1973] Building ProofWidgets.Component.OfRpcMethod
# [241/1973] Building ProofWidgets.Presentation.Expr
# [245/1973] Building Qq.MetaM
# [246/1973] Building Mathlib.Tactic.ToExpr
# [247/1973] Building Mathlib.Tactic.Widget.SelectPanelUtils
# [252/1973] Building Qq.AssertInstancesCommute
# [252/1973] Building Qq.Match
# [254/1973] Building Mathlib.Tactic.FBinop
# [259/1973] Building Mathlib.Init.Control.Combinators
# [259/1973] Building Std.Data.Array.Init.Lemmas
# [259/1973] Building Std.Data.List.Init.Attach
# [260/1973] Building Mathlib.Data.SProd
# [261/1973] Building Std.Data.Array.Basic
# [265/1973] Building Std.Data.RBMap.WF
# [266/1973] Building Std.Data.Nat.Bitwise
# [266/1973] Building Std.Data.Array.Merge
# [266/1973] Building Std.Data.Nat.Gcd
# [266/1973] Building Std.Data.Int.Lemmas
# [266/1973] Building Std.Data.BinomialHeap.Basic
# [268/1973] Building Std.Data.Array.Match
# [268/1973] Building Std.Data.List.Basic
# [269/1973] Building Std.Data.BitVec.Basic
# [269/1973] Building Std.Data.Nat
# [270/1973] Building Aesop.Util.UnorderedArraySet
# [270/1973] Building Std.Lean.Meta.DiscrTree
# [272/1973] Building Std.Data.Int.Order
# [274/1973] Building Std.Data.String.Basic
# [276/1973] Building Qq
# [277/1973] Building Std.Tactic.Ext.Attr
# [277/1973] Building Mathlib.Lean.Meta.Simp
# [277/1973] Building Std.Util.Cache
# [279/1973] Building Mathlib.Util.Qq
# [279/1973] Building Mathlib.Tactic.FunProp.Decl
# [280/1973] Building Std.Lean.Meta.UnusedNames
# [280/1973] Building Mathlib.Tactic.Says
# [282/1973] Building Std.Data.Char
# [282/1973] Building Std.Data.UInt
# [282/1973] Building Std.Data.Option.Lemmas
# [282/1973] Building Std.Tactic.Ext
# [284/1973] Building Mathlib.Tactic.Find
# [290/1973] Building Std.Data.Option
# [293/1973] Building Mathlib.Init.Data.Int.Basic
# [293/1973] Building Std.Tactic.Omega.MinNatAbs
# [293/1973] Building Std.Tactic.Omega.Int
# [293/1973] Building Std.Data.Int.DivMod
# [294/1973] Building Mathlib.Lean.Thunk
# [294/1973] Building Std.Control.Lemmas
# [294/1973] Building Std.Tactic.Congr
# [294/1973] Building Std.Data.Sum.Lemmas
# [294/1973] Building Std.Data.Fin.Lemmas
# [299/1973] Building Std.Data.BinomialHeap.Lemmas
# [301/1973] Building Std.Data.Sum
# [302/1973] Building Std.Data.BinomialHeap
# [306/1973] Building Std.Data.Fin
# [308/1973] Building Std.Data.Rat.Basic
# [308/1973] Building Std.Tactic.Omega.IntList
# [308/1973] Building Std.Data.Int.Gcd
# [309/1973] Building Std.Data.Int
# [311/1973] Building Std.Data.RBMap.Alter
# [312/1973] Building Std.Tactic.PermuteGoals
# [312/1973] Building Std.Data.AssocList
# [312/1973] Building Mathlib.Data.String.Defs
# [312/1973] Building Mathlib.Lean.Meta
# [312/1973] Building Std.Tactic.SolveByElim.Backtrack
# [312/1973] Building Mathlib.Tactic.FunProp.RefinedDiscrTree
# [312/1973] Building Mathlib.Init.Data.List.Basic
# [312/1973] Building Std.Data.List.Lemmas
# [313/1973] Building Mathlib.Data.Rat.Init
# [313/1973] Building Std.Classes.RatCast
# [313/1973] Building Mathlib.Lean.Expr.Basic
# [313/1973] Building Std.Data.Rat.Lemmas
# [314/1973] Building Mathlib.Tactic.Widget.Calc
# [314/1973] Building Mathlib.Tactic.Widget.Conv
# [319/1973] Building Mathlib.Lean.Elab.Tactic.Basic
# [319/1973] Building Mathlib.Lean.Meta.CongrTheorems
# [320/1973] Building Std.Tactic.Omega.Coeffs.IntList
# [321/1973] Building Std.Tactic.Omega.Constraint
# [321/1973] Building Std.Tactic.Omega.LinearCombo
# [323/1973] Building Std.Tactic.SolveByElim
# [325/1973] Building Mathlib.Tactic.Relation.Trans
# [326/1973] Building Mathlib.Tactic.Cases
# [326/1973] Building Mathlib.Tactic.RenameBVar
# [326/1973] Building Mathlib.Tactic.Core
# [326/1973] Building Mathlib.Tactic.GeneralizeProofs
# [326/1973] Building Mathlib.Tactic.Simps.Basic
# [327/1973] Building Std.Data.HashMap.Basic
# [328/1973] Building Std.Data.Rat
# [331/1973] Building Std.Tactic.Omega.OmegaM
# [333/1973] Building Mathlib.Tactic.Congr!
# [334/1973] Building Mathlib.Lean.Name
# [334/1973] Building Aesop.Util.UnionFind
# [334/1973] Building Std.Data.HashMap.Lemmas
# [334/1973] Building Mathlib.Data.MLList.Dedup
# [334/1973] Building Mathlib.Data.HashMap
# [339/1973] Building Aesop.Util.Basic
# [341/1973] Building Mathlib.Tactic.SplitIfs
# [341/1973] Building Mathlib.Tactic.WLOG
# [342/1973] Building Mathlib.Tactic.Propose
# [342/1973] Building Mathlib.Tactic.Monotonicity.Basic
# [342/1973] Building Std.Tactic.LibrarySearch
# [342/1973] Building Mathlib.Tactic.LibrarySearch
# [347/1973] Building Std.Tactic.Omega.Core
# [348/1973] Building Aesop.Index.Basic
# [348/1973] Building Aesop.Tracing
# [348/1973] Building Aesop.Rule.Name
# [348/1973] Building Aesop.Util.Tactic
# [352/1973] Building Aesop.Index
# [353/1973] Building Mathlib.Tactic.Observe
# [355/1973] Building Aesop.Script
# [357/1973] Building Mathlib.Init.Core
# [357/1973] Building Mathlib.Init.Logic
# [362/1973] Building Mathlib.Tactic.ToAdditive
# [363/1973] Building Std.Tactic.Omega.Frontend
# [364/1973] Building Mathlib.Tactic.Convert
# [365/1973] Building Mathlib.Init.CCLemmas
# [365/1973] Building Mathlib.Init.Algebra.Classes
# [365/1973] Building Mathlib.Init.Data.Bool.Lemmas
# [365/1973] Building Mathlib.Init.Align
# [367/1973] Building Aesop.RuleTac.Basic
# [372/1973] Building Aesop.Rule.Basic
# [372/1973] Building Aesop.RuleTac.Preprocess
# [372/1973] Building Aesop.RuleTac.Apply
# [372/1973] Building Aesop.RuleTac.Cases
# [372/1973] Building Aesop.RuleTac.Tactic
# [372/1973] Building Aesop.RuleTac.Forward
# [374/1973] Building Aesop.Search.Expansion.Basic
# [374/1973] Building Aesop.Rule
# [378/1973] Building Aesop.Builder.Basic
# [378/1973] Building Aesop.Tree.UnsafeQueue
# [380/1973] Building Aesop.RuleTac
# [382/1973] Building Aesop.Tree.Data
# [383/1973] Building Aesop.Builder.NormSimp
# [383/1973] Building Aesop.Builder.Tactic
# [383/1973] Building Aesop.Builder.Cases
# [383/1973] Building Aesop.Builder.Unfold
# [383/1973] Building Aesop.Builder.Forward
# [383/1973] Building Aesop.Builder.Apply
# [384/1973] Building Std.Lean.System.IO
# [384/1973] Building Std.Data.Range.Lemmas
# [384/1973] Building Mathlib.Init.Data.List.Instances
# [384/1973] Building Mathlib.Init.Data.List.Lemmas
# [384/1973] Building Std.Data.RBMap.Lemmas
# [384/1973] Building Std.Data.String.Lemmas
# [384/1973] Building Std.Data.List.Count
# [384/1973] Building Std.Data.Array.Lemmas
# [385/1973] Building Aesop.Builder.Constructors
# [390/1973] Building Std.Data.MLList.IO
# [393/1973] Building Aesop.Builder.Default
# [394/1973] Building Std.Data.MLList
# [396/1973] Building Aesop.Builder
# [398/1973] Building Std.Data.List.Pairwise
# [399/1973] Building Std.Data.Range
# [400/1973] Building Aesop.RuleSet
# [402/1973] Building Aesop.Tree.Traversal
# [402/1973] Building Aesop.Profiling
# [402/1973] Building Aesop.Tree.RunMetaM
# [403/1973] Building Aesop.Tree.TreeM
# [403/1973] Building Aesop.Tree.Tracing
# [404/1973] Building Aesop.Tree.State
# [405/1973] Building Mathlib.Init.ZeroOne
# [406/1973] Building Std.Data.List.Perm
# [407/1973] Building Mathlib.Init.Data.Nat.Basic
# [409/1973] Building Aesop.Tree.Free
# [409/1973] Building Aesop.Tree.AddRapp
# [409/1973] Building Aesop.Tree.ExtractScript
# [410/1973] Building Aesop.Tree.Check
# [414/1973] Building Aesop.Tree.ExtractProof
# [415/1973] Building Std.Tactic.Omega
# [416/1973] Building Aesop.Search.Expansion.Simp
# [416/1973] Building Aesop.Frontend.Extension.Init
# [416/1973] Building Aesop.Frontend.RuleExpr
# [417/1973] Building Std.Data.BitVec.Lemmas
# [420/1973] Building Aesop.Frontend.Extension
# [421/1973] Building Std.Data.RBMap
# [425/1973] Building Std.Data.List
# [426/1973] Building Aesop.Tree
# [428/1973] Building Std.Data.BitVec.Folds
# [429/1973] Building Aesop.Search.Queue.Class
# [430/1973] Building Std.Data.BitVec.Bitblast
# [431/1973] Building Std.Data.ByteArray
# [431/1973] Building Std.Data.HashMap.WF
# [431/1973] Building Std.Data.Array
# [432/1973] Building Aesop.Search.Queue
# [432/1973] Building Aesop.Search.SearchM
# [435/1973] Building Aesop.Frontend.Attribute
# [436/1973] Building Aesop.Search.RuleSelection
# [437/1973] Building Std.Data.BitVec
# [439/1973] Building Aesop.Search.Expansion.Norm
# [440/1973] Building Aesop.BuiltinRules.Ext
# [440/1973] Building Aesop.BuiltinRules.Intros
# [440/1973] Building Aesop.BuiltinRules.Split
# [440/1973] Building Aesop.Frontend.Tactic
# [440/1973] Building Aesop.BuiltinRules.ApplyHyps
# [440/1973] Building Aesop.BuiltinRules.DestructProducts
# [440/1973] Building Aesop.BuiltinRules.Assumption
# [440/1973] Building Aesop.BuiltinRules.Subst
# [440/1973] Building Aesop.Frontend.Command
# [444/1973] Building Std.Data.String
# [451/1973] Building Aesop.Frontend
# [453/1973] Building Aesop.BuiltinRules
# [454/1973] Building Aesop.Search.Expansion
# [455/1973] Building Std.Data.HashMap
# [457/1973] Building Std
# [458/1973] Building Mathlib.Tactic.TypeStar
# [459/1973] Building Mathlib.Data.Bracket
# [459/1973] Building Mathlib.Tactic.Basic
# [459/1973] Building Mathlib.Tactic.Inhabit
# [459/1973] Building Mathlib.Init.Order.Defs
# [459/1973] Building Mathlib.Tactic.MkIffOfInductiveProp
# [459/1973] Building Mathlib.Data.Option.Defs
# [459/1973] Building Mathlib.Algebra.Group.Defs
# [459/1973] Building Mathlib.Data.List.TFAE
# [463/1973] Building Mathlib.Tactic.TFAE
# [464/1973] Building Mathlib.Tactic.Change
# [464/1973] Building Mathlib.Tactic.RSuffices
# [464/1973] Building Mathlib.Init.Control.Lawful
# [464/1973] Building Mathlib.Tactic.LiftLets
# [464/1973] Building Mathlib.Tactic.ExtractLets
# [464/1973] Building Mathlib.Tactic.DefEqTransformations
# [464/1973] Building Mathlib.Tactic.Lift
# [464/1973] Building Mathlib.Init.Function
# [464/1973] Building Mathlib.Order.Notation
# [465/1973] Building Mathlib.Init.Data.Int.Order
# [465/1973] Building Mathlib.Init.Order.LinearOrder
# [465/1973] Building Mathlib.Tactic.GCongr.Core
# [465/1973] Building Mathlib.Init.Data.Nat.Lemmas
# [469/1973] Building Aesop.Search.ExpandSafePrefix
# [474/1973] Building Mathlib.Logic.Nonempty
# [474/1973] Building Mathlib.Logic.Nontrivial.Defs
# [474/1973] Building Mathlib.Data.Prod.PProd
# [474/1973] Building Mathlib.Logic.Relator
# [474/1973] Building Mathlib.Control.Basic
# [474/1973] Building Mathlib.Logic.Basic
# [474/1973] Building Mathlib.Data.Option.NAry
# [481/1973] Building Mathlib.Data.Int.Defs
# [484/1973] Building Mathlib.Data.Bool.Basic
# [486/1973] Building Aesop.Search.Main
# [487/1973] Building Mathlib.Control.Functor
# [487/1973] Building Mathlib.Tactic.Rewrites
# [488/1973] Building Mathlib.Data.List.BigOperators.Defs
# [488/1973] Building Mathlib.Algebra.Group.Commutator
# [488/1973] Building Mathlib.Algebra.Invertible.Defs
# [488/1973] Building Mathlib.Algebra.Group.Semiconj.Defs
# [488/1973] Building Mathlib.Data.Nat.Cast.Defs
# [493/1973] Building Mathlib.Init.Data.Nat.Bitwise
# [495/1973] Building Mathlib.Logic.Function.Basic
# [495/1973] Building Mathlib.Logic.Lemmas
# [495/1973] Building Mathlib.Algebra.NeZero
# [495/1973] Building Mathlib.Tactic.Tauto
# [495/1973] Building Mathlib.Tactic.TermCongr
# [495/1973] Building Mathlib.Tactic.PushNeg
# [496/1973] Building Mathlib.Control.Applicative
# [496/1973] Building Mathlib.Data.List.Defs
# [496/1973] Building Mathlib.Control.Traversable.Basic
# [497/1973] Building Mathlib.Data.Int.Cast.Defs
# [498/1973] Building Mathlib.Data.Nat.Cast.NeZero
# [502/1973] Building Mathlib.Init.Data.Int.Bitwise
# [502/1973] Building Mathlib.Data.Num.Basic
# [506/1973] Building Mathlib.Control.Traversable.Lemmas
# [509/1973] Building Mathlib.Tactic.DeriveTraversable
# [513/1973] Building Mathlib.Tactic.Choose
# [513/1973] Building Mathlib.Algebra.CharZero.Defs
# [513/1973] Building Mathlib.Tactic.FunProp.Types
# [513/1973] Building Mathlib.Data.Sigma.Basic
# [513/1973] Building Mathlib.Tactic.ByContra
# [513/1973] Building Mathlib.Data.Sum.Basic
# [513/1973] Building Mathlib.Logic.Function.Conjugate
# [513/1973] Building Mathlib.Tactic.Contrapose
# [513/1973] Building Mathlib.Data.FunLike.Basic
# [513/1973] Building Mathlib.Logic.IsEmpty
# [513/1973] Building Mathlib.Data.Subtype
# [513/1973] Building Mathlib.Data.Prod.Basic
# [513/1973] Building Mathlib.Data.Nat.Defs
# [513/1973] Building Mathlib.Logic.Relation
# [513/1973] Building Mathlib.Algebra.GroupWithZero.Defs
# [513/1973] Building Mathlib.Algebra.Group.Basic
# [514/1973] Building Mathlib.Tactic.Congrm
# [515/1973] Building Mathlib.Tactic.FunProp.Mor
# [515/1973] Building Mathlib.Data.FunLike.Embedding
# [520/1973] Building Mathlib.Logic.Function.Iterate
# [521/1973] Building Mathlib.Logic.Unique
# [522/1973] Building Mathlib.Data.Set.Defs
# [522/1973] Building Mathlib.Tactic.IrreducibleDef
# [523/1973] Building Mathlib.Data.FunLike.Equiv
# [524/1973] Building Mathlib.Algebra.GroupWithZero.NeZero
# [524/1973] Building Mathlib.Algebra.Ring.Defs
# [524/1973] Building Mathlib.Algebra.Group.Hom.Defs
# [525/1973] Building Mathlib.Order.Basic
# [526/1973] Building Mathlib.Tactic.Widget.Congrm
# [530/1973] Building Mathlib.Algebra.Invertible.GroupWithZero
# [531/1973] Building Mathlib.Tactic.FunProp.FunctionData
# [534/1973] Building Mathlib.Logic.Nontrivial.Basic
# [534/1973] Building Mathlib.Data.Quot
# [534/1973] Building Mathlib.Data.Pi.Algebra
# [536/1973] Building Mathlib.Lean.Expr.ExtraRecognizers
# [539/1973] Building Mathlib.Tactic.FunProp.Theorems
# [540/1973] Building Aesop.Main
# [541/1973] Building Mathlib.Algebra.Ring.Semiconj
# [541/1973] Building Mathlib.Algebra.Field.Defs
# [542/1973] Building Mathlib.Tactic.Nontriviality.Core
# [544/1973] Building Mathlib.Init.Classical
# [546/1973] Building Aesop
# [549/1973] Building Mathlib.CategoryTheory.Category.Init
# [549/1973] Building Mathlib.Tactic.Continuity.Init
# [549/1973] Building Mathlib.Tactic.SetLike
# [549/1973] Building Mathlib.Tactic.Measurability.Init
# [549/1973] Building Mathlib.Data.Option.Basic
# [550/1973] Building Mathlib.Tactic.Common
# [551/1973] Building Mathlib.Logic.Equiv.Defs
# [555/1973] Building Mathlib.Tactic.Measurability
# [556/1973] Building Mathlib.Control.Bifunctor
# [556/1973] Building Mathlib.Logic.Pairwise
# [556/1973] Building Mathlib.Algebra.Field.IsField
# [556/1973] Building Mathlib.Algebra.Quotient
# [557/1973] Building Mathlib.Tactic.FunProp.Attr
# [557/1973] Building Mathlib.Tactic.FunProp.Core
# [558/1973] Building Mathlib.Tactic.Continuity
# [559/1973] Building Mathlib.Data.Int.Cast.Basic
# [559/1973] Building Mathlib.Algebra.Group.Semiconj.Basic
# [559/1973] Building Mathlib.Tactic.MoveAdd
# [560/1973] Building Mathlib.Tactic.Nontriviality
# [567/1973] Building Mathlib.Order.ULift
# [567/1973] Building Mathlib.Algebra.Order.ZeroLEOne
# [567/1973] Building Mathlib.Order.RelClasses
# [567/1973] Building Mathlib.Data.PNat.Defs
# [567/1973] Building Mathlib.Data.Tree
# [570/1973] Building Mathlib.Tactic.Zify
# [570/1973] Building Mathlib.Algebra.Group.InjSurj
# [578/1973] Building Mathlib.Logic.Equiv.Functor
# [578/1973] Building Mathlib.Tactic.ProdAssoc
# [578/1973] Building Mathlib.Tactic.ProxyType
# [578/1973] Building Mathlib.Control.Monad.Basic
# [578/1973] Building Mathlib.Data.Finite.Defs
# [578/1973] Building Mathlib.Data.Opposite
# [578/1973] Building Mathlib.Control.Monad.Writer
# [578/1973] Building Mathlib.Order.Synonym
# [578/1973] Building Mathlib.Control.EquivFunctor
# [578/1973] Building Mathlib.Logic.Small.Defs
# [578/1973] Building Mathlib.Algebra.Opposites
# [578/1973] Building Mathlib.Logic.Equiv.Basic
# [580/1973] Building Mathlib.Algebra.Group.Hom.Basic
# [581/1973] Building Mathlib.Data.Sigma.Lex
# [582/1973] Building Mathlib.Algebra.Group.TypeTags
# [582/1973] Building Mathlib.Data.Countable.Defs
# [583/1973] Building Mathlib.Logic.UnivLE
# [585/1973] Building Mathlib.Combinatorics.Quiver.Basic
# [586/1973] Building Mathlib.Logic.Equiv.Option
# [587/1973] Building Mathlib.Order.Max
# [587/1973] Building Mathlib.Algebra.Group.OrderSynonym
# [587/1973] Building Mathlib.Order.Compare
# [590/1973] Building Mathlib.Control.Monad.Cont
# [591/1973] Building Mathlib.Algebra.Ring.Basic
# [595/1973] Building Mathlib.Combinatorics.Quiver.Push
# [595/1973] Building Mathlib.Combinatorics.Quiver.Path
# [595/1973] Building Mathlib.CategoryTheory.Category.Basic
# [597/1973] Building Mathlib.Algebra.GroupWithZero.Basic
# [597/1973] Building Mathlib.Algebra.Ring.OrderSynonym
# [598/1973] Building Mathlib.Algebra.GroupWithZero.InjSurj
# [599/1973] Building Mathlib.Order.Monotone.Basic
# [600/1973] Building Mathlib.Data.Nat.Basic
# [603/1973] Building Mathlib.Data.Nat.Bits
# [603/1973] Building Mathlib.Data.List.EditDistance.Defs
# [603/1973] Building Mathlib.Tactic.NormNum.Result
# [603/1973] Building Mathlib.Tactic.Sat.FromLRAT
# [604/1973] Building Mathlib.Algebra.Ring.Hom.Defs
# [609/1973] Building Mathlib.Combinatorics.Quiver.Symmetric
# [610/1973] Building Mathlib.Algebra.Ring.InjSurj
# [613/1973] Building Mathlib.Tactic.Widget.CommDiag
# [613/1973] Building Mathlib.CategoryTheory.Functor.Basic
# [613/1973] Building Mathlib.Tactic.CategoryTheory.Slice
# [614/1973] Building Mathlib.Algebra.Group.Commute.Defs
# [615/1973] Building Mathlib.Data.Int.Basic
# [615/1973] Building Mathlib.Order.Iterate
# [615/1973] Building Mathlib.Algebra.CovariantAndContravariant
# [615/1973] Building Mathlib.Order.Lattice
# [622/1973] Building Mathlib.Algebra.Group.Commute.Basic
# [622/1973] Building Mathlib.Algebra.Group.Commute.Hom
# [623/1973] Building Mathlib.Tactic.CategoryTheory.Reassoc
# [625/1973] Building Mathlib.Data.ULift
# [625/1973] Building Mathlib.Logic.Embedding.Basic
# [625/1973] Building Mathlib.Control.ULiftable
# [625/1973] Building Mathlib.Algebra.Group.Equiv.Basic
# [626/1973] Building Mathlib.Algebra.Order.Ring.Lemmas
# [628/1973] Building Mathlib.Tactic.NormNum.Core
# [631/1973] Building Mathlib.CategoryTheory.NatTrans
# [631/1973] Building Mathlib.CategoryTheory.Iso
# [633/1973] Building Mathlib.Algebra.GroupPower.Basic
# [635/1973] Building Mathlib.Tactic.FunProp.Elab
# [637/1973] Building Mathlib.Order.MinMax
# [637/1973] Building Mathlib.Order.BoundedOrder
# [638/1973] Building Mathlib.Tactic.FunProp
# [639/1973] Building Mathlib.Algebra.Group.Embedding
# [639/1973] Building Mathlib.Order.RelIso.Basic
# [639/1973] Building Mathlib.GroupTheory.GroupAction.Defs
# [644/1973] Building Mathlib.CategoryTheory.Functor.Category
# [644/1973] Building Mathlib.Algebra.Order.Monoid.Lemmas
# [646/1973] Building Mathlib.Algebra.Group.Equiv.TypeTags
# [646/1973] Building Mathlib.Algebra.Group.ULift
# [647/1973] Building Mathlib.Algebra.Group.Hom.Instances
# [647/1973] Building Mathlib.Algebra.GroupPower.Hom
# [647/1973] Building Mathlib.Algebra.Divisibility.Basic
# [647/1973] Building Mathlib.Algebra.Group.Units
# [648/1973] Building Mathlib.Data.Prod.Lex
# [648/1973] Building Mathlib.Order.Disjoint
# [648/1973] Building Mathlib.Order.WithBot
# [651/1973] Building Mathlib.Algebra.Ring.Divisibility.Basic
# [651/1973] Building Mathlib.Algebra.EuclideanDomain.Defs
# [651/1973] Building Mathlib.Data.Nat.Cast.Basic
# [652/1973] Building Mathlib.CategoryTheory.Thin
# [652/1973] Building Mathlib.CategoryTheory.NatIso
# [658/1973] Building Mathlib.Order.PropInstances
# [660/1973] Building Mathlib.CategoryTheory.Functor.FullyFaithful
# [660/1973] Building Mathlib.CategoryTheory.Bicategory.Basic
# [662/1973] Building Mathlib.Order.Heyting.Basic
# [663/1973] Building Mathlib.GroupTheory.GroupAction.Ring
# [664/1973] Building Mathlib.Algebra.Order.Monoid.MinMax
# [664/1973] Building Mathlib.Algebra.Order.Monoid.Defs
# [664/1973] Building Mathlib.Algebra.Order.Sub.Defs
# [664/1973] Building Mathlib.Algebra.Order.Monoid.NatCast
# [667/1973] Building Mathlib.Algebra.Group.WithOne.Defs
# [667/1973] Building Mathlib.Order.Hom.Basic
# [669/1973] Building Mathlib.Algebra.Group.Semiconj.Units
# [669/1973] Building Mathlib.Data.Nat.Units
# [669/1973] Building Mathlib.Algebra.Divisibility.Units
# [669/1973] Building Mathlib.Algebra.Group.Units.Hom
# [669/1973] Building Mathlib.GroupTheory.GroupAction.Units
# [669/1973] Building Mathlib.Algebra.Regular.Basic
# [669/1973] Building Mathlib.Algebra.GroupWithZero.Units.Basic
# [669/1973] Building Mathlib.Algebra.Group.Opposite
# [670/1973] Building Mathlib.Algebra.Order.Monoid.Canonical.Defs
# [670/1973] Building Mathlib.Algebra.Order.Monoid.OrderDual
# [671/1973] Building Mathlib.Algebra.Order.Group.Defs
# [673/1973] Building Mathlib.CategoryTheory.FullSubcategory
# [673/1973] Building Mathlib.CategoryTheory.Whiskering
# [675/1973] Building Mathlib.Algebra.GroupPower.CovariantClass
# [677/1973] Building Mathlib.Algebra.Group.Commute.Units
# [678/1973] Building Mathlib.Algebra.GroupWithZero.Divisibility
# [679/1973] Building Mathlib.Algebra.GroupWithZero.Semiconj
# [680/1973] Building Mathlib.Algebra.Ring.Regular
# [682/1973] Building Mathlib.Algebra.Order.Monoid.WithZero.Defs
# [682/1973] Building Mathlib.Algebra.Order.Monoid.TypeTags
# [682/1973] Building Mathlib.Algebra.Order.Sub.Canonical
# [682/1973] Building Mathlib.Algebra.Order.Monoid.WithTop
# [685/1973] Building Mathlib.Algebra.GroupWithZero.Commute
# [686/1973] Building Mathlib.Algebra.Ring.Units
# [686/1973] Building Mathlib.Algebra.Group.Units.Equiv
# [688/1973] Building Mathlib.CategoryTheory.EssentialImage
# [689/1973] Building Mathlib.Algebra.EuclideanDomain.Basic
# [692/1973] Building Mathlib.Algebra.Order.Monoid.Basic
# [692/1973] Building Mathlib.Order.Antisymmetrization
# [692/1973] Building Mathlib.Tactic.ApplyFun
# [692/1973] Building Mathlib.Algebra.Order.Monoid.Units
# [692/1973] Building Mathlib.Order.Hom.Bounded
# [692/1973] Building Mathlib.Data.Sum.Order
# [693/1973] Building Mathlib.Algebra.GroupWithZero.Units.Lemmas
# [694/1973] Building Mathlib.Data.Int.Units
# [694/1973] Building Mathlib.Algebra.Ring.Commute
# [700/1973] Building Mathlib.Order.Estimator
# [700/1973] Building Mathlib.Order.BooleanAlgebra
# [701/1973] Building Mathlib.Algebra.GroupWithZero.Units.Equiv
# [702/1973] Building Mathlib.CategoryTheory.Bicategory.Functor
# [703/1973] Building Mathlib.GroupTheory.GroupAction.Opposite
# [703/1973] Building Mathlib.Algebra.Ring.Opposite
# [703/1973] Building Mathlib.Algebra.Group.Prod
# [704/1973] Building Mathlib.Data.Nat.Cast.Commute
# [705/1973] Building Mathlib.Algebra.Order.Sub.WithTop
# [705/1973] Building Mathlib.Data.Nat.Cast.WithTop
# [710/1973] Building Mathlib.Data.Int.Cast.Field
# [710/1973] Building Mathlib.Algebra.Invertible.Basic
# [710/1973] Building Mathlib.Algebra.Field.Basic
# [712/1973] Building Mathlib.Algebra.Order.Group.TypeTags
# [712/1973] Building Mathlib.Algebra.Order.Group.WithTop
# [712/1973] Building Mathlib.Algebra.Order.Group.Units
# [712/1973] Building Mathlib.Algebra.Order.Group.OrderIso
# [712/1973] Building Mathlib.Algebra.Order.Group.InjSurj
# [712/1973] Building Mathlib.Algebra.Order.Group.Instances
# [713/1973] Building Mathlib.Algebra.Order.Ring.Defs
# [719/1973] Building Mathlib.Algebra.Order.WithZero
# [721/1973] Building Mathlib.Algebra.GroupPower.IterateHom
# [725/1973] Building Mathlib.CategoryTheory.Equivalence
# [726/1973] Building Mathlib.Algebra.Order.Group.Lattice
# [728/1973] Building Mathlib.Tactic.NormNum.Basic
# [731/1973] Building Mathlib.Data.Nat.Cast.Prod
# [731/1973] Building Mathlib.GroupTheory.GroupAction.Prod
# [731/1973] Building Mathlib.Algebra.Order.Monoid.Prod
# [732/1973] Building Mathlib.Algebra.Order.Group.Abs
# [734/1973] Building Mathlib.Order.SymmDiff
# [735/1973] Building Mathlib.Data.Int.Cast.Prod
# [736/1973] Building Mathlib.Algebra.Order.Group.Prod
# [739/1973] Building Mathlib.Algebra.SMulWithZero
# [740/1973] Building Mathlib.Order.Hom.Lattice
# [740/1973] Building Mathlib.Data.Set.Basic
# [741/1973] Building Mathlib.Algebra.Order.Group.MinMax
# [742/1973] Building Mathlib.Algebra.Regular.SMul
# [745/1973] Building Mathlib.Algebra.Order.Ring.CharZero
# [745/1973] Building Mathlib.Algebra.Order.Positive.Ring
# [745/1973] Building Mathlib.Algebra.Order.Field.Defs
# [745/1973] Building Mathlib.Algebra.Order.Ring.InjSurj
# [745/1973] Building Mathlib.Algebra.Order.Ring.Canonical
# [747/1973] Building Mathlib.Algebra.Order.Ring.WithTop
# [747/1973] Building Mathlib.Data.Nat.Order.Basic
# [749/1973] Building Mathlib.Algebra.Order.Field.Canonical.Defs
# [751/1973] Building Mathlib.CategoryTheory.Opposites
# [751/1973] Building Mathlib.CategoryTheory.Adjunction.Basic
# [751/1973] Building Mathlib.CategoryTheory.Category.Preorder
# [752/1973] Building Mathlib.CategoryTheory.Bicategory.Free
# [753/1973] Building Mathlib.Algebra.Order.Field.Canonical.Basic
# [754/1973] Building Mathlib.Algebra.Order.Field.InjSurj
# [758/1973] Building Mathlib.Data.Vector
# [758/1973] Building Mathlib.Algebra.GroupPower.Ring
# [758/1973] Building Mathlib.Data.Nat.Cast.Order
# [758/1973] Building Mathlib.Data.Nat.ForSqrt
# [758/1973] Building Mathlib.Data.Nat.WithBot
# [758/1973] Building Mathlib.Data.Nat.MaxPowDiv
# [758/1973] Building Mathlib.Data.Int.Order.Basic
# [758/1973] Building Mathlib.Data.List.Basic
# [761/1973] Building Mathlib.Algebra.GroupPower.Order
# [764/1973] Building Mathlib.Data.PEquiv
# [764/1973] Building Mathlib.Data.Set.BoolIndicator
# [764/1973] Building Mathlib.Algebra.Ring.Hom.Basic
# [764/1973] Building Mathlib.Data.SetLike.Basic
# [764/1973] Building Mathlib.Order.Circular
# [764/1973] Building Mathlib.Order.WellFounded
# [764/1973] Building Mathlib.Data.Nat.Order.Lemmas
# [764/1973] Building Mathlib.Data.Part
# [764/1973] Building Mathlib.Data.PNat.Basic
# [764/1973] Building Mathlib.Data.Set.Intervals.Basic
# [764/1973] Building Mathlib.Data.Set.Image
# [766/1973] Building Mathlib.Algebra.GroupWithZero.Power
# [766/1973] Building Mathlib.Data.Int.LeastGreatest
# [767/1973] Building Mathlib.Data.Int.Range
# [768/1973] Building Mathlib.Algebra.EuclideanDomain.Instances
# [769/1973] Building Mathlib.Data.Rat.Defs
# [771/1973] Building Mathlib.Data.Int.Cast.Lemmas
# [771/1973] Building Mathlib.Algebra.Order.Invertible
# [772/1973] Building Mathlib.Algebra.Order.Ring.Pow
# [773/1973] Building Mathlib.Data.Int.Dvd.Basic
# [774/1973] Building Mathlib.Tactic.Linarith.Lemmas
# [776/1973] Building Mathlib.CategoryTheory.Functor.Const
# [776/1973] Building Mathlib.CategoryTheory.EqToHom
# [779/1973] Building Mathlib.Data.Nat.GCD.Basic
# [783/1973] Building Mathlib.Data.Int.Div
# [787/1973] Building Mathlib.Tactic.CategoryTheory.BicategoryCoherence
# [789/1973] Building Mathlib.CategoryTheory.Category.ULift
# [789/1973] Building Mathlib.CategoryTheory.Bicategory.Strict
# [789/1973] Building Mathlib.CategoryTheory.Comma.Basic
# [789/1973] Building Mathlib.CategoryTheory.DiscreteCategory
# [790/1973] Building Mathlib.Data.Rat.Basic
# [792/1973] Building Mathlib.CategoryTheory.Products.Basic
# [794/1973] Building Mathlib.Data.Bool.Set
# [794/1973] Building Mathlib.Data.Nat.Set
# [794/1973] Building Mathlib.Data.Set.Sigma
# [794/1973] Building Mathlib.Order.Directed
# [794/1973] Building Mathlib.Data.Set.Prod
# [794/1973] Building Mathlib.Logic.Embedding.Set
# [795/1973] Building Mathlib.Algebra.Field.Opposite
# [795/1973] Building Mathlib.Data.Rat.Order
# [795/1973] Building Mathlib.Tactic.NormNum.Pow
# [795/1973] Building Mathlib.Tactic.Positivity.Core
# [796/1973] Building Mathlib.Data.Rat.Lemmas
# [798/1973] Building Mathlib.Data.Nat.Size
# [798/1973] Building Mathlib.Data.Nat.Pow
# [799/1973] Building Mathlib.Algebra.Order.Ring.Abs
# [802/1973] Building Mathlib.Order.RelIso.Set
# [806/1973] Building Mathlib.Data.Nat.Factorial.Basic
# [810/1973] Building Mathlib.Algebra.Parity
# [810/1973] Building Mathlib.Data.Int.Order.Units
# [810/1973] Building Mathlib.Data.Int.Order.Lemmas
# [812/1973] Building Mathlib.Data.Rat.Cast.Defs
# [813/1973] Building Mathlib.CategoryTheory.PEmpty
# [813/1973] Building Mathlib.CategoryTheory.PUnit
# [815/1973] Building Mathlib.Data.Set.Intervals.Instances
# [815/1973] Building Mathlib.Data.Set.Intervals.WithBotTop
# [815/1973] Building Mathlib.Data.Set.Intervals.Group
# [815/1973] Building Mathlib.Data.Nat.Log
# [815/1973] Building Mathlib.Order.Bounded
# [819/1973] Building Mathlib.Data.Nat.Choose.Basic
# [821/1973] Building Mathlib.Tactic.FieldSimp
# [822/1973] Building Mathlib.Data.Set.NAry
# [822/1973] Building Mathlib.Data.Set.Function
# [828/1973] Building Mathlib.Tactic.NormNum.OfScientific
# [829/1973] Building Mathlib.Data.List.Lex
# [829/1973] Building Mathlib.Data.List.Palindrome
# [829/1973] Building Mathlib.Data.List.Infix
# [829/1973] Building Mathlib.Data.Nat.Bitwise
# [829/1973] Building Mathlib.Data.List.MinMax
# [829/1973] Building Mathlib.Data.List.Pairwise
# [829/1973] Building Mathlib.Data.Set.List
# [829/1973] Building Mathlib.Data.List.Lattice
# [830/1973] Building Mathlib.Order.Bounds.Basic
# [833/1973] Building Mathlib.Data.Nat.Sqrt
# [833/1973] Building Mathlib.Algebra.Associated
# [840/1973] Building Mathlib.Data.List.Forall2
# [842/1973] Building Mathlib.CategoryTheory.Functor.Currying
# [842/1973] Building Mathlib.CategoryTheory.Pi.Basic
# [842/1973] Building Mathlib.CategoryTheory.Monoidal.Category
# [843/1973] Building Mathlib.Data.Set.Intervals.Image
# [843/1973] Building Mathlib.Algebra.Group.Pi
# [843/1973] Building Mathlib.Data.Set.Intervals.Monoid
# [843/1973] Building Mathlib.Logic.Equiv.PartialEquiv
# [843/1973] Building Mathlib.Data.Set.Pairwise.Basic
# [843/1973] Building Mathlib.Logic.Equiv.Set
# [844/1973] Building Mathlib.Data.Int.Bitwise
# [845/1973] Building Mathlib.Data.List.EditDistance.Bounds
# [846/1973] Building Mathlib.Order.LatticeIntervals
# [846/1973] Building Mathlib.Data.Int.GCD
# [847/1973] Building Mathlib.Data.List.Chain
# [847/1973] Building Mathlib.Data.List.BigOperators.Basic
# [849/1973] Building Mathlib.Algebra.GroupWithZero.Bitwise
# [849/1973] Building Mathlib.Data.Int.Lemmas
# [851/1973] Building Mathlib.Data.Set.Intervals.UnorderedInterval
# [852/1973] Building Mathlib.Data.List.Nodup
# [853/1973] Building Mathlib.Data.List.EditDistance.Estimator
# [859/1973] Building Mathlib.Logic.Small.Basic
# [859/1973] Building Mathlib.Order.Hom.Set
# [859/1973] Building Mathlib.Algebra.Ring.Equiv
# [859/1973] Building Mathlib.Order.InitialSeg
# [860/1973] Building Mathlib.Data.Prod.TProd
# [860/1973] Building Mathlib.Data.List.Duplicate
# [862/1973] Building Mathlib.Algebra.Ring.Pi
# [862/1973] Building Mathlib.GroupTheory.GroupAction.Pi
# [862/1973] Building Mathlib.Data.Pi.Lex
# [862/1973] Building Mathlib.GroupTheory.Perm.Basic
# [864/1973] Building Mathlib.Data.Set.Intervals.OrderIso
# [864/1973] Building Mathlib.Order.Bounds.OrderIso
# [864/1973] Building Mathlib.Order.Antichain
# [864/1973] Building Mathlib.Data.Fin.Basic
# [864/1973] Building Mathlib.Order.CompleteLattice
# [866/1973] Building Mathlib.Data.Set.Intervals.OrderEmbedding
# [868/1973] Building Mathlib.Data.List.Count
# [868/1973] Building Mathlib.Data.List.Join
# [868/1973] Building Mathlib.Algebra.FreeMonoid.Basic
# [869/1973] Building Mathlib.Data.List.Zip
# [870/1973] Building Mathlib.Algebra.Order.Field.Basic
# [871/1973] Building Mathlib.Data.List.BigOperators.Lemmas
# [874/1973] Building Mathlib.Algebra.GCDMonoid.Basic
# [874/1973] Building Mathlib.Data.Nat.Prime
# [876/1973] Building Mathlib.Algebra.Order.Pi
# [877/1973] Building Mathlib.Data.List.Dedup
# [878/1973] Building Mathlib.Data.List.Permutation
# [881/1973] Building Mathlib.Dynamics.FixedPoints.Basic
# [881/1973] Building Mathlib.GroupTheory.Perm.ViaEmbedding
# [881/1973] Building Mathlib.Algebra.Group.Aut
# [883/1973] Building Mathlib.Data.List.Perm
# [885/1973] Building Mathlib.Algebra.Ring.CompTypeclasses
# [885/1973] Building Mathlib.Algebra.Ring.ULift
# [885/1973] Building Mathlib.Algebra.Ring.Prod
# [886/1973] Building Mathlib.Data.List.Range
# [886/1973] Building Mathlib.Data.List.Rotate
# [892/1973] Building Mathlib.CategoryTheory.Groupoid
# [892/1973] Building Mathlib.GroupTheory.GroupAction.Group
# [892/1973] Building Mathlib.Algebra.Group.Conj
# [893/1973] Building Mathlib.CategoryTheory.Comma.Arrow
# [894/1973] Building Mathlib.Data.List.NatAntidiagonal
# [895/1973] Building Mathlib.Data.PNat.Prime
# [895/1973] Building Mathlib.Tactic.NormNum.Prime
# [897/1973] Building Mathlib.CategoryTheory.EpiMono
# [898/1973] Building Mathlib.Algebra.Order.Kleene
# [904/1973] Building Mathlib.CategoryTheory.Balanced
# [904/1973] Building Mathlib.CategoryTheory.Types
# [905/1973] Building Mathlib.CategoryTheory.CommSq
# [906/1973] Building Mathlib.Algebra.GroupRingAction.Basic
# [908/1973] Building Mathlib.Control.Random
# [908/1973] Building Mathlib.Data.Fin.Tuple.Basic
# [909/1973] Building Mathlib.Algebra.Ring.Aut
# [911/1973] Building Mathlib.CategoryTheory.Category.Cat
# [911/1973] Building Mathlib.CategoryTheory.Functor.Hom
# [912/1973] Building Mathlib.CategoryTheory.LiftingProperties.Basic
# [913/1973] Building Mathlib.Testing.SlimCheck.Gen
# [914/1973] Building Mathlib.Data.List.Prime
# [914/1973] Building Mathlib.Data.List.Sublists
# [914/1973] Building Mathlib.Data.Multiset.Basic
# [915/1973] Building Mathlib.Order.GaloisConnection
# [915/1973] Building Mathlib.Order.CompleteBooleanAlgebra
# [916/1973] Building Mathlib.Algebra.Star.Basic
# [918/1973] Building Mathlib.CategoryTheory.LiftingProperties.Adjunction
# [918/1973] Building Mathlib.CategoryTheory.Limits.Shapes.StrongEpi
# [919/1973] Building Mathlib.Testing.SlimCheck.Sampleable
# [920/1973] Building Mathlib.Data.Nat.Cast.Field
# [920/1973] Building Mathlib.Tactic.CancelDenoms.Core
# [922/1973] Building Mathlib.CategoryTheory.IsomorphismClasses
# [925/1973] Building Mathlib.Testing.SlimCheck.Testable
# [928/1973] Building Mathlib.CategoryTheory.Functor.EpiMono
# [929/1973] Building Mathlib.CategoryTheory.Skeletal
# [930/1973] Building Mathlib.CategoryTheory.Yoneda
# [931/1973] Building Mathlib.Order.Hom.Order
# [931/1973] Building Mathlib.Data.Setoid.Basic
# [932/1973] Building Mathlib.CategoryTheory.Monoidal.Functor
# [933/1973] Building Mathlib.Algebra.Star.Pi
# [933/1973] Building Mathlib.Algebra.Star.Prod
# [934/1973] Building Mathlib.Tactic.SlimCheck
# [935/1973] Building Mathlib.CategoryTheory.Functor.ReflectsIso
# [938/1973] Building Mathlib.Data.Set.Lattice
# [941/1973] Building Mathlib.Order.FixedPoints
# [944/1973] Building Mathlib.Data.List.OfFn
# [944/1973] Building Mathlib.Data.Fin.VecNotation
# [946/1973] Building Mathlib.CategoryTheory.EssentiallySmall
# [948/1973] Building Mathlib.Logic.Equiv.Fin
# [949/1973] Building Mathlib.Data.List.Sort
# [949/1973] Building Mathlib.Data.List.FinRange
# [949/1973] Building Mathlib.Data.Vector.Basic
# [949/1973] Building Mathlib.Data.List.Indexes
# [951/1973] Building Mathlib.CategoryTheory.Monoidal.Free.Basic
# [953/1973] Building Mathlib.Algebra.Ring.Fin
# [955/1973] Building Mathlib.CategoryTheory.Limits.Cones
# [956/1973] Building Mathlib.Data.Nat.Factors
# [956/1973] Building Mathlib.Data.List.NodupEquivFin
# [957/1973] Building Mathlib.Data.Multiset.Sort
# [957/1973] Building Mathlib.Data.Multiset.Range
# [957/1973] Building Mathlib.Algebra.BigOperators.Multiset.Basic
# [958/1973] Building Mathlib.Data.Sym.Basic
# [959/1973] Building Mathlib.Data.Set.Intervals.Disjoint
# [959/1973] Building Mathlib.Data.Set.Intervals.Pi
# [959/1973] Building Mathlib.Data.Set.Accumulate
# [959/1973] Building Mathlib.Data.Set.Intervals.OrdConnected
# [959/1973] Building Mathlib.Data.Nat.Pairing
# [959/1973] Building Mathlib.Topology.Defs.Basic
# [959/1973] Building Mathlib.Order.Chain
# [959/1973] Building Mathlib.Data.Set.Pointwise.Basic
# [959/1973] Building Mathlib.GroupTheory.Subsemigroup.Basic
# [959/1973] Building Mathlib.Order.ConditionallyCompleteLattice.Basic
# [959/1973] Building Mathlib.Tactic.Monotonicity.Lemmas
# [959/1973] Building Mathlib.Data.Set.Functor
# [960/1973] Building Mathlib.Data.Set.UnionLift
# [961/1973] Building Mathlib.Order.Hom.CompleteLattice
# [962/1973] Building Mathlib.Order.Closure
# [963/1973] Building Mathlib.Tactic.Monotonicity
# [965/1973] Building Mathlib.Tactic.CategoryTheory.Coherence
# [968/1973] Building Mathlib.Data.Set.Intervals.OrdConnectedComponent
# [968/1973] Building Mathlib.Data.Set.Intervals.ProjIcc
# [968/1973] Building Mathlib.Order.UpperLower.Basic
# [968/1973] Building Mathlib.Order.Cover
# [969/1973] Building Mathlib.Order.Zorn
# [970/1973] Building Mathlib.Order.OmegaCompletePartialOrder
# [973/1973] Building Mathlib.Logic.Equiv.Nat
# [974/1973] Building Mathlib.GroupTheory.Subsemigroup.Membership
# [974/1973] Building Mathlib.GroupTheory.Subsemigroup.Operations
# [974/1973] Building Mathlib.GroupTheory.Submonoid.Basic
# [975/1973] Building Mathlib.SetTheory.Cardinal.SchroederBernstein
# [979/1973] Building Mathlib.Data.Countable.Basic
# [979/1973] Building Mathlib.Logic.Encodable.Basic
# [983/1973] Building Mathlib.Algebra.Function.Support
# [983/1973] Building Mathlib.Order.ModularLattice
# [983/1973] Building Mathlib.Order.SuccPred.Basic
# [984/1973] Building Mathlib.Algebra.BigOperators.Multiset.Lemmas
# [984/1973] Building Mathlib.Data.Multiset.Bind
# [988/1973] Building Mathlib.Data.Rat.Encodable
# [988/1973] Building Mathlib.Logic.Encodable.Lattice
# [992/1973] Building Mathlib.Order.Atoms
# [993/1973] Building Mathlib.GroupTheory.Submonoid.MulOpposite
# [995/1973] Building Mathlib.Algebra.CharZero.Lemmas
# [995/1973] Building Mathlib.Data.Int.CharZero
# [995/1973] Building Mathlib.Algebra.Function.Indicator
# [996/1973] Building Mathlib.Order.ConditionallyCompleteLattice.Group
# [996/1973] Building Mathlib.Order.CompleteLatticeIntervals
# [996/1973] Building Mathlib.Order.Copy
# [999/1973] Building Mathlib.Data.Set.Pointwise.ListOfFn
# [999/1973] Building Mathlib.Data.Set.Semiring
# ...
# [1802/1973] Building Mathlib.Analysis.Convex.Between
# [1805/1973] Building Mathlib.LinearAlgebra.Matrix.Block
# [1805/1973] Building Mathlib.LinearAlgebra.Determinant
# [1805/1973] Building Mathlib.LinearAlgebra.UnitaryGroup
# [1805/1973] Building Mathlib.LinearAlgebra.Matrix.GeneralLinearGroup
# [1805/1973] Building Mathlib.Topology.Instances.Matrix
# [1806/1973] Building Mathlib.Analysis.Calculus.Deriv.Slope
# [1806/1973] Building Mathlib.Analysis.Calculus.Deriv.Comp
# [1809/1973] Building Mathlib.LinearAlgebra.Vandermonde
# [1813/1973] Building Mathlib.Analysis.Convex.Normed
# [1814/1973] Building Mathlib.LinearAlgebra.Matrix.ToLinearEquiv
# [1815/1973] Building Mathlib.Analysis.Convex.StrictConvexSpace
# [1816/1973] Building Mathlib.Analysis.Convex.Uniform
# [1817/1973] Building Mathlib.LinearAlgebra.Matrix.SesquilinearForm
# [1818/1973] Building Mathlib.RingTheory.HahnSeries
# [1820/1973] Building Mathlib.RingTheory.MatrixAlgebra
# [1821/1973] Building Mathlib.Analysis.NormedSpace.Multilinear.Curry
# [1821/1973] Building Mathlib.Analysis.NormedSpace.BoundedLinearMaps
# [1822/1973] Building Mathlib.Topology.Algebra.Module.Determinant
# [1824/1973] Building Mathlib.RingTheory.PolynomialAlgebra
# [1825/1973] Building Mathlib.Analysis.Calculus.FDeriv.Linear
# [1826/1973] Building Mathlib.LinearAlgebra.Matrix.Charpoly.Basic
# [1827/1973] Building Mathlib.Analysis.Calculus.Deriv.Linear
# [1827/1973] Building Mathlib.Analysis.Calculus.FDeriv.Prod
# [1827/1973] Building Mathlib.Analysis.Calculus.FDeriv.Add
# [1827/1973] Building Mathlib.Analysis.Calculus.FDeriv.Equiv
# [1828/1973] Building Mathlib.LinearAlgebra.Matrix.Charpoly.Coeff
# [1830/1973] Building Mathlib.Analysis.Calculus.Deriv.Inverse
# [1831/1973] Building Mathlib.RingTheory.LaurentSeries
# [1832/1973] Building Mathlib.Analysis.Calculus.FDeriv.Bilinear
# [1834/1973] Building Mathlib.Analysis.Calculus.Conformal.NormedSpace
# [1834/1973] Building Mathlib.Analysis.Calculus.Deriv.Add
# [1834/1973] Building Mathlib.Analysis.Calculus.FDeriv.Pi
# [1835/1973] Building Mathlib.Analysis.Calculus.FormalMultilinearSeries
# [1838/1973] Building Mathlib.FieldTheory.RatFunc
# [1839/1973] Building Mathlib.Analysis.Calculus.LocalExtr.Basic
# [1839/1973] Building Mathlib.Analysis.Calculus.Deriv.AffineMap
# [1840/1973] Building Mathlib.Analysis.Calculus.FDeriv.Mul
# [1842/1973] Building Mathlib.LinearAlgebra.Matrix.Charpoly.LinearMap
# [1844/1973] Building Mathlib.Analysis.Calculus.LocalExtr.Rolle
# [1846/1973] Building Mathlib.Analysis.Calculus.ContDiff.Defs
# [1847/1973] Building Mathlib.RingTheory.IntegralClosure
# [1848/1973] Building Mathlib.FieldTheory.Minpoly.Basic
# [1848/1973] Building Mathlib.RingTheory.Algebraic
# [1850/1973] Building Mathlib.FieldTheory.Minpoly.Field
# [1850/1973] Building Mathlib.RingTheory.Localization.Integral
# [1851/1973] Building Mathlib.Analysis.Calculus.Deriv.Mul
# [1852/1973] Building Mathlib.RingTheory.IntegrallyClosed
# [1852/1973] Building Mathlib.RingTheory.Ideal.Over
# [1853/1973] Building Mathlib.Algebra.GCDMonoid.IntegrallyClosed
# [1853/1973] Building Mathlib.RingTheory.Polynomial.RationalRoot
# [1857/1973] Building Mathlib.LinearAlgebra.Charpoly.Basic
# [1857/1973] Building Mathlib.RingTheory.PowerBasis
# [1858/1973] Building Mathlib.LinearAlgebra.FreeModule.StrongRankCondition
# [1859/1973] Building Mathlib.LinearAlgebra.FreeModule.Finite.Matrix
# [1859/1973] Building Mathlib.LinearAlgebra.Dual
# [1860/1973] Building Mathlib.FieldTheory.Tower
# [1860/1973] Building Mathlib.Topology.Algebra.Module.FiniteDimension
# [1861/1973] Building Mathlib.RingTheory.DedekindDomain.Basic
# [1862/1973] Building Mathlib.FieldTheory.IntermediateField
# [1862/1973] Building Mathlib.Data.Complex.Module
# [1864/1973] Building Mathlib.RingTheory.Adjoin.PowerBasis
# [1864/1973] Building Mathlib.LinearAlgebra.Matrix.Charpoly.Minpoly
# [1864/1973] Building Mathlib.FieldTheory.Separable
# [1864/1973] Building Mathlib.RingTheory.AdjoinRoot
# [1865/1973] Building Mathlib.Analysis.Calculus.IteratedDeriv.Defs
# [1865/1973] Building Mathlib.Analysis.Calculus.ContDiff.Basic
# [1866/1973] Building Mathlib.Analysis.Calculus.Deriv.Inv
# [1866/1973] Building Mathlib.Analysis.Calculus.Deriv.Pow
# [1866/1973] Building Mathlib.Analysis.Calculus.MeanValue
# [1871/1973] Building Mathlib.Analysis.Complex.Basic
# [1872/1973] Building Mathlib.FieldTheory.Finite.Basic
# [1874/1973] Building Mathlib.MeasureTheory.Constructions.BorelSpace.ContinuousLinearMap
# [1874/1973] Building Mathlib.Analysis.NormedSpace.FiniteDimension
# [1876/1973] Building Mathlib.Analysis.Calculus.ContDiff.IsROrC
# [1879/1973] Building Mathlib.NumberTheory.LegendreSymbol.QuadraticChar.Basic
# [1880/1973] Building Mathlib.NumberTheory.LegendreSymbol.Basic
# [1882/1973] Building Mathlib.RingTheory.Adjoin.Field
# [1883/1973] Building Mathlib.LinearAlgebra.BilinearForm.Properties
# [1883/1973] Building Mathlib.LinearAlgebra.Contraction
# [1884/1973] Building Mathlib.FieldTheory.SplittingField.IsSplittingField
# [1885/1973] Building Mathlib.Data.IsROrC.Lemmas
# [1887/1973] Building Mathlib.FieldTheory.Adjoin
# [1887/1973] Building Mathlib.FieldTheory.SplittingField.Construction
# [1888/1973] Building Mathlib.Analysis.SpecialFunctions.Exp
# [1888/1973] Building Mathlib.Analysis.InnerProductSpace.Basic
# [1889/1973] Building Mathlib.LinearAlgebra.Trace
# [1890/1973] Building Mathlib.Analysis.Complex.Circle
# [1890/1973] Building Mathlib.Analysis.SpecialFunctions.Log.Basic
# [1890/1973] Building Mathlib.Analysis.SpecialFunctions.Trigonometric.Basic
# [1891/1973] Building Mathlib.Analysis.Complex.Isometry
# [1892/1973] Building Mathlib.FieldTheory.Perfect
# [1892/1973] Building Mathlib.RingTheory.Polynomial.GaussLemma
# [1894/1973] Building Mathlib.Analysis.SpecialFunctions.Trigonometric.Inverse
# [1894/1973] Building Mathlib.Analysis.SpecialFunctions.Trigonometric.Angle
# [1895/1973] Building Mathlib.FieldTheory.Minpoly.IsIntegrallyClosed
# [1897/1973] Building Mathlib.Tactic.FunProp.Continuous
# [1898/1973] Building Mathlib.Analysis.Complex.Conformal
# [1899/1973] Building Mathlib.LinearAlgebra.BilinearForm.Orthogonal
# [1899/1973] Building Mathlib.LinearAlgebra.BilinearForm.DualLattice
# [1899/1973] Building Mathlib.LinearAlgebra.Matrix.BilinearForm
# [1902/1973] Building Mathlib.RingTheory.RootsOfUnity.Minpoly
# [1904/1973] Building Mathlib.Analysis.Calculus.IteratedDeriv.Lemmas
# [1904/1973] Building Mathlib.Analysis.Complex.RealDeriv
# [1904/1973] Building Mathlib.Tactic.FunProp.Measurable
# [1909/1973] Building Mathlib.Analysis.SpecialFunctions.Complex.Arg
# [1911/1973] Building Mathlib.Analysis.SpecialFunctions.ExpDeriv
# [1912/1973] Building Mathlib.Analysis.SpecialFunctions.Log.Deriv
# [1913/1973] Building Mathlib.Analysis.SpecialFunctions.Complex.Log
# [1914/1973] Building Mathlib.RingTheory.RootsOfUnity.Complex
# [1914/1973] Building Mathlib.Analysis.SpecialFunctions.Pow.Complex
# [1915/1973] Building Mathlib.RingTheory.Polynomial.Cyclotomic.Basic
# [1916/1973] Building Mathlib.Tactic.FunProp.Differentiable
# [1917/1973] Building Mathlib.Analysis.SpecialFunctions.Pow.Real
# [1918/1973] Building Mathlib.Tactic.FunProp.ContDiff
# [1920/1973] Building Mathlib.FieldTheory.Extension
# [1921/1973] Building Mathlib.RingTheory.Polynomial.Cyclotomic.Roots
# [1923/1973] Building Mathlib.Analysis.Complex.Arg
# [1923/1973] Building Mathlib.Analysis.InnerProductSpace.Symmetric
# [1923/1973] Building Mathlib.Analysis.InnerProductSpace.Orthogonal
# [1924/1973] Building Mathlib.Analysis.Convex.SpecificFunctions.Basic
# [1924/1973] Building Mathlib.Analysis.SpecialFunctions.Pow.NNReal
# [1925/1973] Building Mathlib.RingTheory.Polynomial.Cyclotomic.Expand
# [1926/1973] Building Mathlib.RingTheory.Polynomial.Cyclotomic.Eval
# [1928/1973] Building Mathlib.Analysis.InnerProductSpace.Projection
# [1931/1973] Building Mathlib.Analysis.MeanInequalities
# [1933/1973] Building Mathlib.FieldTheory.Normal
# [1934/1973] Building Mathlib.Analysis.NormedSpace.PiLp
# [1935/1973] Building Mathlib.FieldTheory.NormalClosure
# [1935/1973] Building Mathlib.FieldTheory.Fixed
# [1935/1973] Building Mathlib.FieldTheory.IsAlgClosed.Basic
# [1939/1973] Building Mathlib.FieldTheory.IsAlgClosed.AlgebraicClosure
# [1940/1973] Building Mathlib.Analysis.InnerProductSpace.PiL2
# [1941/1973] Building Mathlib.FieldTheory.PrimitiveElement
# [1942/1973] Building Mathlib.FieldTheory.Galois
# [1942/1973] Building Mathlib.FieldTheory.Minpoly.MinpolyDiv
# [1944/1973] Building Mathlib.FieldTheory.Finite.GaloisField
# [1944/1973] Building Mathlib.RingTheory.Norm
# [1944/1973] Building Mathlib.RingTheory.Trace
# [1945/1973] Building Mathlib.MeasureTheory.Measure.Haar.OfBasis
# [1947/1973] Building Mathlib.Tactic.FunProp.AEMesurable
# [1950/1973] Building Mathlib.RingTheory.DedekindDomain.IntegralClosure
# [1950/1973] Building Mathlib.FieldTheory.Finite.Trace
# [1952/1973] Building Mathlib.NumberTheory.NumberField.Basic
# [1953/1973] Building Mathlib.NumberTheory.Cyclotomic.Basic
# [1954/1973] Building Mathlib.NumberTheory.Cyclotomic.PrimitiveRoots
# [1955/1973] Building Mathlib.NumberTheory.LegendreSymbol.AddCharacter
# [1956/1973] Building Mathlib.NumberTheory.LegendreSymbol.GaussSum
# [1957/1973] Building Mathlib.NumberTheory.LegendreSymbol.QuadraticChar.GaussSum
# [1958/1973] Building Mathlib.NumberTheory.LegendreSymbol.QuadraticReciprocity
# [1959/1973] Building Mathlib.NumberTheory.LegendreSymbol.JacobiSymbol
# [1960/1973] Building Mathlib.Tactic.NormNum.LegendreSymbol
# [1961/1973] Building Mathlib.Tactic
# [1962/1973] Building MIL.Common
# [1963/1973] Building MIL.C03_Logic.solutions.Solutions_S06_Sequences_and_Convergence
# [1963/1973] Building MIL.C05_Elementary_Number_Theory.solutions.Solutions_S01_Irrational_Roots
# [1963/1973] Building MIL.C05_Elementary_Number_Theory.solutions.Solutions_S02_Induction_and_Recursion
# [1963/1973] Building MIL.C03_Logic.solutions.Solutions_S05_Disjunction
# [1963/1973] Building MIL.C04_Sets_and_Functions.solutions.Solutions_S03_The_Schroeder_Bernstein_Theorem
# [1963/1973] Building MIL.C04_Sets_and_Functions.solutions.Solutions_S02_Functions
# [1963/1973] Building MIL.C03_Logic.solutions.Solutions_S03_Negation
# [1963/1973] Building MIL.C04_Sets_and_Functions.solutions.Solutions_S01_Sets
# [1963/1973] Building MIL.C03_Logic.solutions.Solutions_S04_Conjunction_and_Iff
# stdout:
# ./././MIL/C03_Logic/solutions/Solutions_S03_Negation.lean:48:15: warning: unused variable `x` [linter.unusedVariables]
# ./././MIL/C03_Logic/solutions/Solutions_S03_Negation.lean:50:14: warning: unused variable `leab` [linter.unusedVariables]
# stdout:
# ./././MIL/C03_Logic/solutions/Solutions_S04_Conjunction_and_Iff.lean:87:23: warning: unused variable `h3` [linter.unusedVariables]
# stdout:
# ./././MIL/C05_Elementary_Number_Theory/solutions/Solutions_S02_Induction_and_Recursion.lean:48:4: warning: unused variable `x` [linter.unusedVariables]
# stdout:
# ./././MIL/C05_Elementary_Number_Theory/solutions/Solutions_S01_Irrational_Roots.lean:89:109: warning: unused variable `prime_p` [linter.unusedVariables]
# stdout:
# ./././MIL/C04_Sets_and_Functions/solutions/Solutions_S01_Sets.lean:27:9: warning: unused variable `x` [linter.unusedVariables]
# ./././MIL/C04_Sets_and_Functions/solutions/Solutions_S01_Sets.lean:27:36: warning: unused variable `x` [linter.unusedVariables]
# ./././MIL/C04_Sets_and_Functions/solutions/Solutions_S01_Sets.lean:38:22: warning: unused variable `xt` [linter.unusedVariables]
# ./././MIL/C04_Sets_and_Functions/solutions/Solutions_S01_Sets.lean:43:17: warning: unused variable `nxt` [linter.unusedVariables]
# stdout:
# ./././MIL/C03_Logic/solutions/Solutions_S05_Disjunction.lean:61:22: warning: unused variable `h1` [linter.unusedVariables]
# stdout:
# ./././MIL/C04_Sets_and_Functions/solutions/Solutions_S03_The_Schroeder_Bernstein_Theorem.lean:66:23: warning: unused variable `hf` [linter.unusedVariables]
# stdout:
# ./././MIL/C03_Logic/solutions/Solutions_S06_Sequences_and_Convergence.lean:9:53: warning: unused variable `x` [linter.unusedVariables]
# ./././MIL/C03_Logic/solutions/Solutions_S06_Sequences_and_Convergence.lean:12:10: warning: unused variable `nge` [linter.unusedVariables]
# stdout:
# ./././MIL/C04_Sets_and_Functions/solutions/Solutions_S02_Functions.lean:82:6: warning: unused variable `x` [linter.unusedVariables]
# ./././MIL/C04_Sets_and_Functions/solutions/Solutions_S02_Functions.lean:124:22: warning: unused variable `xAi` [linter.unusedVariables]
# ./././MIL/C04_Sets_and_Functions/solutions/Solutions_S02_Functions.lean:169:16: warning: unused variable `xnonneg` [linter.unusedVariables]
# ./././MIL/C04_Sets_and_Functions/solutions/Solutions_S02_Functions.lean:231:9: warning: unused variable `y` [linter.unusedVariables]
# [1972/1973] Building MIL
# 2024-04-26 22:06:09.636 | INFO     | __main__:main:188 - Tracing math-in-lean
# 2024-04-26 22:06:09.670 | DEBUG    | __main__:main:193 - /home/mcwave/.elan/bin/lake env lean --threads 20 --run ExtractData.lean
#  98%|█████████▊| 2692/2740 [22:51<00:11,  4.08it/s]2024-04-26 22:29:06,119	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2733/2733 [03:00<00:00, 15.17it/s]
# 2024-04-26 22:32:20.700 | WARNING  | lean_dojo.data_extraction.lean:__post_init__:442 - LeanGitRepo(url='https://github.com/leanprover-community/quote4', commit='1c88406514a636d241903e2e288d21dc6d861e01') relies on an unsupported Lean version: ec941735c80dc54c53948e30c428905b6600f95a
# 2024-04-26 22:32:22.749 | WARNING  | lean_dojo.data_extraction.lean:__post_init__:442 - LeanGitRepo(url='https://github.com/leanprover/lean4-cli', commit='a751d21d4b68c999accb6fc5d960538af26ad5ec') relies on an unsupported Lean version: ec941735c80dc54c53948e30c428905b6600f95a
# 2024-04-26 22:32:49.438 | WARNING  | lean_dojo.data_extraction.lean:__post_init__:442 - LeanGitRepo(url='https://github.com/leanprover/lean4-cli', commit='be8fa79a28b8b6897dce0713ef50e89c4a0f6ef5') relies on an unsupported Lean version: ec941735c80dc54c53948e30c428905b6600f95a
# 2024-04-26 22:33:08.187 | WARNING  | lean_dojo.data_extraction.lean:__post_init__:442 - LeanGitRepo(url='https://github.com/xubaiw/CMark.lean', commit='0077cbbaa92abf855fc1c0413e158ffd8195ec77') relies on an unsupported Lean version: 8fc1af650ad6d31cf766d9bc84119149330e7d4e
# Following Github server redirection from /repos/mhuisi/lean4-cli to /repositories/341363356
# 2024-04-26 22:33:23.634 | WARNING  | lean_dojo.data_extraction.lean:__post_init__:442 - LeanGitRepo(url='https://github.com/mhuisi/lean4-cli', commit='39229f3630d734af7d9cfb5937ddc6b41d3aa6aa') relies on an unsupported Lean version: 216d2460e0adec8317fdeeb6f2543cb7442564fd
# 2024-04-26 22:33:35.504 | WARNING  | lean_dojo.data_extraction.lean:__post_init__:442 - LeanGitRepo(url='https://github.com/fgdorais/lean4-unicode-basic', commit='280d75fdfe7be8eb337be7f1bf8479b4aac09f71') relies on an unsupported Lean version: 0d7051497ea09b2b4a4ef608e371b8f317487c3c
# 2024-04-26 22:33:41.245 | WARNING  | lean_dojo.data_extraction.lean:__post_init__:442 - LeanGitRepo(url='https://github.com/hargonix/LeanInk', commit='2447df5cc6e48eb965c3c3fba87e46d353b5e9f1') relies on an unsupported Lean version: f6cd6c069587cfe62dd68cb6330f9ad794a56724
# 2024-04-26 22:34:05,375	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2733/2733 [00:46<00:00, 59.10it/s]
# 2024-04-26 22:34:58.676 | INFO     | lean_dojo.data_extraction.trace:trace:117 - Loading the traced repo from /home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-0708e774a2050a294e83776f171235d942f46e9d/math-in-lean
# 2024-04-26 22:35:01,548	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2733/2733 [04:12<00:00, 10.83it/s]
# DiGraph with 2733 nodes and 11292 edges
# len(traced_repo.traced_files): 2733

# %%
[x for x in traced_repo.traced_files if 'solutions' in str(x.lean_file.path)]
# Out:
# [TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-0708e774a2050a294e83776f171235d942f46e9d/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='0708e774a2050a294e83776f171235d942f46e9d'), lean_file=LeanFile(path=PosixPath('MIL/C04_Sets_and_Functions/solutions/Solutions_S03_The_Schroeder_Bernstein_Theorem.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-0708e774a2050a294e83776f171235d942f46e9d/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='0708e774a2050a294e83776f171235d942f46e9d'), lean_file=LeanFile(path=PosixPath('MIL/C03_Logic/solutions/Solutions_S04_Conjunction_and_Iff.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-0708e774a2050a294e83776f171235d942f46e9d/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='0708e774a2050a294e83776f171235d942f46e9d'), lean_file=LeanFile(path=PosixPath('MIL/C05_Elementary_Number_Theory/solutions/Solutions_S02_Induction_and_Recursion.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-0708e774a2050a294e83776f171235d942f46e9d/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='0708e774a2050a294e83776f171235d942f46e9d'), lean_file=LeanFile(path=PosixPath('MIL/C05_Elementary_Number_Theory/solutions/Solutions_S01_Irrational_Roots.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-0708e774a2050a294e83776f171235d942f46e9d/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='0708e774a2050a294e83776f171235d942f46e9d'), lean_file=LeanFile(path=PosixPath('MIL/C03_Logic/solutions/Solutions_S05_Disjunction.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-0708e774a2050a294e83776f171235d942f46e9d/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='0708e774a2050a294e83776f171235d942f46e9d'), lean_file=LeanFile(path=PosixPath('MIL/C03_Logic/solutions/Solutions_S03_Negation.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-0708e774a2050a294e83776f171235d942f46e9d/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='0708e774a2050a294e83776f171235d942f46e9d'), lean_file=LeanFile(path=PosixPath('MIL/C04_Sets_and_Functions/solutions/Solutions_S01_Sets.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-0708e774a2050a294e83776f171235d942f46e9d/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='0708e774a2050a294e83776f171235d942f46e9d'), lean_file=LeanFile(path=PosixPath('MIL/C03_Logic/solutions/Solutions_S06_Sequences_and_Convergence.lean'))),
#  TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-0708e774a2050a294e83776f171235d942f46e9d/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='0708e774a2050a294e83776f171235d942f46e9d'), lean_file=LeanFile(path=PosixPath('MIL/C04_Sets_and_Functions/solutions/Solutions_S02_Functions.lean')))]

# %%
traced_file = traced_repo.get_traced_file("MIL/C04_Sets_and_Functions/solutions/Solutions_S03_The_Schroeder_Bernstein_Theorem.lean")

print(traced_file)
# Out:
# TracedFile(root_dir=PosixPath('/home/mcwave/.cache/lean_dojo/xiaoxin-yin-math-in-lean-0708e774a2050a294e83776f171235d942f46e9d/math-in-lean'), repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='0708e774a2050a294e83776f171235d942f46e9d'), lean_file=LeanFile(path=PosixPath('MIL/C04_Sets_and_Functions/solutions/Solutions_S03_The_Schroeder_Bernstein_Theorem.lean')))

# %%
traced_file.get_premise_definitions()
# Out:
# [{'full_name': 'sbAux',
#   'code': "def sbAux : ℕ → Set α\n  | 0 => univ \\ g '' univ\n  | n + 1 => g '' (f '' sbAux n)",
#   'start': [15, 1],
#   'end': [17, 33],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'sbSet',
#   'code': 'def sbSet :=\n  ⋃ n, sbAux f g n',
#   'start': [19, 1],
#   'end': [20, 19],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'sbFun',
#   'code': 'def sbFun (x : α) : β :=\n  if x ∈ sbSet f g then f x else invFun g x',
#   'start': [22, 1],
#   'end': [23, 44],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'sb_right_inv',
#   'code': 'theorem sb_right_inv {x : α} (hx : x ∉ sbSet f g) : g (invFun g x) = x',
#   'start': [25, 1],
#   'end': [35, 23],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'sb_injective',
#   'code': 'theorem sb_injective (hf : Injective f) : Injective (sbFun f g)',
#   'start': [37, 1],
#   'end': [64, 60],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'sb_surjective',
#   'code': 'theorem sb_surjective (hf : Injective f) (hg : Injective g) : Surjective (sbFun f g)',
#   'start': [66, 1],
#   'end': [85, 30],
#   'kind': 'commanddeclaration'}]

# %%
thm = traced_file.get_traced_theorem("sb_injective")

print(thm.theorem)

proof_node = thm.get_proof_node()
proof = proof_node.lean_file[proof_node.start : proof_node.end]
print(proof)

traced_tactics = thm.get_traced_tactics()
print("\ntraced_tactics:\n", traced_tactics)

tac = traced_tactics[1]
print("\ntac:\n", tac)
# Out:
# Theorem(repo=LeanGitRepo(url='https://github.com/xiaoxin-yin/math-in-lean', commit='0708e774a2050a294e83776f171235d942f46e9d'), file_path=PosixPath('MIL/C04_Sets_and_Functions/solutions/Solutions_S03_The_Schroeder_Bernstein_Theorem.lean'), full_name='sb_injective')
# by
#   set A := sbSet f g with A_def
#   set h := sbFun f g with h_def
#   intro x₁ x₂
#   intro (hxeq : h x₁ = h x₂)
#   show x₁ = x₂
#   simp only [h_def, sbFun, ← A_def] at hxeq
#   by_cases xA : x₁ ∈ A ∨ x₂ ∈ A
#   · wlog x₁A : x₁ ∈ A generalizing x₁ x₂ hxeq xA
#     · symm
#       apply this hxeq.symm xA.symm (xA.resolve_left x₁A)
#     have x₂A : x₂ ∈ A := by
#       apply not_imp_self.mp
#       intro (x₂nA : x₂ ∉ A)
#       rw [if_pos x₁A, if_neg x₂nA] at hxeq
#       rw [A_def, sbSet, mem_iUnion] at x₁A
#       have x₂eq : x₂ = g (f x₁) := by
#         rw [hxeq, sb_right_inv f g x₂nA]
#       rcases x₁A with ⟨n, hn⟩
#       rw [A_def, sbSet, mem_iUnion]
#       use n + 1
#       simp [sbAux]
#       exact ⟨x₁, hn, x₂eq.symm⟩
#     rw [if_pos x₁A, if_pos x₂A] at hxeq
#     exact hf hxeq
#   push_neg  at xA
#   rw [if_neg xA.1, if_neg xA.2] at hxeq
#   rw [← sb_right_inv f g xA.1, hxeq, sb_right_inv f g xA.2]
#
# traced_tactics:
#  [TracedTactic(tactic=set A := sbSet f g with A_def, state_before=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# ⊢ Injective (sbFun f g), state_after=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# ⊢ Injective (sbFun f g)), TracedTactic(tactic=set h := sbFun f g with h_def, state_before=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# ⊢ Injective (sbFun f g), state_after=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# ⊢ Injective h), TracedTactic(tactic=intro x₁ x₂, state_before=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# ⊢ Injective h, state_after=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# ⊢ h x₁ = h x₂ → x₁ = x₂), TracedTactic(tactic=intro (hxeq : h x₁ = h x₂), state_before=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# ⊢ h x₁ = h x₂ → x₁ = x₂, state_after=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : h x₁ = h x₂
# ⊢ x₁ = x₂), TracedTactic(tactic=simp only [h_def, sbFun, ← A_def] at hxeq, state_before=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : h x₁ = h x₂
# ⊢ x₁ = x₂, state_after=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# ⊢ x₁ = x₂), TracedTactic(tactic=by_cases xA : x₁ ∈ A ∨ x₂ ∈ A, state_before=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# ⊢ x₁ = x₂, state_after=case pos
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# ⊢ x₁ = x₂
#
# case neg
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : ¬(x₁ ∈ A ∨ x₂ ∈ A)
# ⊢ x₁ = x₂), TracedTactic(tactic=· wlog x₁A : x₁ ∈ A generalizing x₁ x₂ hxeq xA
#   · symm
#     apply this hxeq.symm xA.symm (xA.resolve_left x₁A)
#   have x₂A : x₂ ∈ A := by
#     apply not_imp_self.mp
#     intro (x₂nA : x₂ ∉ A)
#     rw [if_pos x₁A, if_neg x₂nA] at hxeq
#     rw [A_def, sbSet, mem_iUnion] at x₁A
#     have x₂eq : x₂ = g (f x₁) := by
#       rw [hxeq, sb_right_inv f g x₂nA]
#     rcases x₁A with ⟨n, hn⟩
#     rw [A_def, sbSet, mem_iUnion]
#     use n + 1
#     simp [sbAux]
#     exact ⟨x₁, hn, x₂eq.symm⟩
#   rw [if_pos x₁A, if_pos x₂A] at hxeq
#   exact hf hxeq, state_before=case pos
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# ⊢ x₁ = x₂
#
# case neg
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : ¬(x₁ ∈ A ∨ x₂ ∈ A)
# ⊢ x₁ = x₂, state_after=case neg
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : ¬(x₁ ∈ A ∨ x₂ ∈ A)
# ⊢ x₁ = x₂), TracedTactic(tactic=push_neg  at xA, state_before=case neg
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : ¬(x₁ ∈ A ∨ x₂ ∈ A)
# ⊢ x₁ = x₂, state_after=case neg
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : x₁ ∉ A ∧ x₂ ∉ A
# ⊢ x₁ = x₂), TracedTactic(tactic=rw [if_neg xA.1, if_neg xA.2] at hxeq, state_before=case neg
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : x₁ ∉ A ∧ x₂ ∉ A
# ⊢ x₁ = x₂, state_after=case neg
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : invFun g x₁ = invFun g x₂
# xA : x₁ ∉ A ∧ x₂ ∉ A
# ⊢ x₁ = x₂), TracedTactic(tactic=rw [← sb_right_inv f g xA.1, hxeq, sb_right_inv f g xA.2], state_before=case neg
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : invFun g x₁ = invFun g x₂
# xA : x₁ ∉ A ∧ x₂ ∉ A
# ⊢ x₁ = x₂, state_after=no goals), TracedTactic(tactic=wlog x₁A : x₁ ∈ A generalizing x₁ x₂ hxeq xA, state_before=case pos
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# ⊢ x₁ = x₂, state_after=case pos.inr
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# this :
#   ∀ ⦃x₁ x₂ : α⦄,
#     ((if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂) → x₁ ∈ A ∨ x₂ ∈ A → x₁ ∈ A → x₁ = x₂
# x₁A : x₁ ∉ A
# ⊢ x₁ = x₂
#
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₁A : x₁ ∈ A
# ⊢ x₁ = x₂), TracedTactic(tactic=· symm
#   apply this hxeq.symm xA.symm (xA.resolve_left x₁A), state_before=case pos.inr
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# this :
#   ∀ ⦃x₁ x₂ : α⦄,
#     ((if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂) → x₁ ∈ A ∨ x₂ ∈ A → x₁ ∈ A → x₁ = x₂
# x₁A : x₁ ∉ A
# ⊢ x₁ = x₂
#
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₁A : x₁ ∈ A
# ⊢ x₁ = x₂, state_after=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₁A : x₁ ∈ A
# ⊢ x₁ = x₂), TracedTactic(tactic=have x₂A : x₂ ∈ A := by
#   apply not_imp_self.mp
#   intro (x₂nA : x₂ ∉ A)
#   rw [if_pos x₁A, if_neg x₂nA] at hxeq
#   rw [A_def, sbSet, mem_iUnion] at x₁A
#   have x₂eq : x₂ = g (f x₁) := by
#     rw [hxeq, sb_right_inv f g x₂nA]
#   rcases x₁A with ⟨n, hn⟩
#   rw [A_def, sbSet, mem_iUnion]
#   use n + 1
#   simp [sbAux]
#   exact ⟨x₁, hn, x₂eq.symm⟩, state_before=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₁A : x₁ ∈ A
# ⊢ x₁ = x₂, state_after=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₁A : x₁ ∈ A
# x₂A : x₂ ∈ A
# ⊢ x₁ = x₂), TracedTactic(tactic=rw [if_pos x₁A, if_pos x₂A] at hxeq, state_before=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₁A : x₁ ∈ A
# x₂A : x₂ ∈ A
# ⊢ x₁ = x₂, state_after=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : f x₁ = f x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₁A : x₁ ∈ A
# x₂A : x₂ ∈ A
# ⊢ x₁ = x₂), TracedTactic(tactic=exact hf hxeq, state_before=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : f x₁ = f x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₁A : x₁ ∈ A
# x₂A : x₂ ∈ A
# ⊢ x₁ = x₂, state_after=no goals), TracedTactic(tactic=symm, state_before=case pos.inr
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# this :
#   ∀ ⦃x₁ x₂ : α⦄,
#     ((if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂) → x₁ ∈ A ∨ x₂ ∈ A → x₁ ∈ A → x₁ = x₂
# x₁A : x₁ ∉ A
# ⊢ x₁ = x₂, state_after=case pos.inr
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# this :
#   ∀ ⦃x₁ x₂ : α⦄,
#     ((if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂) → x₁ ∈ A ∨ x₂ ∈ A → x₁ ∈ A → x₁ = x₂
# x₁A : x₁ ∉ A
# ⊢ x₂ = x₁), TracedTactic(tactic=apply this hxeq.symm xA.symm (xA.resolve_left x₁A), state_before=case pos.inr
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# this :
#   ∀ ⦃x₁ x₂ : α⦄,
#     ((if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂) → x₁ ∈ A ∨ x₂ ∈ A → x₁ ∈ A → x₁ = x₂
# x₁A : x₁ ∉ A
# ⊢ x₂ = x₁, state_after=no goals), TracedTactic(tactic=apply not_imp_self.mp, state_before=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₁A : x₁ ∈ A
# ⊢ x₂ ∈ A, state_after=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₁A : x₁ ∈ A
# ⊢ x₂ ∉ A → x₂ ∈ A), TracedTactic(tactic=intro (x₂nA : x₂ ∉ A), state_before=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₁A : x₁ ∈ A
# ⊢ x₂ ∉ A → x₂ ∈ A, state_after=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₁A : x₁ ∈ A
# x₂nA : x₂ ∉ A
# ⊢ x₂ ∈ A), TracedTactic(tactic=rw [if_pos x₁A, if_neg x₂nA] at hxeq, state_before=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : (if x₁ ∈ A then f x₁ else invFun g x₁) = if x₂ ∈ A then f x₂ else invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₁A : x₁ ∈ A
# x₂nA : x₂ ∉ A
# ⊢ x₂ ∈ A, state_after=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : f x₁ = invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₁A : x₁ ∈ A
# x₂nA : x₂ ∉ A
# ⊢ x₂ ∈ A), TracedTactic(tactic=rw [A_def, sbSet, mem_iUnion] at x₁A, state_before=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : f x₁ = invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₁A : x₁ ∈ A
# x₂nA : x₂ ∉ A
# ⊢ x₂ ∈ A, state_after=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : f x₁ = invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₁A : ∃ i, x₁ ∈ sbAux f g i
# x₂nA : x₂ ∉ A
# ⊢ x₂ ∈ A), TracedTactic(tactic=have x₂eq : x₂ = g (f x₁) := by
#   rw [hxeq, sb_right_inv f g x₂nA], state_before=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : f x₁ = invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₁A : ∃ i, x₁ ∈ sbAux f g i
# x₂nA : x₂ ∉ A
# ⊢ x₂ ∈ A, state_after=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : f x₁ = invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₁A : ∃ i, x₁ ∈ sbAux f g i
# x₂nA : x₂ ∉ A
# x₂eq : x₂ = g (f x₁)
# ⊢ x₂ ∈ A), TracedTactic(tactic=rcases x₁A with ⟨n, hn⟩, state_before=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : f x₁ = invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₁A : ∃ i, x₁ ∈ sbAux f g i
# x₂nA : x₂ ∉ A
# x₂eq : x₂ = g (f x₁)
# ⊢ x₂ ∈ A, state_after=case intro
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : f x₁ = invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₂nA : x₂ ∉ A
# x₂eq : x₂ = g (f x₁)
# n : ℕ
# hn : x₁ ∈ sbAux f g n
# ⊢ x₂ ∈ A), TracedTactic(tactic=rw [A_def, sbSet, mem_iUnion], state_before=case intro
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : f x₁ = invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₂nA : x₂ ∉ A
# x₂eq : x₂ = g (f x₁)
# n : ℕ
# hn : x₁ ∈ sbAux f g n
# ⊢ x₂ ∈ A, state_after=case intro
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : f x₁ = invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₂nA : x₂ ∉ A
# x₂eq : x₂ = g (f x₁)
# n : ℕ
# hn : x₁ ∈ sbAux f g n
# ⊢ ∃ i, x₂ ∈ sbAux f g i), TracedTactic(tactic=use n + 1, state_before=case intro
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : f x₁ = invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₂nA : x₂ ∉ A
# x₂eq : x₂ = g (f x₁)
# n : ℕ
# hn : x₁ ∈ sbAux f g n
# ⊢ ∃ i, x₂ ∈ sbAux f g i, state_after=case h
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : f x₁ = invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₂nA : x₂ ∉ A
# x₂eq : x₂ = g (f x₁)
# n : ℕ
# hn : x₁ ∈ sbAux f g n
# ⊢ x₂ ∈ sbAux f g (n + 1)), TracedTactic(tactic=simp [sbAux], state_before=case h
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : f x₁ = invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₂nA : x₂ ∉ A
# x₂eq : x₂ = g (f x₁)
# n : ℕ
# hn : x₁ ∈ sbAux f g n
# ⊢ x₂ ∈ sbAux f g (n + 1), state_after=case h
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : f x₁ = invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₂nA : x₂ ∉ A
# x₂eq : x₂ = g (f x₁)
# n : ℕ
# hn : x₁ ∈ sbAux f g n
# ⊢ ∃ a ∈ sbAux f g n, g (f a) = x₂), TracedTactic(tactic=exact ⟨x₁, hn, x₂eq.symm⟩, state_before=case h
# α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : f x₁ = invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₂nA : x₂ ∉ A
# x₂eq : x₂ = g (f x₁)
# n : ℕ
# hn : x₁ ∈ sbAux f g n
# ⊢ ∃ a ∈ sbAux f g n, g (f a) = x₂, state_after=no goals), TracedTactic(tactic=rw [hxeq, sb_right_inv f g x₂nA], state_before=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# x₁ x₂ : α
# hxeq : f x₁ = invFun g x₂
# xA : x₁ ∈ A ∨ x₂ ∈ A
# x₁A : ∃ i, x₁ ∈ sbAux f g i
# x₂nA : x₂ ∉ A
# ⊢ x₂ = g (f x₁), state_after=no goals)]
#
# tac:
#  TracedTactic(tactic=set h := sbFun f g with h_def, state_before=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# ⊢ Injective (sbFun f g), state_after=α : Type u_1
# β : Type u_2
# inst✝ : Nonempty β
# f : α → β
# g : β → α
# hf : Injective f
# A : Set α := sbSet f g
# A_def : A = sbSet f g
# h : α → β := sbFun f g
# h_def : h = sbFun f g
# ⊢ Injective h)

# %%
from utils.lean_math_utils import *

def get_tactic_templates_of_theorem(thm):
    tac_templates = []
    traced_tactics = thm.get_traced_tactics()
    for tracted_tac in traced_tactics:
        print("TAC:", tracted_tac.tactic)
        tac_template = parse_lean_state_and_tactic(tracted_tac.state_before, tracted_tac.tactic)
        tac_templates.append((tracted_tac.tactic, tac_template))
    return tac_templates

def get_tactic_templates_of_traced_file(traced_file):
    tac_templates = []
    premises = traced_file.get_premise_definitions()
    for premise in premises:
        if premise['code'].startswith('theorem') or premise['code'].startswith('lemma'):
            thm_name = premise['full_name']
            print("Theorem", thm_name, '\n')
            thm = traced_file.get_traced_theorem(thm_name)
            tac_templates.extend(get_tactic_templates_of_theorem(thm))
    return tac_templates
        
get_tactic_templates_of_traced_file(traced_file)
# Out:
# Theorem sb_right_inv
#
# TAC: have : x ∈ g '' univ := by
#   contrapose! hx
#   rw [sbSet, mem_iUnion]
#   use 0
#   rw [sbAux, mem_diff]
#   exact ⟨mem_univ _, hx⟩
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'x': 'variable', 'hx': 'hypothesis'}
# TAC: have : ∃ y, g y = x := by
#   simp at this
#   assumption
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'x': 'variable', 'hx': 'hypothesis', 'this': 'hypothesis'}
# TAC: exact invFun_eq this
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'x': 'variable', 'hx': 'hypothesis', 'this✝': 'hypothesis', 'this': 'hypothesis'}
# TAC: contrapose! hx
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'x': 'variable', 'hx': 'hypothesis'}
# TAC: rw [sbSet, mem_iUnion]
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'x': 'variable', 'hx': 'hypothesis'}
# TAC: use 0
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'x': 'variable', 'hx': 'hypothesis'}
# TAC: rw [sbAux, mem_diff]
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'x': 'variable', 'hx': 'hypothesis'}
# TAC: exact ⟨mem_univ _, hx⟩
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'x': 'variable', 'hx': 'hypothesis'}
# TAC: simp at this
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'x': 'variable', 'hx': 'hypothesis', 'this': 'hypothesis'}
# TAC: assumption
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'x': 'variable', 'hx': 'hypothesis', 'this': 'hypothesis'}
# Theorem sb_injective
#
# TAC: set A := sbSet f g with A_def
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown'}
# TAC: set h := sbFun f g with h_def
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown'}
# TAC: intro x₁ x₂
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown'}
# TAC: intro (hxeq : h x₁ = h x₂)
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable'}
# TAC: simp only [h_def, sbFun, ← A_def] at hxeq
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'unknown'}
# TAC: by_cases xA : x₁ ∈ A ∨ x₂ ∈ A
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'hypothesis'}
# TAC: · wlog x₁A : x₁ ∈ A generalizing x₁ x₂ hxeq xA
#   · symm
#     apply this hxeq.symm xA.symm (xA.resolve_left x₁A)
#   have x₂A : x₂ ∈ A := by
#     apply not_imp_self.mp
#     intro (x₂nA : x₂ ∉ A)
#     rw [if_pos x₁A, if_neg x₂nA] at hxeq
#     rw [A_def, sbSet, mem_iUnion] at x₁A
#     have x₂eq : x₂ = g (f x₁) := by
#       rw [hxeq, sb_right_inv f g x₂nA]
#     rcases x₁A with ⟨n, hn⟩
#     rw [A_def, sbSet, mem_iUnion]
#     use n + 1
#     simp [sbAux]
#     exact ⟨x₁, hn, x₂eq.symm⟩
#   rw [if_pos x₁A, if_pos x₂A] at hxeq
#   exact hf hxeq
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'hypothesis', 'xA': 'hypothesis'}
# TAC: push_neg  at xA
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'hypothesis', 'xA': 'hypothesis'}
# TAC: rw [if_neg xA.1, if_neg xA.2] at hxeq
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'hypothesis', 'xA': 'hypothesis'}
# TAC: rw [← sb_right_inv f g xA.1, hxeq, sb_right_inv f g xA.2]
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'unknown', 'xA': 'hypothesis'}
# TAC: wlog x₁A : x₁ ∈ A generalizing x₁ x₂ hxeq xA
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'hypothesis', 'xA': 'hypothesis'}
# TAC: · symm
#   apply this hxeq.symm xA.symm (xA.resolve_left x₁A)
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'hypothesis', 'xA': 'hypothesis', 'this': 'unknown', '∀': 'unknown', '⦃x₁': 'unknown', 'x₁A': 'hypothesis'}
# TAC: have x₂A : x₂ ∈ A := by
#   apply not_imp_self.mp
#   intro (x₂nA : x₂ ∉ A)
#   rw [if_pos x₁A, if_neg x₂nA] at hxeq
#   rw [A_def, sbSet, mem_iUnion] at x₁A
#   have x₂eq : x₂ = g (f x₁) := by
#     rw [hxeq, sb_right_inv f g x₂nA]
#   rcases x₁A with ⟨n, hn⟩
#   rw [A_def, sbSet, mem_iUnion]
#   use n + 1
#   simp [sbAux]
#   exact ⟨x₁, hn, x₂eq.symm⟩
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'hypothesis', 'xA': 'hypothesis', 'x₁A': 'hypothesis'}
# TAC: rw [if_pos x₁A, if_pos x₂A] at hxeq
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'hypothesis', 'xA': 'hypothesis', 'x₁A': 'hypothesis', 'x₂A': 'hypothesis'}
# TAC: exact hf hxeq
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'unknown', 'xA': 'hypothesis', 'x₁A': 'hypothesis', 'x₂A': 'hypothesis'}
# TAC: symm
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'unknown', 'hxeq': 'hypothesis', 'xA': 'hypothesis', 'this': 'unknown', '∀': 'unknown', '⦃x₁': 'unknown', 'x₁A': 'hypothesis'}
# TAC: apply this hxeq.symm xA.symm (xA.resolve_left x₁A)
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'unknown', 'hxeq': 'hypothesis', 'xA': 'hypothesis', 'this': 'unknown', '∀': 'unknown', '⦃x₁': 'unknown', 'x₁A': 'hypothesis'}
# TAC: apply not_imp_self.mp
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'hypothesis', 'xA': 'hypothesis', 'x₁A': 'hypothesis'}
# TAC: intro (x₂nA : x₂ ∉ A)
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'hypothesis', 'xA': 'hypothesis', 'x₁A': 'hypothesis'}
# TAC: rw [if_pos x₁A, if_neg x₂nA] at hxeq
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'hypothesis', 'xA': 'hypothesis', 'x₁A': 'hypothesis', 'x₂nA': 'hypothesis'}
# TAC: rw [A_def, sbSet, mem_iUnion] at x₁A
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'unknown', 'xA': 'hypothesis', 'x₁A': 'hypothesis', 'x₂nA': 'hypothesis'}
# TAC: have x₂eq : x₂ = g (f x₁) := by
#   rw [hxeq, sb_right_inv f g x₂nA]
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'unknown', 'xA': 'hypothesis', 'x₁A': 'hypothesis', 'x₂nA': 'hypothesis'}
# TAC: rcases x₁A with ⟨n, hn⟩
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'unknown', 'xA': 'hypothesis', 'x₁A': 'hypothesis', 'x₂nA': 'hypothesis', 'x₂eq': 'unknown'}
# TAC: rw [A_def, sbSet, mem_iUnion]
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'unknown', 'xA': 'hypothesis', 'x₂nA': 'hypothesis', 'x₂eq': 'unknown', 'n': 'unknown', 'hn': 'hypothesis'}
# TAC: use n + 1
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'unknown', 'xA': 'hypothesis', 'x₂nA': 'hypothesis', 'x₂eq': 'unknown', 'n': 'unknown', 'hn': 'hypothesis'}
# TAC: simp [sbAux]
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'unknown', 'xA': 'hypothesis', 'x₂nA': 'hypothesis', 'x₂eq': 'unknown', 'n': 'unknown', 'hn': 'hypothesis'}
# TAC: exact ⟨x₁, hn, x₂eq.symm⟩
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'unknown', 'xA': 'hypothesis', 'x₂nA': 'hypothesis', 'x₂eq': 'unknown', 'n': 'unknown', 'hn': 'hypothesis'}
# TAC: rw [hxeq, sb_right_inv f g x₂nA]
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'x₁': 'variable', 'x₂': 'variable', 'hxeq': 'unknown', 'xA': 'hypothesis', 'x₁A': 'hypothesis', 'x₂nA': 'hypothesis'}
# Theorem sb_surjective
#
# TAC: set A := sbSet f g with A_def
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'hg': 'unknown'}
# TAC: set h := sbFun f g with h_def
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'hg': 'unknown', 'A': 'set', 'A_def': 'unknown'}
# TAC: intro y
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'hg': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown'}
# TAC: by_cases gyA : g y ∈ A
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'hg': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'y': 'variable'}
# TAC: · rw [A_def, sbSet, mem_iUnion] at gyA
#   rcases gyA with ⟨n, hn⟩
#   rcases n with _ | n
#   · simp [sbAux] at hn
#   simp [sbAux] at hn
#   rcases hn with ⟨x, xmem, hx⟩
#   use x
#   have : x ∈ A := by
#     rw [A_def, sbSet, mem_iUnion]
#     exact ⟨n, xmem⟩
#   simp only [h_def, sbFun, if_pos this]
#   exact hg hx
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'hg': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'y': 'variable', 'gyA': 'hypothesis'}
# TAC: use g y
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'hg': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'y': 'variable', 'gyA': 'hypothesis'}
# TAC: simp only [h_def, sbFun, if_neg gyA]
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'hg': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'y': 'variable', 'gyA': 'hypothesis'}
# TAC: apply leftInverse_invFun hg
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'hg': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'y': 'variable', 'gyA': 'hypothesis'}
# TAC: rw [A_def, sbSet, mem_iUnion] at gyA
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'hg': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'y': 'variable', 'gyA': 'hypothesis'}
# TAC: rcases gyA with ⟨n, hn⟩
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'hg': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'y': 'variable', 'gyA': 'hypothesis'}
# TAC: rcases n with _ | n
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'hg': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'y': 'variable', 'n': 'unknown', 'hn': 'hypothesis'}
# TAC: · simp [sbAux] at hn
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'hg': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'y': 'variable', 'hn': 'hypothesis', 'n': 'unknown'}
# TAC: simp [sbAux] at hn
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'hg': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'y': 'variable', 'n': 'unknown', 'hn': 'hypothesis'}
# TAC: rcases hn with ⟨x, xmem, hx⟩
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'hg': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'y': 'variable', 'n': 'unknown', 'hn': 'hypothesis'}
# TAC: use x
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'hg': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'y': 'variable', 'n': 'unknown', 'x': 'variable', 'xmem': 'hypothesis', 'hx': 'unknown'}
# TAC: have : x ∈ A := by
#   rw [A_def, sbSet, mem_iUnion]
#   exact ⟨n, xmem⟩
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'hg': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'y': 'variable', 'n': 'unknown', 'x': 'variable', 'xmem': 'hypothesis', 'hx': 'unknown'}
# TAC: simp only [h_def, sbFun, if_pos this]
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'hg': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'y': 'variable', 'n': 'unknown', 'x': 'variable', 'xmem': 'hypothesis', 'hx': 'unknown', 'this': 'hypothesis'}
# TAC: exact hg hx
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'hg': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'y': 'variable', 'n': 'unknown', 'x': 'variable', 'xmem': 'hypothesis', 'hx': 'unknown', 'this': 'hypothesis'}
# TAC: simp [sbAux] at hn
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'hg': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'y': 'variable', 'hn': 'hypothesis'}
# TAC: rw [A_def, sbSet, mem_iUnion]
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'hg': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'y': 'variable', 'n': 'unknown', 'x': 'variable', 'xmem': 'hypothesis', 'hx': 'unknown'}
# TAC: exact ⟨n, xmem⟩
# {'α': 'type', 'β': 'type', 'inst✝': 'unknown', 'f': 'function', 'g': 'function', 'hf': 'unknown', 'hg': 'unknown', 'A': 'set', 'A_def': 'unknown', 'h': 'function', 'h_def': 'unknown', 'y': 'variable', 'n': 'unknown', 'x': 'variable', 'xmem': 'hypothesis', 'hx': 'unknown'}
# [("have : x ∈ g '' univ := by\n  contrapose! hx\n  rw [sbSet, mem_iUnion]\n  use 0\n  rw [sbAux, mem_diff]\n  exact ⟨mem_univ _, hx⟩",
#   "have : {variable} ∈ {function} '' univ := by\n  contrapose! {hypothesis}\n  rw [sbSet, mem_iUnion]\n  use 0\n  rw [sbAux, mem_diff]\n  exact ⟨mem_univ _, {hypothesis}⟩"),
#  ('have : ∃ y, g y = x := by\n  simp at this\n  assumption',
#   'have : ∃ y, {function} y = {variable} := by\n  simp at {hypothesis}\n  assumption'),
#  ('exact invFun_eq this', 'exact invFun_eq {hypothesis}'),
#  ('contrapose! hx', 'contrapose! {hypothesis}'),
#  ('rw [sbSet, mem_iUnion]', 'rw [sbSet, mem_iUnion]'),
#  ('use 0', 'use 0'),
#  ('rw [sbAux, mem_diff]', 'rw [sbAux, mem_diff]'),
#  ('exact ⟨mem_univ _, hx⟩', 'exact ⟨mem_univ _, {hypothesis}⟩'),
#  ('simp at this', 'simp at {hypothesis}'),
#  ('assumption', 'assumption'),
#  ('set A := sbSet f g with A_def',
#   'set A := sbSet {function} {function} with A_def'),
#  ('set h := sbFun f g with h_def',
#   'set h := sbFun {function} {function} with h_def'),
#  ('intro x₁ x₂', 'intro x₁ x₂'),
#  ('intro (hxeq : h x₁ = h x₂)',
#   'intro (hxeq : {function} {variable} = {function} {variable})'),
#  ('simp only [h_def, sbFun, ← A_def] at hxeq',
#   'simp only [{unknown}, sbFun, ← {unknown}] at {unknown}'),
#  ('by_cases xA : x₁ ∈ A ∨ x₂ ∈ A',
#   'by_cases xA : {variable} ∈ {set} ∨ {variable} ∈ {set}'),
#  ('· wlog x₁A : x₁ ∈ A generalizing x₁ x₂ hxeq xA\n  · symm\n    apply this hxeq.symm xA.symm (xA.resolve_left x₁A)\n  have x₂A : x₂ ∈ A := by\n    apply not_imp_self.mp\n    intro (x₂nA : x₂ ∉ A)\n    rw [if_pos x₁A, if_neg x₂nA] at hxeq\n    rw [A_def, sbSet, mem_iUnion] at x₁A\n    have x₂eq : x₂ = g (f x₁) := by\n      rw [hxeq, sb_right_inv f g x₂nA]\n    rcases x₁A with ⟨n, hn⟩\n    rw [A_def, sbSet, mem_iUnion]\n    use n + 1\n    simp [sbAux]\n    exact ⟨x₁, hn, x₂eq.symm⟩\n  rw [if_pos x₁A, if_pos x₂A] at hxeq\n  exact hf hxeq',
#   '· wlog x₁A : {variable} ∈ {set} generalizing {variable} {variable} {hypothesis} {hypothesis}\n  · symm\n    apply this {hypothesis}.symm {hypothesis}.symm ({hypothesis}.resolve_left x₁A)\n  have x₂A : {variable} ∈ {set} := by\n    apply not_imp_self.mp\n    intro (x₂nA : {variable} ∉ {set})\n    rw [if_pos x₁A, if_neg x₂nA] at {hypothesis}\n    rw [{unknown}, sbSet, mem_iUnion] at x₁A\n    have x₂eq : {variable} = {function} ({function} {variable}) := by\n      rw [{hypothesis}, sb_right_inv {function} {function} x₂nA]\n    rcases x₁A with ⟨n, hn⟩\n    rw [{unknown}, sbSet, mem_iUnion]\n    use n + 1\n    simp [sbAux]\n    exact ⟨{variable}, hn, x₂eq.symm⟩\n  rw [if_pos x₁A, if_pos x₂A] at {hypothesis}\n  exact {unknown} {hypothesis}'),
#  ('push_neg  at xA', 'push_neg  at {hypothesis}'),
#  ('rw [if_neg xA.1, if_neg xA.2] at hxeq',
#   'rw [if_neg {hypothesis}.1, if_neg {hypothesis}.2] at {hypothesis}'),
#  ('rw [← sb_right_inv f g xA.1, hxeq, sb_right_inv f g xA.2]',
#   'rw [← sb_right_inv {function} {function} {hypothesis}.1, {unknown}, sb_right_inv {function} {function} {hypothesis}.2]'),
#  ('wlog x₁A : x₁ ∈ A generalizing x₁ x₂ hxeq xA',
#   'wlog x₁A : {variable} ∈ {set} generalizing {variable} {variable} {hypothesis} {hypothesis}'),
#  ('· symm\n  apply this hxeq.symm xA.symm (xA.resolve_left x₁A)',
#   '· symm\n  apply {unknown} {hypothesis}.symm {hypothesis}.symm ({hypothesis}.resolve_left {hypothesis})'),
#  ('have x₂A : x₂ ∈ A := by\n  apply not_imp_self.mp\n  intro (x₂nA : x₂ ∉ A)\n  rw [if_pos x₁A, if_neg x₂nA] at hxeq\n  rw [A_def, sbSet, mem_iUnion] at x₁A\n  have x₂eq : x₂ = g (f x₁) := by\n    rw [hxeq, sb_right_inv f g x₂nA]\n  rcases x₁A with ⟨n, hn⟩\n  rw [A_def, sbSet, mem_iUnion]\n  use n + 1\n  simp [sbAux]\n  exact ⟨x₁, hn, x₂eq.symm⟩',
#   'have x₂A : {variable} ∈ {set} := by\n  apply not_imp_self.mp\n  intro (x₂nA : {variable} ∉ {set})\n  rw [if_pos {hypothesis}, if_neg x₂nA] at {hypothesis}\n  rw [{unknown}, sbSet, mem_iUnion] at {hypothesis}\n  have x₂eq : {variable} = {function} ({function} {variable}) := by\n    rw [{hypothesis}, sb_right_inv {function} {function} x₂nA]\n  rcases {hypothesis} with ⟨n, hn⟩\n  rw [{unknown}, sbSet, mem_iUnion]\n  use n + 1\n  simp [sbAux]\n  exact ⟨{variable}, hn, x₂eq.symm⟩'),
#  ('rw [if_pos x₁A, if_pos x₂A] at hxeq',
#   'rw [if_pos {hypothesis}, if_pos {hypothesis}] at {hypothesis}'),
#  ('exact hf hxeq', 'exact {unknown} {unknown}'),
#  ('symm', 'symm'),
#  ('apply this hxeq.symm xA.symm (xA.resolve_left x₁A)',
#   'apply {unknown} {hypothesis}.symm {hypothesis}.symm ({hypothesis}.resolve_left {hypothesis})'),
#  ('apply not_imp_self.mp', 'apply not_imp_self.mp'),
#  ('intro (x₂nA : x₂ ∉ A)', 'intro (x₂nA : {variable} ∉ {set})'),
#  ('rw [if_pos x₁A, if_neg x₂nA] at hxeq',
#   'rw [if_pos {hypothesis}, if_neg {hypothesis}] at {hypothesis}'),
#  ('rw [A_def, sbSet, mem_iUnion] at x₁A',
#   'rw [{unknown}, sbSet, mem_iUnion] at {hypothesis}'),
#  ('have x₂eq : x₂ = g (f x₁) := by\n  rw [hxeq, sb_right_inv f g x₂nA]',
#   'have x₂eq : {variable} = {function} ({function} {variable}) := by\n  rw [{unknown}, sb_right_inv {function} {function} {hypothesis}]'),
#  ('rcases x₁A with ⟨n, hn⟩', 'rcases {hypothesis} with ⟨n, hn⟩'),
#  ('rw [A_def, sbSet, mem_iUnion]', 'rw [{unknown}, sbSet, mem_iUnion]'),
#  ('use n + 1', 'use {unknown} + 1'),
#  ('simp [sbAux]', 'simp [sbAux]'),
#  ('exact ⟨x₁, hn, x₂eq.symm⟩',
#   'exact ⟨{variable}, {hypothesis}, {unknown}.symm⟩'),
#  ('rw [hxeq, sb_right_inv f g x₂nA]',
#   'rw [{unknown}, sb_right_inv {function} {function} {hypothesis}]'),
#  ('set A := sbSet f g with A_def',
#   'set A := sbSet {function} {function} with A_def'),
#  ('set h := sbFun f g with h_def',
#   'set h := sbFun {function} {function} with h_def'),
#  ('intro y', 'intro y'),
#  ('by_cases gyA : g y ∈ A', 'by_cases gyA : {function} {variable} ∈ {set}'),
#  ('· rw [A_def, sbSet, mem_iUnion] at gyA\n  rcases gyA with ⟨n, hn⟩\n  rcases n with _ | n\n  · simp [sbAux] at hn\n  simp [sbAux] at hn\n  rcases hn with ⟨x, xmem, hx⟩\n  use x\n  have : x ∈ A := by\n    rw [A_def, sbSet, mem_iUnion]\n    exact ⟨n, xmem⟩\n  simp only [h_def, sbFun, if_pos this]\n  exact hg hx',
#   '· rw [{unknown}, sbSet, mem_iUnion] at {hypothesis}\n  rcases {hypothesis} with ⟨n, hn⟩\n  rcases n with _ | n\n  · simp [sbAux] at hn\n  simp [sbAux] at hn\n  rcases hn with ⟨x, xmem, hx⟩\n  use x\n  have : x ∈ {set} := by\n    rw [{unknown}, sbSet, mem_iUnion]\n    exact ⟨n, xmem⟩\n  simp only [{unknown}, sbFun, if_pos this]\n  exact {unknown} hx'),
#  ('use g y', 'use {function} {variable}'),
#  ('simp only [h_def, sbFun, if_neg gyA]',
#   'simp only [{unknown}, sbFun, if_neg {hypothesis}]'),
#  ('apply leftInverse_invFun hg', 'apply leftInverse_invFun {unknown}'),
#  ('rw [A_def, sbSet, mem_iUnion] at gyA',
#   'rw [{unknown}, sbSet, mem_iUnion] at {hypothesis}'),
#  ('rcases gyA with ⟨n, hn⟩', 'rcases {hypothesis} with ⟨n, hn⟩'),
#  ('rcases n with _ | n', 'rcases {unknown} with _ | {unknown}'),
#  ('· simp [sbAux] at hn', '· simp [sbAux] at {hypothesis}'),
#  ('simp [sbAux] at hn', 'simp [sbAux] at {hypothesis}'),
#  ('rcases hn with ⟨x, xmem, hx⟩', 'rcases {hypothesis} with ⟨x, xmem, hx⟩'),
#  ('use x', 'use {variable}'),
#  ('have : x ∈ A := by\n  rw [A_def, sbSet, mem_iUnion]\n  exact ⟨n, xmem⟩',
#   'have : {variable} ∈ {set} := by\n  rw [{unknown}, sbSet, mem_iUnion]\n  exact ⟨{unknown}, {hypothesis}⟩'),
#  ('simp only [h_def, sbFun, if_pos this]',
#   'simp only [{unknown}, sbFun, if_pos {hypothesis}]'),
#  ('exact hg hx', 'exact {unknown} {unknown}'),
#  ('simp [sbAux] at hn', 'simp [sbAux] at {hypothesis}'),
#  ('rw [A_def, sbSet, mem_iUnion]', 'rw [{unknown}, sbSet, mem_iUnion]'),
#  ('exact ⟨n, xmem⟩', 'exact ⟨{unknown}, {hypothesis}⟩')]

# %%
premises = traced_file.get_premise_definitions()

for premise in premises:
    if premise['code'].startswith('theorem'):
        thm_name = premise['full_name']
        print("Theorem", thm_name, '\n')
        thm = traced_file.get_traced_theorem(thm_name)
        traced_tactics = thm.get_traced_tactics()
        for step in traced_tactics:
            print(step.state_before)
            print(step.tactic)
            tac = parse_lean_state_and_tactic(step.state_before, step.tactic)
            print("TAC:")
            print(tac)
            print()
# Out:
# Theorem C03S03.S03_Negation_ex1
#
# a b : ℝ
# h : a < b
# ⊢ ¬b < a
# intro h'
# TAC:
# intro h'
#
# a b : ℝ
# h : a < b
# h' : b < a
# ⊢ False
# have : a < a := lt_trans h h'
# TAC:
# have : a < a := lt_trans {a < b} {b < a}
#
# a b : ℝ
# h : a < b
# h' : b < a
# this : a < a
# ⊢ False
# apply lt_irrefl a this
# TAC:
# apply lt_irrefl a {a < a}
#
# Theorem C03S03.S03_Negation_ex2
#
# a b : ℝ
# f : ℝ → ℝ
# h : ∀ (a : ℝ), ∃ x, f x > a
# ⊢ ¬FnHasUb f
# intro fnub
# TAC:
# intro fnub
#
# a b : ℝ
# f : ℝ → ℝ
# h : ∀ (a : ℝ), ∃ x, f x > a
# fnub : FnHasUb f
# ⊢ False
# rcases fnub with ⟨a, fnuba⟩
# TAC:
# rcases {FnHasUb f} with ⟨a, fnuba⟩
#
# case intro
# a✝ b : ℝ
# f : ℝ → ℝ
# h : ∀ (a : ℝ), ∃ x, f x > a
# a : ℝ
# fnuba : FnUb f a
# ⊢ False
# rcases h a with ⟨x, hx⟩
# TAC:
# rcases {∀ (a} {ℝ} with ⟨x, hx⟩
#
# case intro.intro
# a✝ b : ℝ
# f : ℝ → ℝ
# h : ∀ (a : ℝ), ∃ x, f x > a
# a : ℝ
# fnuba : FnUb f a
# x : ℝ
# hx : f x > a
# ⊢ False
# have : f x ≤ a := fnuba x
# TAC:
# have : {ℝ → ℝ} {ℝ} ≤ {ℝ} := {FnUb f a} {ℝ}
#
# case intro.intro
# a✝ b : ℝ
# f : ℝ → ℝ
# h : ∀ (a : ℝ), ∃ x, f x > a
# a : ℝ
# fnuba : FnUb f a
# x : ℝ
# hx : f x > a
# this : f x ≤ a
# ⊢ False
# linarith
# TAC:
# linarith
#
# Theorem C03S03.S03_Negation_ex3
#
# Theorem C03S03.S03_Negation_ex4
#
# Theorem C03S03.S03_Negation_ex5
#
# a b : ℝ
# f : ℝ → ℝ
# h : Monotone f
# h' : f a < f b
# ⊢ a < b
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex6
#
# a b : ℝ
# f : ℝ → ℝ
# h : a ≤ b
# h' : f b < f a
# ⊢ ¬Monotone f
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex7
#
# a b : ℝ
# f : ℝ → ℝ
# ⊢ ¬∀ {f : ℝ → ℝ}, Monotone f → ∀ {a b : ℝ}, f a ≤ f b → a ≤ b
# intro h
# TAC:
# intro h
#
# a b : ℝ
# f : ℝ → ℝ
# h : ∀ {f : ℝ → ℝ}, Monotone f → ∀ {a b : ℝ}, f a ≤ f b → a ≤ b
# ⊢ False
# let f := fun x : ℝ ↦ (0 : ℝ)
# TAC:
# let {ℝ → ℝ} := fun x : ℝ ↦ (0 : ℝ)
#
# a b : ℝ
# f✝ : ℝ → ℝ
# h : ∀ {f : ℝ → ℝ}, Monotone f → ∀ {a b : ℝ}, f a ≤ f b → a ≤ b
# f : ℝ → ℝ := fun x => 0
# ⊢ False
# have monof : Monotone f := by sorry
# TAC:
# have monof : Monotone {ℝ → ℝ := fun x => 0} := by sorry
#
# a b : ℝ
# f✝ : ℝ → ℝ
# h : ∀ {f : ℝ → ℝ}, Monotone f → ∀ {a b : ℝ}, f a ≤ f b → a ≤ b
# f : ℝ → ℝ := fun x => 0
# monof : Monotone f
# ⊢ False
# have h' : f 1 ≤ f 0 := le_refl _
# TAC:
# have h' : {ℝ → ℝ := fun x => 0} 1 ≤ {ℝ → ℝ := fun x => 0} 0 := le_refl _
#
# a b : ℝ
# f✝ : ℝ → ℝ
# h : ∀ {f : ℝ → ℝ}, Monotone f → ∀ {a b : ℝ}, f a ≤ f b → a ≤ b
# f : ℝ → ℝ := fun x => 0
# monof : Monotone f
# h' : f 1 ≤ f 0
# ⊢ False
# sorry
# TAC:
# sorry
#
# a b : ℝ
# f✝ : ℝ → ℝ
# h : ∀ {f : ℝ → ℝ}, Monotone f → ∀ {a b : ℝ}, f a ≤ f b → a ≤ b
# f : ℝ → ℝ := fun x => 0
# ⊢ Monotone f
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex8
#
# a b : ℝ
# f : ℝ → ℝ
# x : ℝ
# h : ∀ ε > 0, x < ε
# ⊢ x ≤ 0
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex9
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : ¬∃ x, P x
# ⊢ ∀ (x : α), ¬P x
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex10
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : ∀ (x : α), ¬P x
# ⊢ ¬∃ x, P x
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex11
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : ¬∀ (x : α), P x
# ⊢ ∃ x, ¬P x
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex12
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : ∃ x, ¬P x
# ⊢ ¬∀ (x : α), P x
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex13
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : ¬∀ (x : α), P x
# ⊢ ∃ x, ¬P x
# by_contra h'
# TAC:
# by_contra h'
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : ¬∀ (x : α), P x
# h' : ¬∃ x, ¬P x
# ⊢ False
# apply h
# TAC:
# apply {¬∀ (x}
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : ¬∀ (x : α), P x
# h' : ¬∃ x, ¬P x
# ⊢ ∀ (x : α), P x
# intro x
# TAC:
# intro x
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : ¬∀ (x : α), P x
# h' : ¬∃ x, ¬P x
# x : α
# ⊢ P x
# by_contra h''
# TAC:
# by_contra h''
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : ¬∀ (x : α), P x
# h' : ¬∃ x, ¬P x
# x : α
# h'' : ¬P x
# ⊢ False
# exact h' ⟨x, h''⟩
# TAC:
# exact {¬∃ x, ¬P x} ⟨x, h''⟩
#
# Theorem C03S03.S03_Negation_ex14
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : ¬¬Q
# ⊢ Q
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex15
#
# α : Type u_1
# P : α → Prop
# Q : Prop
# h : Q
# ⊢ ¬¬Q
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex16
#
# f : ℝ → ℝ
# h : ¬FnHasUb f
# ⊢ ∀ (a : ℝ), ∃ x, f x > a
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex17
#
# f : ℝ → ℝ
# h : ¬∀ (a : ℝ), ∃ x, f x > a
# ⊢ FnHasUb f
# push_neg at h
# TAC:
# push_neg at {¬∀ (a}
#
# f : ℝ → ℝ
# h : ∃ a, ∀ (x : ℝ), f x ≤ a
# ⊢ FnHasUb f
# exact h
# TAC:
# exact {∃ a, ∀ (x}
#
# Theorem C03S03.S03_Negation_ex18
#
# f : ℝ → ℝ
# h : ¬FnHasUb f
# ⊢ ∀ (a : ℝ), ∃ x, f x > a
# dsimp only [FnHasUb, FnUb] at h
# TAC:
# dsimp only [FnHasUb, FnUb] at h
#
# f : ℝ → ℝ
# h : ¬∃ a, ∀ (x : ℝ), f x ≤ a
# ⊢ ∀ (a : ℝ), ∃ x, f x > a
# push_neg at h
# TAC:
# push_neg at {¬∃ a, ∀ (x}
#
# f : ℝ → ℝ
# h : ∀ (a : ℝ), ∃ x, a < f x
# ⊢ ∀ (a : ℝ), ∃ x, f x > a
# exact h
# TAC:
# exact {∀ (a}
#
# Theorem C03S03.S03_Negation_ex19
#
# f : ℝ → ℝ
# h : ¬Monotone f
# ⊢ ∃ x y, x ≤ y ∧ f y < f x
# sorry
# TAC:
# sorry
#
# Theorem C03S03.S03_Negation_ex20
#
# f : ℝ → ℝ
# h : ¬FnHasUb f
# ⊢ ∀ (a : ℝ), ∃ x, f x > a
# contrapose! h
# TAC:
# contrapose! {¬FnHasUb f}
#
# f : ℝ → ℝ
# h : ∃ a, ∀ (x : ℝ), f x ≤ a
# ⊢ FnHasUb f
# exact h
# TAC:
# exact {∃ a, ∀ (x}
#
# Theorem C03S03.S03_Negation_ex21
#
# f : ℝ → ℝ
# x : ℝ
# h : ∀ ε > 0, x ≤ ε
# ⊢ x ≤ 0
# contrapose! h
# TAC:
# contrapose! {∀ ε > 0, x ≤ ε}
#
# f : ℝ → ℝ
# x : ℝ
# h : 0 < x
# ⊢ ∃ ε > 0, ε < x
# use x / 2
# TAC:
# use {ℝ} / 2
#
# case h
# f : ℝ → ℝ
# x : ℝ
# h : 0 < x
# ⊢ x / 2 > 0 ∧ x / 2 < x
# constructor <;> linarith
# TAC:
# constructor <;> linarith
#
# Theorem C03S03.S03_Negation_ex22
#
# a : ℕ
# h : 0 < 0
# ⊢ a > 37
# exfalso
# TAC:
# exfalso
#
# a : ℕ
# h : 0 < 0
# ⊢ False
# apply lt_irrefl 0 h
# TAC:
# apply lt_irrefl 0 {0 < 0}
#
# Theorem C03S03.S03_Negation_ex23
#
# Theorem C03S03.S03_Negation_ex24
#
# a : ℕ
# h : 0 < 0
# ⊢ a > 37
# have h' : ¬0 < 0 := lt_irrefl 0
# TAC:
# have h' : ¬0 < 0 := lt_irrefl 0
#
# a : ℕ
# h : 0 < 0
# h' : ¬0 < 0
# ⊢ a > 37
# contradiction
# TAC:
# contradiction

# %%
premises = traced_file.get_premise_definitions()

premises[0]
# Out:
# {'full_name': 'C03S01.my_lemma',
#  'code': 'theorem my_lemma : ∀ x y ε : ℝ, 0 < ε → ε ≤ 1 → |x| < ε → |y| < ε → |x * y| < ε',
#  'start': [10, 1],
#  'end': [11, 8],
#  'kind': 'commanddeclaration'}

# %%
def classify_lean_element(line):
    VARIABLE_TYPES = ['ℝ']
    
    # Clean up the line
    line = line.strip()
    if not line:
        return None, None

    # Split the line around the ':'
    parts = line.split(':', 1)
    if len(parts) != 2:
        return None, None  # Skip malformed lines

    # Clean up names and types
    name_part, type_info = parts[0].strip(), parts[1].strip()

    if type_info.startswith('Type'):
        return 'type', name_part.split(), type_info
    
    if type_info.startswith('Set'):
        return 'set', name_part.split(), type_info
    
    if type_info.startswith(('∀', '∃', '¬')):
        return 'hypothesis', name_part.split(), type_info
    
    if type_info in VARIABLE_TYPES:
        return 'variable', name_part.split(), type_info
    
    # Check for function definitions or lambda functions
    if '→' in type_info or 'fun' in type_info or ':=' in type_info:
        # Check if it's a hypothesis disguised as a function (look for logical operators)
        if '∀' in type_info or '∃' in type_info:
            return 'hypothesis', name_part.split(), type_info
        return 'function', name_part.split(), type_info

    # Check for propositions or logical statements involving quantifiers
    if 'Prop' in type_info or '¬' in type_info or '∈' in type_info or '∉' in type_info:
        return 'hypothesis', name_part.split(), type_info

    # Handle multiple variables on the same line
    names = name_part.split()
    return 'unknown', names, type_info

def classify_lean_elements(lean_state):
    category_of_name = {}
    type_info_of_name = {}
    lines = lean_state.strip().split('\n')
    for line in lines:
        category, names, type_info = classify_lean_element(line)
        for name in names:
            category_of_name[name] = category
            type_info_of_name[name] = type_info
    
    names = list(category_of_name.keys())
    for name in names:
        if category_of_name[name] == 'unknown' and\
            type_info_of_name[name] in names and\
            category_of_name[type_info_of_name[name]] == 'type':
            category_of_name[name] = 'variable'

    return category_of_name, type_info_of_name

# Example usage
lean_state = """
α : Type u_1
P : α → Prop
Q : Prop
h : ¬∀ (x : α), P x
h' : ¬∃ x, ¬P x
x : α
h'' : ¬P x
a b : ℝ
f✝ : ℝ → ℝ
h1 : ∀ {f : ℝ → ℝ}, Monotone f → ∀ {a b : ℝ}, f a ≤ f b → a ≤ b
f : ℝ → ℝ := fun x => 0
α1 : Type u_1
s t : Set α
xstu : x ∈ (s \ t) \ u
xs : x ∈ s
xnt : x ∉ t
xnu : x ∉ u
xu : x ∈ u
ubf : FnHasUb f
ι : Type u_1
R : Type u_2
inst✝ : CommRing R
I : Ideal R
J : ι → Ideal R
i : ι
hs : (∀ j ∈ s, I + J j = 1) → I + ⨅ j ∈ s, J j = 1
hf : ∀ j ∈ insert i s, I + J j = 1
inst✝ : CommRing R
"""

category_of_name, _ = classify_lean_elements(lean_state)
for name, category in category_of_name.items():
    print(name, category)
# Out:
# α type
# P function
# Q hypothesis
# h hypothesis
# h' hypothesis
# x variable
# h'' hypothesis
# a variable
# b variable
# f✝ function
# h1 hypothesis
# f function
# α1 type
# s set
# t set
# xstu hypothesis
# xs hypothesis
# xnt hypothesis
# xnu hypothesis
# xu hypothesis
# ubf unknown
# ι type
# R type
# inst✝ unknown
# I unknown
# J function
# i variable
# hs hypothesis
# hf hypothesis

# %%
theorem = Theorem(repo, "MIL/C03_Logic/S01_Implication_and_the_Universal_Quantifier.lean", 
                  "C03S01.S01_Implication_and_the_Universal_Quantifier_ex1")

# For some theorems, it might take a few minutes.
dojo, state_0 = Dojo(theorem).__enter__()

print(state_0.pp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 4
#       1 theorem = Theorem(repo, "MIL/C03_Logic/S01_Implication_and_the_Universal_Quantifier.lean",
#       2                   "C03S01.S01_Implication_and_the_Universal_Quantifier_ex1")
# ----> 4 proof_node = theorem.get_proof_node()
#       5 proof = proof_node.lean_file[proof_node.start : proof_node.end]
#       6 print(proof)
#
# AttributeError: 'Theorem' object has no attribute 'get_proof_node'

# %%
state_1 = dojo.run_tac(state_0, "intro x")

print(state_1.pp)
# Out:
# f g : ℝ → ℝ
# a b : ℝ
# hfa : FnUb f a
# hgb : FnUb g b
# x : ℝ
# ⊢ (fun x => f x + g x) x ≤ a + b

# %%
state_2 = dojo.run_tac(state_1, "dsimp") 

print(state_2.pp)
# Out:
# f g : ℝ → ℝ
# a b : ℝ
# hfa : FnUb f a
# hgb : FnUb g b
# x : ℝ
# ⊢ f x + g x ≤ a + b

# %%
state_3 = dojo.run_tac(state_2, "apply add_le_add") 

print(state_3.pp)
# Out:
# case h₁
# f g : ℝ → ℝ
# a b : ℝ
# hfa : FnUb f a
# hgb : FnUb g b
# x : ℝ
# ⊢ f x ≤ a
#
# case h₂
# f g : ℝ → ℝ
# a b : ℝ
# hfa : FnUb f a
# hgb : FnUb g b
# x : ℝ
# ⊢ g x ≤ b

# %%
state_4 = dojo.run_tac(state_3, "apply hfa")

print(state_4.pp)
# Out:
# case h₂
# f g : ℝ → ℝ
# a b : ℝ
# hfa : FnUb f a
# hgb : FnUb g b
# x : ℝ
# ⊢ g x ≤ b

# %%
state_5 = dojo.run_tac(state_4, "apply hgb") 

state_5
# Out:
# ProofFinished(tactic_state_id=5, message='')

# %%
from datasets import Dataset
from transformers import AutoTokenizer
import pandas as pd
import json
import random

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained("xhyi/PT_GPTNEO350_ATG")
encoded = tokenizer.encode('a b c : ℝ\n⊢ (-c + (c + c))\nxnt : x ∉ t\nxnu : x ∉ u\nP : α → Prop\nh : ¬∀ (x : α), P x\nh : ¬∃ x, ¬P x')
decoded = tokenizer.decode(encoded)
print(decoded)
# Out:
# a b c : ℝ
# ⊢ (-c + (c + c))
# xnt : x ∉ t
# xnu : x ∉ u
# P : α → Prop
# h : ¬∀ (x : α), P x
# h : ¬∃ x, ¬P x
